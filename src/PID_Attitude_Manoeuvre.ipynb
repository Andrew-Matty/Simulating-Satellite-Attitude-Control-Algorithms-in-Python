# %% [markdown]
# # Final PID attitude manuever no ext tourque using rk4 method

# %% [markdown]
# Run once for manual tuned and another for the optimiser results

# %% [markdown]
# ## Firstly the manually tuned conditions

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Quaternion Kinematics Functions

# %%
def quaternion_product(q, p):
    w0, x0, y0, z0 = q
    w1, x1, y1, z1 = p
    return np.array([
        w0*w1 - x0*x1 - y0*y1 - z0*z1,
        w0*x1 + x0*w1 + y0*z1 - z0*y1,
        w0*y1 - x0*z1 + y0*w1 + z0*x1,
        w0*z1 + x0*y1 - y0*x1 + z0*w1
    ])

def quaternion_conjugate(q):
    return np.array([q[0], -q[1], -q[2], -q[3]])

def quaternion_error(q, q_target):
    return quaternion_product(quaternion_conjugate(q), q_target)

# %% [markdown]
# PID controller function with Quaternion Error

# %%
def pid_control(q, omega, q_target, integral_error, prev_error, dt):
    error = 2*quaternion_error(q, q_target)[1:]  # Vector part of the quaternion error
    
    integral_error += error * dt
    derivative_error = (error - prev_error) / dt
    
    control_torque = Kp * error + Ki * integral_error + Kd * derivative_error

    return control_torque, integral_error, error,

# %% [markdown]
# Satellite Dynamics using Eulers equations

# %%
# Satellite dynamics function
def dynamics(t, state, integral_error, prev_error, dt):
    q = state[:4]
    omega = state[4:]

    q = q / np.linalg.norm(q)  # Normalize quaternion

    dqdt = 0.5 * quaternion_product(q, np.append([0], omega))
    
    control_torque, integral_error, prev_error = pid_control(q, omega, q_target, integral_error, prev_error, dt)
    
    omega_cross_I_omega = np.cross(omega, I @ omega)
    dwdt = inv_I @ (control_torque - omega_cross_I_omega)

    return np.concatenate([dqdt, dwdt]), integral_error, prev_error

# %% [markdown]
# Runge Kutta 4th order integration Function to update the state of the satellite

# %%
# RK4 integration method
def rk4_step(dynamics_func, t, state, dt, integral_error, prev_error):
    k1, integral_error1, prev_error1 = dynamics_func(t, state, integral_error, prev_error, dt)
    k2, integral_error2, prev_error2 = dynamics_func(t + 0.5 * dt, state + 0.5 * dt * k1, integral_error1, prev_error1, dt)
    k3, integral_error3, prev_error3 = dynamics_func(t + 0.5 * dt, state + 0.5 * dt * k2, integral_error2, prev_error2, dt)
    k4, integral_error4, prev_error4 = dynamics_func(t + dt, state + dt * k3, integral_error3, prev_error3, dt)

    new_state = state + (dt / 6) * (k1 + 2 * k2 + 2 * k3 + k4)
    return new_state, integral_error4, prev_error4

# %% [markdown]
# Initial conditions for the simulation:

# %%
# Inertia Matrix
Ix, Iy, Iz = 1191, 1844, 1798
I = np.diag([Ix, Iy, Iz])  # Inertia matrix
inv_I = np.linalg.inv(I)

# PID controller gains with manually tuned PID gains 
Kp = np.array([0.3, 0.3, 0.3])
Ki = np.array([0.000001, 0.000001, 0.000001])
Kd = np.array([100.0, 100.0, 100.0])

# Target quaternion (example target)
q_target = np.array([0.9938, 0.086, 0.0513, 0.0608])
q_target = q_target / np.linalg.norm(q_target) 

q0 = np.array([1, 0, 0, 0])  # Initial quaternion
q0 = q0 / np.linalg.norm(q0)  # Normalize quaternion
omega0 = np.array([0, 0, 0])
state0 = np.concatenate([q0, omega0])

# Simulation parameters
t_span = (0, 2000)  # Time span for the simulation
t_eval = np.linspace(*t_span, 2000)  # Time points where the solution is computed
dt = 1

# Initialize PID errors
integral_error = np.zeros(3)
prev_error = np.zeros(3)
# Initialize storage for control torques
control_torques_history = [(0,0,0)]
time_history = [0]
# Run simulation using RK4
states = [state0]
t_values = [t_span[0]]

# %% [markdown]
# Simulaiton Loop

# %%
for t in t_eval[:-1]:
    new_state, integral_error, prev_error = rk4_step(dynamics, t, states[-1], dt, integral_error, prev_error)
    states.append(new_state)
    t_values.append(t + dt)
    control_torque_t, _, _ = pid_control(new_state[:4], new_state[4:], q_target, integral_error, prev_error, dt)
    # Store the control torque and time history
    control_torques_history.append(control_torque_t)
    time_history.append(t)
    #updater for sim
    print(f"Simulation step {t+1}/{len(t_eval)}")

states = np.array(states)
#time in seconds 5000s
time_sec = np.linspace(0, 2000, 2000)
# Output the final state for inspection
print(states[-1])

# %% [markdown]
# Plotting the Quaternions over time

# %%
# Optional: Plot results
plt.figure(figsize=(10, 6))
plt.plot(time_sec, states[:, :4])
# Put in flat lines of the q target
plt.plot(time_sec, np.tile(q_target, (len(time_sec), 1)), '--')
plt.xlabel('Time')
plt.ylabel('Quaternion Components')
plt.title('Quaternion over Time')
plt.legend(['q0', 'q1', 'q2', 'q3'])
plt.show()

# %% [markdown]
# Plots of the Angular Velocity

# %%
#plot angular velocity
plt.figure(figsize=(10, 6))
plt.plot(time_sec, states[:, 4:])
plt.plot(time_sec, np.tile(0.00269, (len(time_sec), 1)), '--')
plt.xlabel('Time')
plt.ylabel('Angular Velocity')
plt.title('Angular Velocity over Time')
plt.legend(['wx', 'wy', 'wz'])
plt.show()

# %% [markdown]
# Control Torques over time

# %%
#plot control torques
plt.figure(figsize=(10, 6))
time_sec_control = np.linspace(0, 2000, 2000)
plt.plot(time_sec_control, control_torques_history)
plt.xlabel('Time')
plt.ylabel('Control Torques')
plt.title('Control Torques over Time')
plt.legend(['Tx', 'Ty', 'Tz'])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def quaternion_product(q, p):
    w0, x0, y0, z0 = q
    w1, x1, y1, z1 = p
    return np.array([
        w0*w1 - x0*x1 - y0*y1 - z0*z1,
        w0*x1 + x0*w1 + y0*z1 - z0*y1,
        w0*y1 - x0*z1 + y0*w1 + z0*x1,
        w0*z1 + x0*y1 - y0*x1 + z0*w1
    ])

def quaternion_conjugate(q):
    return np.array([q[0], -q[1], -q[2], -q[3]])

def quaternion_error(q, q_target):
    return quaternion_product(quaternion_conjugate(q), q_target)


def pid_control(q, omega, q_target, integral_error, prev_error, dt):
    error = 2*quaternion_error(q, q_target)[1:]  # Vector part of the quaternion error
    
    integral_error += error * dt
    derivative_error = (error - prev_error) / dt
    
    control_torque = Kp * error + Ki * integral_error + Kd * derivative_error

    # adding bounds to the control torque
    control_torque = np.clip(control_torque, -0.25, 0.25)

    return control_torque, integral_error, error,

def dynamics(t, state, integral_error, prev_error, dt):
    q = state[:4]
    omega = state[4:]

    q = q / np.linalg.norm(q)  # Normalize quaternion

    dqdt = 0.5 * quaternion_product(q, np.append([0], omega))
    
    control_torque, integral_error, prev_error = pid_control(q, omega, q_target, integral_error, prev_error, dt)
    
    omega_cross_I_omega = np.cross(omega, I @ omega)
    dwdt = inv_I @ (control_torque - omega_cross_I_omega)

    return np.concatenate([dqdt, dwdt]), integral_error, prev_error


# RK4 integration method
def rk4_step(dynamics_func, t, state, dt, integral_error, prev_error):
    k1, integral_error1, prev_error1 = dynamics_func(t, state, integral_error, prev_error, dt)
    k2, integral_error2, prev_error2 = dynamics_func(t + 0.5 * dt, state + 0.5 * dt * k1, integral_error1, prev_error1, dt)
    k3, integral_error3, prev_error3 = dynamics_func(t + 0.5 * dt, state + 0.5 * dt * k2, integral_error2, prev_error2, dt)
    k4, integral_error4, prev_error4 = dynamics_func(t + dt, state + dt * k3, integral_error3, prev_error3, dt)

    new_state = state + (dt / 6) * (k1 + 2 * k2 + 2 * k3 + k4)
    return new_state, integral_error4, prev_error4

# Initialize simulation
Ix, Iy, Iz = 1191, 1844, 1798
I = np.diag([Ix, Iy, Iz])  # Inertia matrix
inv_I = np.linalg.inv(I)

#Best gains: Kp = [0.19795918 0.19795918 0.19795918], Ki = [1.e-06 1.e-06 1.e-06], Kd = [111.51515152 111.51515152 111.51515152]
# PID controller gains
Kp = np.array([0.19795918, 0.19795918, 0.19795918])
Ki = np.array([0.000001, 0.000001, 0.000001])
Kd = np.array([111.51515152, 111.51515152, 111.51515152])

# PID controller gains working
#Kp = np.array([0.2, 0.2, 0.2])
#Ki = np.array([0.000001, 0.000001, 0.000001])
#Kd = np.array([80.0, 80.0, 80.0])


# Target quaternion (example target)
q_target = np.array([0.9938, 0.086, 0.0513, 0.0608])
q_target = q_target / np.linalg.norm(q_target) 

q0 = np.array([1, 0, 0, 0])  # Initial quaternion
q0 = q0 / np.linalg.norm(q0)  # Normalize quaternion
omega0 = np.array([0, 0, 0])
state0 = np.concatenate([q0, omega0])

# Simulation parameters
t_span = (0, 2000)  # Time span for the simulation
t_eval = np.linspace(*t_span, 2000)  # Time points where the solution is computed
dt = 1

# Initialize PID errors
integral_error = np.zeros(3)
prev_error = np.zeros(3)
# Initialize storage for control torques
control_torques_history = [(0,0,0)]
time_history = [0]
# Run simulation using RK4
states = [state0]
t_values = [t_span[0]]

for t in t_eval[:-1]:
    new_state, integral_error, prev_error = rk4_step(dynamics, t, states[-1], dt, integral_error, prev_error)
    states.append(new_state)
    t_values.append(t + dt)
    control_torque_t, _, _ = pid_control(new_state[:4], new_state[4:], q_target, integral_error, prev_error, dt)
    # Store the control torque and time history
    control_torques_history.append(control_torque_t)
    time_history.append(t)
    #updater for sim
    print(f"Simulation step {t+1}/{len(t_eval)}")

states = np.array(states)
#time in seconds 5000s
time_sec = np.linspace(0, 2000, 2000)
# Output the final state for inspection
print(states[-1])

# Optional: Plot results
plt.figure(figsize=(10, 6))
plt.plot(time_sec, states[:, :4])
# Put in flat lines of the q target
plt.plot(time_sec, np.tile(q_target, (len(time_sec), 1)), '--')
plt.xlabel('Time')
plt.ylabel('Quaternion Components')
plt.title('Quaternion over Time')
plt.legend(['q0', 'q1', 'q2', 'q3'])
plt.show()
# Out:
# Simulation step 1.0/2000
# Simulation step 2.0005002501250626/2000
# Simulation step 3.001000500250125/2000
# Simulation step 4.001500750375188/2000
# Simulation step 5.00200100050025/2000
# Simulation step 6.002501250625313/2000
# Simulation step 7.003001500750376/2000
# Simulation step 8.003501750875438/2000
# Simulation step 9.0040020010005/2000
# Simulation step 10.004502251125563/2000
# Simulation step 11.005002501250626/2000
# Simulation step 12.005502751375689/2000
# Simulation step 13.006003001500751/2000
# Simulation step 14.006503251625814/2000
# Simulation step 15.007003501750876/2000
# Simulation step 16.007503751875937/2000
# Simulation step 17.008004002001/2000
# Simulation step 18.008504252126066/2000
# Simulation step 19.009004502251127/2000
# Simulation step 20.009504752376188/2000
# Simulation step 21.010005002501252/2000
# Simulation step 22.010505252626317/2000
# Simulation step 23.011005502751377/2000
# Simulation step 24.011505752876438/2000
# Simulation step 25.012006003001503/2000
# Simulation step 26.012506253126567/2000
# Simulation step 27.013006503251628/2000
# Simulation step 28.01350675337669/2000
# Simulation step 29.014007003501753/2000
# Simulation step 30.014507253626817/2000
# Simulation step 31.015007503751878/2000
# Simulation step 32.01550775387694/2000
# Simulation step 33.016008004002/2000
# Simulation step 34.01650825412707/2000
# Simulation step 35.01700850425213/2000
# Simulation step 36.01750875437719/2000
# Simulation step 37.018009004502254/2000
# Simulation step 38.01850925462732/2000
# Simulation step 39.019009504752376/2000
# Simulation step 40.01950975487744/2000
# Simulation step 41.020010005002504/2000
# Simulation step 42.02051025512757/2000
# Simulation step 43.02101050525263/2000
# Simulation step 44.02151075537769/2000
# Simulation step 45.022011005502755/2000
# Simulation step 46.02251125562782/2000
# Simulation step 47.023011505752876/2000
# Simulation step 48.02351175587794/2000
# Simulation step 49.024012006003005/2000
# Simulation step 50.02451225612807/2000
# Simulation step 51.025012506253134/2000
# Simulation step 52.02551275637819/2000
# Simulation step 53.026013006503256/2000
# Simulation step 54.02651325662832/2000
# Simulation step 55.02701350675338/2000
# Simulation step 56.02751375687844/2000
# Simulation step 57.028014007003506/2000
# Simulation step 58.02851425712857/2000
# Simulation step 59.029014507253635/2000
# Simulation step 60.02951475737869/2000
# Simulation step 61.030015007503756/2000
# Simulation step 62.03051525762882/2000
# Simulation step 63.03101550775388/2000
# Simulation step 64.03151575787894/2000
# Simulation step 65.032016008004/2000
# Simulation step 66.03251625812906/2000
# Simulation step 67.03301650825414/2000
# Simulation step 68.03351675837919/2000
# Simulation step 69.03401700850426/2000
# Simulation step 70.03451725862932/2000
# Simulation step 71.03501750875438/2000
# Simulation step 72.03551775887945/2000
# Simulation step 73.03601800900451/2000
# Simulation step 74.03651825912956/2000
# Simulation step 75.03701850925464/2000
# Simulation step 76.0375187593797/2000
# Simulation step 77.03801900950475/2000
# Simulation step 78.03851925962982/2000
# Simulation step 79.03901950975488/2000
# Simulation step 80.03951975987995/2000
# Simulation step 81.04002001000501/2000
# Simulation step 82.04052026013007/2000
# Simulation step 83.04102051025514/2000
# Simulation step 84.0415207603802/2000
# Simulation step 85.04202101050527/2000
# Simulation step 86.04252126063032/2000
# Simulation step 87.04302151075538/2000
# Simulation step 88.04352176088045/2000
# Simulation step 89.04402201100551/2000
# Simulation step 90.04452226113057/2000
# Simulation step 91.04502251125564/2000
# Simulation step 92.0455227613807/2000
# Simulation step 93.04602301150575/2000
# Simulation step 94.04652326163082/2000
# Simulation step 95.04702351175588/2000
# Simulation step 96.04752376188095/2000
# Simulation step 97.04802401200601/2000
# Simulation step 98.04852426213107/2000
# Simulation step 99.04902451225614/2000
# Simulation step 100.0495247623812/2000
# Simulation step 101.05002501250627/2000
# Simulation step 102.05052526263133/2000
# Simulation step 103.05102551275638/2000
# Simulation step 104.05152576288145/2000
# Simulation step 105.05202601300651/2000
# Simulation step 106.05252626313157/2000
# Simulation step 107.05302651325664/2000
# Simulation step 108.0535267633817/2000
# Simulation step 109.05402701350675/2000
# Simulation step 110.05452726363183/2000
# Simulation step 111.05502751375688/2000
# Simulation step 112.05552776388195/2000
# Simulation step 113.05602801400701/2000
# Simulation step 114.05652826413207/2000
# Simulation step 115.05702851425714/2000
# Simulation step 116.0575287643822/2000
# Simulation step 117.05802901450727/2000
# Simulation step 118.05852926463233/2000
# Simulation step 119.05902951475738/2000
# Simulation step 120.05952976488246/2000
# Simulation step 121.06003001500751/2000
# Simulation step 122.06053026513257/2000
# Simulation step 123.06103051525764/2000
# Simulation step 124.0615307653827/2000
# Simulation step 125.06203101550776/2000
# Simulation step 126.06253126563283/2000
# Simulation step 127.06303151575788/2000
# Simulation step 128.06353176588294/2000
# Simulation step 129.064032016008/2000
# Simulation step 130.06453226613309/2000
# Simulation step 131.06503251625813/2000
# Simulation step 132.0655327663832/2000
# Simulation step 133.06603301650827/2000
# Simulation step 134.06653326663331/2000
# Simulation step 135.06703351675839/2000
# Simulation step 136.06753376688346/2000
# Simulation step 137.06803401700853/2000
# Simulation step 138.06853426713357/2000
# Simulation step 139.06903451725864/2000
# Simulation step 140.06953476738371/2000
# Simulation step 141.07003501750876/2000
# Simulation step 142.07053526763383/2000
# Simulation step 143.0710355177589/2000
# Simulation step 144.07153576788394/2000
# Simulation step 145.07203601800902/2000
# Simulation step 146.0725362681341/2000
# Simulation step 147.07303651825913/2000
# Simulation step 148.0735367683842/2000
# Simulation step 149.07403701850927/2000
# Simulation step 150.07453726863432/2000
# Simulation step 151.0750375187594/2000
# Simulation step 152.07553776888446/2000
# Simulation step 153.0760380190095/2000
# Simulation step 154.07653826913457/2000
# Simulation step 155.07703851925964/2000
# Simulation step 156.07753876938472/2000
# Simulation step 157.07803901950976/2000
# Simulation step 158.07853926963483/2000
# Simulation step 159.0790395197599/2000
# Simulation step 160.07953976988495/2000
# Simulation step 161.08004002001002/2000
# Simulation step 162.0805402701351/2000
# Simulation step 163.08104052026013/2000
# Simulation step 164.0815407703852/2000
# Simulation step 165.08204102051027/2000
# Simulation step 166.08254127063532/2000
# Simulation step 167.0830415207604/2000
# Simulation step 168.08354177088546/2000
# Simulation step 169.08404202101053/2000
# Simulation step 170.08454227113558/2000
# Simulation step 171.08504252126065/2000
# Simulation step 172.08554277138572/2000
# Simulation step 173.08604302151076/2000
# Simulation step 174.08654327163583/2000
# Simulation step 175.0870435217609/2000
# Simulation step 176.08754377188595/2000
# Simulation step 177.08804402201102/2000
# Simulation step 178.0885442721361/2000
# Simulation step 179.08904452226113/2000
# Simulation step 180.0895447723862/2000
# Simulation step 181.09004502251128/2000
# Simulation step 182.09054527263632/2000
# Simulation step 183.0910455227614/2000
# Simulation step 184.09154577288646/2000
# Simulation step 185.0920460230115/2000
# Simulation step 186.09254627313658/2000
# Simulation step 187.09304652326165/2000
# Simulation step 188.09354677338672/2000
# Simulation step 189.09404702351176/2000
# Simulation step 190.09454727363683/2000
# Simulation step 191.0950475237619/2000
# Simulation step 192.09554777388695/2000
# Simulation step 193.09604802401202/2000
# Simulation step 194.0965482741371/2000
# Simulation step 195.09704852426214/2000
# Simulation step 196.0975487743872/2000
# Simulation step 197.09804902451228/2000
# Simulation step 198.09854927463732/2000
# Simulation step 199.0990495247624/2000
# Simulation step 200.09954977488746/2000
# Simulation step 201.10005002501254/2000
# Simulation step 202.10055027513758/2000
# Simulation step 203.10105052526265/2000
# Simulation step 204.10155077538772/2000
# Simulation step 205.10205102551276/2000
# Simulation step 206.10255127563784/2000
# Simulation step 207.1030515257629/2000
# Simulation step 208.10355177588795/2000
# Simulation step 209.10405202601302/2000
# Simulation step 210.1045522761381/2000
# Simulation step 211.10505252626314/2000
# Simulation step 212.1055527763882/2000
# Simulation step 213.10605302651328/2000
# Simulation step 214.10655327663832/2000
# Simulation step 215.1070535267634/2000
# Simulation step 216.10755377688847/2000
# Simulation step 217.1080540270135/2000
# Simulation step 218.10855427713858/2000
# Simulation step 219.10905452726365/2000
# Simulation step 220.10955477738872/2000
# Simulation step 221.11005502751377/2000
# Simulation step 222.11055527763884/2000
# Simulation step 223.1110555277639/2000
# Simulation step 224.11155577788895/2000
# Simulation step 225.11205602801402/2000
# Simulation step 226.1125562781391/2000
# Simulation step 227.11305652826414/2000
# Simulation step 228.1135567783892/2000
# Simulation step 229.11405702851428/2000
# Simulation step 230.11455727863932/2000
# Simulation step 231.1150575287644/2000
# Simulation step 232.11555777888947/2000
# Simulation step 233.11605802901454/2000
# Simulation step 234.11655827913958/2000
# Simulation step 235.11705852926465/2000
# Simulation step 236.11755877938973/2000
# Simulation step 237.11805902951477/2000
# Simulation step 238.11855927963984/2000
# Simulation step 239.1190595297649/2000
# Simulation step 240.11955977988995/2000
# Simulation step 241.12006003001503/2000
# Simulation step 242.1205602801401/2000
# Simulation step 243.12106053026514/2000
# Simulation step 244.1215607803902/2000
# Simulation step 245.12206103051528/2000
# Simulation step 246.12256128064033/2000
# Simulation step 247.1230615307654/2000
# Simulation step 248.12356178089047/2000
# Simulation step 249.1240620310155/2000
# Simulation step 250.12456228114058/2000
# Simulation step 251.12506253126566/2000
# Simulation step 252.12556278139073/2000
# Simulation step 253.12606303151577/2000
# Simulation step 254.12656328164084/2000
# Simulation step 255.1270635317659/2000
# Simulation step 256.12756378189096/2000
# Simulation step 257.128064032016/2000
# Simulation step 258.1285642821411/2000
# Simulation step 259.12906453226617/2000
# Simulation step 260.12956478239124/2000
# Simulation step 261.13006503251626/2000
# Simulation step 262.1305652826413/2000
# Simulation step 263.1310655327664/2000
# Simulation step 264.13156578289147/2000
# Simulation step 265.13206603301654/2000
# Simulation step 266.1325662831416/2000
# Simulation step 267.13306653326663/2000
# Simulation step 268.1335667833917/2000
# Simulation step 269.13406703351677/2000
# Simulation step 270.13456728364184/2000
# Simulation step 271.1350675337669/2000
# Simulation step 272.135567783892/2000
# Simulation step 273.13606803401706/2000
# Simulation step 274.1365682841421/2000
# Simulation step 275.13706853426714/2000
# Simulation step 276.1375687843922/2000
# Simulation step 277.1380690345173/2000
# Simulation step 278.13856928464236/2000
# Simulation step 279.13906953476743/2000
# Simulation step 280.13956978489244/2000
# Simulation step 281.1400700350175/2000
# Simulation step 282.1405702851426/2000
# Simulation step 283.14107053526766/2000
# Simulation step 284.14157078539273/2000
# Simulation step 285.1420710355178/2000
# Simulation step 286.1425712856428/2000
# Simulation step 287.1430715357679/2000
# Simulation step 288.14357178589296/2000
# Simulation step 289.14407203601803/2000
# Simulation step 290.1445722861431/2000
# Simulation step 291.1450725362682/2000
# Simulation step 292.14557278639325/2000
# Simulation step 293.14607303651826/2000
# Simulation step 294.14657328664333/2000
# Simulation step 295.1470735367684/2000
# Simulation step 296.1475737868935/2000
# Simulation step 297.14807403701855/2000
# Simulation step 298.1485742871436/2000
# Simulation step 299.14907453726863/2000
# Simulation step 300.1495747873937/2000
# Simulation step 301.1500750375188/2000
# Simulation step 302.15057528764385/2000
# Simulation step 303.1510755377689/2000
# Simulation step 304.151575787894/2000
# Simulation step 305.152076038019/2000
# Simulation step 306.1525762881441/2000
# Simulation step 307.15307653826915/2000
# Simulation step 308.1535767883942/2000
# Simulation step 309.1540770385193/2000
# Simulation step 310.15457728864436/2000
# Simulation step 311.15507753876943/2000
# Simulation step 312.15557778889445/2000
# Simulation step 313.1560780390195/2000
# Simulation step 314.1565782891446/2000
# Simulation step 315.15707853926966/2000
# Simulation step 316.15757878939473/2000
# Simulation step 317.1580790395198/2000
# Simulation step 318.1585792896448/2000
# Simulation step 319.1590795397699/2000
# Simulation step 320.15957978989496/2000
# Simulation step 321.16008004002003/2000
# Simulation step 322.1605802901451/2000
# Simulation step 323.1610805402702/2000
# Simulation step 324.16158079039525/2000
# Simulation step 325.16208104052026/2000
# Simulation step 326.16258129064533/2000
# Simulation step 327.1630815407704/2000
# Simulation step 328.1635817908955/2000
# Simulation step 329.16408204102055/2000
# Simulation step 330.1645822911456/2000
# Simulation step 331.16508254127064/2000
# Simulation step 332.1655827913957/2000
# Simulation step 333.1660830415208/2000
# Simulation step 334.16658329164585/2000
# Simulation step 335.1670835417709/2000
# Simulation step 336.167583791896/2000
# Simulation step 337.16808404202106/2000
# Simulation step 338.1685842921461/2000
# Simulation step 339.16908454227115/2000
# Simulation step 340.1695847923962/2000
# Simulation step 341.1700850425213/2000
# Simulation step 342.17058529264636/2000
# Simulation step 343.17108554277144/2000
# Simulation step 344.17158579289645/2000
# Simulation step 345.1720860430215/2000
# Simulation step 346.1725862931466/2000
# Simulation step 347.17308654327167/2000
# Simulation step 348.17358679339674/2000
# Simulation step 349.1740870435218/2000
# Simulation step 350.1745872936468/2000
# Simulation step 351.1750875437719/2000
# Simulation step 352.17558779389697/2000
# Simulation step 353.17608804402204/2000
# Simulation step 354.1765882941471/2000
# Simulation step 355.1770885442722/2000
# Simulation step 356.17758879439725/2000
# Simulation step 357.17808904452227/2000
# Simulation step 358.17858929464734/2000
# Simulation step 359.1790895447724/2000
# Simulation step 360.1795897948975/2000
# Simulation step 361.18009004502255/2000
# Simulation step 362.1805902951476/2000
# Simulation step 363.18109054527264/2000
# Simulation step 364.1815907953977/2000
# Simulation step 365.1820910455228/2000
# Simulation step 366.18259129564785/2000
# Simulation step 367.1830915457729/2000
# Simulation step 368.183591795898/2000
# Simulation step 369.184092046023/2000
# Simulation step 370.1845922961481/2000
# Simulation step 371.18509254627315/2000
# Simulation step 372.1855927963982/2000
# Simulation step 373.1860930465233/2000
# Simulation step 374.18659329664837/2000
# Simulation step 375.18709354677344/2000
# Simulation step 376.18759379689845/2000
# Simulation step 377.1880940470235/2000
# Simulation step 378.1885942971486/2000
# Simulation step 379.18909454727367/2000
# Simulation step 380.18959479739874/2000
# Simulation step 381.1900950475238/2000
# Simulation step 382.1905952976488/2000
# Simulation step 383.1910955477739/2000
# Simulation step 384.19159579789897/2000
# Simulation step 385.19209604802404/2000
# Simulation step 386.1925962981491/2000
# Simulation step 387.1930965482742/2000
# Simulation step 388.19359679839926/2000
# Simulation step 389.19409704852427/2000
# Simulation step 390.19459729864934/2000
# Simulation step 391.1950975487744/2000
# Simulation step 392.1955977988995/2000
# Simulation step 393.19609804902456/2000
# Simulation step 394.1965982991496/2000
# Simulation step 395.19709854927464/2000
# Simulation step 396.1975987993997/2000
# Simulation step 397.1980990495248/2000
# Simulation step 398.19859929964986/2000
# Simulation step 399.1990995497749/2000
# Simulation step 400.1995997999/2000
# Simulation step 401.20010005002507/2000
# Simulation step 402.2006003001501/2000
# Simulation step 403.20110055027516/2000
# Simulation step 404.20160080040023/2000
# Simulation step 405.2021010505253/2000
# Simulation step 406.2026013006504/2000
# Simulation step 407.20310155077544/2000
# Simulation step 408.20360180090046/2000
# Simulation step 409.20410205102553/2000
# Simulation step 410.2046023011506/2000
# Simulation step 411.2051025512757/2000
# Simulation step 412.20560280140074/2000
# Simulation step 413.2061030515258/2000
# Simulation step 414.20660330165083/2000
# Simulation step 415.2071035517759/2000
# Simulation step 416.207603801901/2000
# Simulation step 417.20810405202604/2000
# Simulation step 418.2086043021511/2000
# Simulation step 419.2091045522762/2000
# Simulation step 420.20960480240126/2000
# Simulation step 421.2101050525263/2000
# Simulation step 422.21060530265135/2000
# Simulation step 423.2111055527764/2000
# Simulation step 424.2116058029015/2000
# Simulation step 425.21210605302656/2000
# Simulation step 426.21260630315163/2000
# Simulation step 427.21310655327665/2000
# Simulation step 428.2136068034017/2000
# Simulation step 429.2141070535268/2000
# Simulation step 430.21460730365186/2000
# Simulation step 431.21510755377693/2000
# Simulation step 432.215607803902/2000
# Simulation step 433.216108054027/2000
# Simulation step 434.2166083041521/2000
# Simulation step 435.21710855427716/2000
# Simulation step 436.21760880440223/2000
# Simulation step 437.2181090545273/2000
# Simulation step 438.2186093046524/2000
# Simulation step 439.21910955477745/2000
# Simulation step 440.21960980490246/2000
# Simulation step 441.22011005502753/2000
# Simulation step 442.2206103051526/2000
# Simulation step 443.2211105552777/2000
# Simulation step 444.22161080540275/2000
# Simulation step 445.2221110555278/2000
# Simulation step 446.22261130565283/2000
# Simulation step 447.2231115557779/2000
# Simulation step 448.223611805903/2000
# Simulation step 449.22411205602805/2000
# Simulation step 450.2246123061531/2000
# Simulation step 451.2251125562782/2000
# Simulation step 452.22561280640326/2000
# Simulation step 453.2261130565283/2000
# Simulation step 454.22661330665335/2000
# Simulation step 455.2271135567784/2000
# Simulation step 456.2276138069035/2000
# Simulation step 457.22811405702856/2000
# Simulation step 458.22861430715363/2000
# Simulation step 459.22911455727865/2000
# Simulation step 460.2296148074037/2000
# Simulation step 461.2301150575288/2000
# Simulation step 462.23061530765386/2000
# Simulation step 463.23111555777893/2000
# Simulation step 464.231615807904/2000
# Simulation step 465.2321160580291/2000
# Simulation step 466.2326163081541/2000
# Simulation step 467.23311655827916/2000
# Simulation step 468.23361680840424/2000
# Simulation step 469.2341170585293/2000
# Simulation step 470.2346173086544/2000
# Simulation step 471.23511755877945/2000
# Simulation step 472.23561780890446/2000
# Simulation step 473.23611805902954/2000
# Simulation step 474.2366183091546/2000
# Simulation step 475.2371185592797/2000
# Simulation step 476.23761880940475/2000
# Simulation step 477.2381190595298/2000
# Simulation step 478.23861930965484/2000
# Simulation step 479.2391195597799/2000
# Simulation step 480.239619809905/2000
# Simulation step 481.24012006003005/2000
# Simulation step 482.2406203101551/2000
# Simulation step 483.2411205602802/2000
# Simulation step 484.24162081040527/2000
# Simulation step 485.2421210605303/2000
# Simulation step 486.24262131065535/2000
# Simulation step 487.2431215607804/2000
# Simulation step 488.2436218109055/2000
# Simulation step 489.24412206103057/2000
# Simulation step 490.24462231115564/2000
# Simulation step 491.24512256128065/2000
# Simulation step 492.2456228114057/2000
# Simulation step 493.2461230615308/2000
# Simulation step 494.24662331165587/2000
# Simulation step 495.24712356178094/2000
# Simulation step 496.247623811906/2000
# Simulation step 497.248124062031/2000
# Simulation step 498.2486243121561/2000
# Simulation step 499.24912456228117/2000
# Simulation step 500.24962481240624/2000
# Simulation step 501.2501250625313/2000
# Simulation step 502.2506253126564/2000
# Simulation step 503.25112556278145/2000
# Simulation step 504.25162581290647/2000
# Simulation step 505.25212606303154/2000
# Simulation step 506.2526263131566/2000
# Simulation step 507.2531265632817/2000
# Simulation step 508.25362681340675/2000
# Simulation step 509.2541270635318/2000
# Simulation step 510.25462731365684/2000
# Simulation step 511.2551275637819/2000
# Simulation step 512.255627813907/2000
# Simulation step 513.256128064032/2000
# Simulation step 514.2566283141571/2000
# Simulation step 515.2571285642822/2000
# Simulation step 516.2576288144072/2000
# Simulation step 517.2581290645323/2000
# Simulation step 518.2586293146574/2000
# Simulation step 519.2591295647825/2000
# Simulation step 520.2596298149075/2000
# Simulation step 521.2601300650325/2000
# Simulation step 522.2606303151576/2000
# Simulation step 523.2611305652827/2000
# Simulation step 524.2616308154078/2000
# Simulation step 525.2621310655328/2000
# Simulation step 526.2626313156578/2000
# Simulation step 527.2631315657829/2000
# Simulation step 528.263631815908/2000
# Simulation step 529.2641320660331/2000
# Simulation step 530.2646323161581/2000
# Simulation step 531.2651325662832/2000
# Simulation step 532.2656328164082/2000
# Simulation step 533.2661330665333/2000
# Simulation step 534.2666333166584/2000
# Simulation step 535.2671335667834/2000
# Simulation step 536.2676338169085/2000
# Simulation step 537.2681340670335/2000
# Simulation step 538.2686343171587/2000
# Simulation step 539.2691345672837/2000
# Simulation step 540.2696348174087/2000
# Simulation step 541.2701350675338/2000
# Simulation step 542.2706353176588/2000
# Simulation step 543.271135567784/2000
# Simulation step 544.271635817909/2000
# Simulation step 545.2721360680341/2000
# Simulation step 546.2726363181591/2000
# Simulation step 547.2731365682841/2000
# Simulation step 548.2736368184093/2000
# Simulation step 549.2741370685343/2000
# Simulation step 550.2746373186594/2000
# Simulation step 551.2751375687844/2000
# Simulation step 552.2756378189094/2000
# Simulation step 553.2761380690346/2000
# Simulation step 554.2766383191596/2000
# Simulation step 555.2771385692847/2000
# Simulation step 556.2776388194097/2000
# Simulation step 557.2781390695349/2000
# Simulation step 558.2786393196599/2000
# Simulation step 559.2791395697849/2000
# Simulation step 560.27963981991/2000
# Simulation step 561.280140070035/2000
# Simulation step 562.2806403201602/2000
# Simulation step 563.2811405702852/2000
# Simulation step 564.2816408204103/2000
# Simulation step 565.2821410705353/2000
# Simulation step 566.2826413206603/2000
# Simulation step 567.2831415707855/2000
# Simulation step 568.2836418209105/2000
# Simulation step 569.2841420710356/2000
# Simulation step 570.2846423211606/2000
# Simulation step 571.2851425712856/2000
# Simulation step 572.2856428214108/2000
# Simulation step 573.2861430715358/2000
# Simulation step 574.2866433216609/2000
# Simulation step 575.2871435717859/2000
# Simulation step 576.287643821911/2000
# Simulation step 577.2881440720361/2000
# Simulation step 578.2886443221611/2000
# Simulation step 579.2891445722862/2000
# Simulation step 580.2896448224112/2000
# Simulation step 581.2901450725363/2000
# Simulation step 582.2906453226614/2000
# Simulation step 583.2911455727865/2000
# Simulation step 584.2916458229115/2000
# Simulation step 585.2921460730365/2000
# Simulation step 586.2926463231616/2000
# Simulation step 587.2931465732867/2000
# Simulation step 588.2936468234118/2000
# Simulation step 589.2941470735368/2000
# Simulation step 590.2946473236618/2000
# Simulation step 591.295147573787/2000
# Simulation step 592.295647823912/2000
# Simulation step 593.2961480740371/2000
# Simulation step 594.2966483241621/2000
# Simulation step 595.2971485742872/2000
# Simulation step 596.2976488244122/2000
# Simulation step 597.2981490745373/2000
# Simulation step 598.2986493246624/2000
# Simulation step 599.2991495747874/2000
# Simulation step 600.2996498249125/2000
# Simulation step 601.3001500750375/2000
# Simulation step 602.3006503251627/2000
# Simulation step 603.3011505752877/2000
# Simulation step 604.3016508254127/2000
# Simulation step 605.3021510755378/2000
# Simulation step 606.3026513256629/2000
# Simulation step 607.303151575788/2000
# Simulation step 608.303651825913/2000
# Simulation step 609.304152076038/2000
# Simulation step 610.3046523261631/2000
# Simulation step 611.3051525762882/2000
# Simulation step 612.3056528264133/2000
# Simulation step 613.3061530765383/2000
# Simulation step 614.3066533266634/2000
# Simulation step 615.3071535767884/2000
# Simulation step 616.3076538269135/2000
# Simulation step 617.3081540770386/2000
# Simulation step 618.3086543271636/2000
# Simulation step 619.3091545772887/2000
# Simulation step 620.3096548274137/2000
# Simulation step 621.3101550775389/2000
# Simulation step 622.3106553276639/2000
# Simulation step 623.3111555777889/2000
# Simulation step 624.311655827914/2000
# Simulation step 625.312156078039/2000
# Simulation step 626.3126563281642/2000
# Simulation step 627.3131565782892/2000
# Simulation step 628.3136568284143/2000
# Simulation step 629.3141570785393/2000
# Simulation step 630.3146573286643/2000
# Simulation step 631.3151575787895/2000
# Simulation step 632.3156578289145/2000
# Simulation step 633.3161580790396/2000
# Simulation step 634.3166583291646/2000
# Simulation step 635.3171585792896/2000
# Simulation step 636.3176588294148/2000
# Simulation step 637.3181590795398/2000
# Simulation step 638.3186593296649/2000
# Simulation step 639.3191595797899/2000
# Simulation step 640.319659829915/2000
# Simulation step 641.3201600800401/2000
# Simulation step 642.3206603301651/2000
# Simulation step 643.3211605802902/2000
# Simulation step 644.3216608304152/2000
# Simulation step 645.3221610805404/2000
# Simulation step 646.3226613306654/2000
# Simulation step 647.3231615807905/2000
# Simulation step 648.3236618309155/2000
# Simulation step 649.3241620810405/2000
# Simulation step 650.3246623311657/2000
# Simulation step 651.3251625812907/2000
# Simulation step 652.3256628314158/2000
# Simulation step 653.3261630815408/2000
# Simulation step 654.3266633316658/2000
# Simulation step 655.327163581791/2000
# Simulation step 656.327663831916/2000
# Simulation step 657.3281640820411/2000
# Simulation step 658.3286643321661/2000
# Simulation step 659.3291645822912/2000
# Simulation step 660.3296648324163/2000
# Simulation step 661.3301650825413/2000
# Simulation step 662.3306653326664/2000
# Simulation step 663.3311655827914/2000
# Simulation step 664.3316658329165/2000
# Simulation step 665.3321660830416/2000
# Simulation step 666.3326663331667/2000
# Simulation step 667.3331665832917/2000
# Simulation step 668.3336668334167/2000
# Simulation step 669.3341670835418/2000
# Simulation step 670.3346673336669/2000
# Simulation step 671.335167583792/2000
# Simulation step 672.335667833917/2000
# Simulation step 673.3361680840421/2000
# Simulation step 674.3366683341671/2000
# Simulation step 675.3371685842922/2000
# Simulation step 676.3376688344173/2000
# Simulation step 677.3381690845423/2000
# Simulation step 678.3386693346674/2000
# Simulation step 679.3391695847924/2000
# Simulation step 680.3396698349175/2000
# Simulation step 681.3401700850426/2000
# Simulation step 682.3406703351676/2000
# Simulation step 683.3411705852927/2000
# Simulation step 684.3416708354177/2000
# Simulation step 685.3421710855429/2000
# Simulation step 686.3426713356679/2000
# Simulation step 687.3431715857929/2000
# Simulation step 688.343671835918/2000
# Simulation step 689.344172086043/2000
# Simulation step 690.3446723361682/2000
# Simulation step 691.3451725862932/2000
# Simulation step 692.3456728364183/2000
# Simulation step 693.3461730865433/2000
# Simulation step 694.3466733366683/2000
# Simulation step 695.3471735867935/2000
# Simulation step 696.3476738369185/2000
# Simulation step 697.3481740870436/2000
# Simulation step 698.3486743371686/2000
# Simulation step 699.3491745872936/2000
# Simulation step 700.3496748374188/2000
# Simulation step 701.3501750875438/2000
# Simulation step 702.3506753376689/2000
# Simulation step 703.3511755877939/2000
# Simulation step 704.3516758379191/2000
# Simulation step 705.3521760880441/2000
# Simulation step 706.3526763381691/2000
# Simulation step 707.3531765882942/2000
# Simulation step 708.3536768384192/2000
# Simulation step 709.3541770885444/2000
# Simulation step 710.3546773386694/2000
# Simulation step 711.3551775887945/2000
# Simulation step 712.3556778389195/2000
# Simulation step 713.3561780890445/2000
# Simulation step 714.3566783391697/2000
# Simulation step 715.3571785892947/2000
# Simulation step 716.3576788394198/2000
# Simulation step 717.3581790895448/2000
# Simulation step 718.3586793396698/2000
# Simulation step 719.359179589795/2000
# Simulation step 720.35967983992/2000
# Simulation step 721.3601800900451/2000
# Simulation step 722.3606803401701/2000
# Simulation step 723.3611805902952/2000
# Simulation step 724.3616808404203/2000
# Simulation step 725.3621810905453/2000
# Simulation step 726.3626813406704/2000
# Simulation step 727.3631815907954/2000
# Simulation step 728.3636818409205/2000
# Simulation step 729.3641820910456/2000
# Simulation step 730.3646823411707/2000
# Simulation step 731.3651825912957/2000
# Simulation step 732.3656828414207/2000
# Simulation step 733.3661830915458/2000
# Simulation step 734.3666833416709/2000
# Simulation step 735.367183591796/2000
# Simulation step 736.367683841921/2000
# Simulation step 737.368184092046/2000
# Simulation step 738.3686843421712/2000
# Simulation step 739.3691845922962/2000
# Simulation step 740.3696848424213/2000
# Simulation step 741.3701850925463/2000
# Simulation step 742.3706853426714/2000
# Simulation step 743.3711855927965/2000
# Simulation step 744.3716858429215/2000
# Simulation step 745.3721860930466/2000
# Simulation step 746.3726863431716/2000
# Simulation step 747.3731865932967/2000
# Simulation step 748.3736868434218/2000
# Simulation step 749.3741870935469/2000
# Simulation step 750.3746873436719/2000
# Simulation step 751.3751875937969/2000
# Simulation step 752.375687843922/2000
# Simulation step 753.376188094047/2000
# Simulation step 754.3766883441722/2000
# Simulation step 755.3771885942972/2000
# Simulation step 756.3776888444223/2000
# Simulation step 757.3781890945473/2000
# Simulation step 758.3786893446724/2000
# Simulation step 759.3791895947975/2000
# Simulation step 760.3796898449225/2000
# Simulation step 761.3801900950476/2000
# Simulation step 762.3806903451726/2000
# Simulation step 763.3811905952977/2000
# Simulation step 764.3816908454228/2000
# Simulation step 765.3821910955478/2000
# Simulation step 766.3826913456729/2000
# Simulation step 767.3831915957979/2000
# Simulation step 768.3836918459231/2000
# Simulation step 769.3841920960481/2000
# Simulation step 770.3846923461731/2000
# Simulation step 771.3851925962982/2000
# Simulation step 772.3856928464232/2000
# Simulation step 773.3861930965484/2000
# Simulation step 774.3866933466734/2000
# Simulation step 775.3871935967985/2000
# Simulation step 776.3876938469235/2000
# Simulation step 777.3881940970485/2000
# Simulation step 778.3886943471737/2000
# Simulation step 779.3891945972987/2000
# Simulation step 780.3896948474238/2000
# Simulation step 781.3901950975488/2000
# Simulation step 782.3906953476738/2000
# Simulation step 783.391195597799/2000
# Simulation step 784.391695847924/2000
# Simulation step 785.3921960980491/2000
# Simulation step 786.3926963481741/2000
# Simulation step 787.3931965982993/2000
# Simulation step 788.3936968484243/2000
# Simulation step 789.3941970985493/2000
# Simulation step 790.3946973486744/2000
# Simulation step 791.3951975987994/2000
# Simulation step 792.3956978489246/2000
# Simulation step 793.3961980990496/2000
# Simulation step 794.3966983491747/2000
# Simulation step 795.3971985992997/2000
# Simulation step 796.3976988494247/2000
# Simulation step 797.3981990995499/2000
# Simulation step 798.3986993496749/2000
# Simulation step 799.3991995998/2000
# Simulation step 800.399699849925/2000
# Simulation step 801.4002001000501/2000
# Simulation step 802.4007003501752/2000
# Simulation step 803.4012006003002/2000
# Simulation step 804.4017008504253/2000
# Simulation step 805.4022011005503/2000
# Simulation step 806.4027013506754/2000
# Simulation step 807.4032016008005/2000
# Simulation step 808.4037018509255/2000
# Simulation step 809.4042021010506/2000
# Simulation step 810.4047023511756/2000
# Simulation step 811.4052026013007/2000
# Simulation step 812.4057028514258/2000
# Simulation step 813.4062031015509/2000
# Simulation step 814.4067033516759/2000
# Simulation step 815.4072036018009/2000
# Simulation step 816.407703851926/2000
# Simulation step 817.4082041020511/2000
# Simulation step 818.4087043521762/2000
# Simulation step 819.4092046023012/2000
# Simulation step 820.4097048524263/2000
# Simulation step 821.4102051025513/2000
# Simulation step 822.4107053526764/2000
# Simulation step 823.4112056028015/2000
# Simulation step 824.4117058529265/2000
# Simulation step 825.4122061030516/2000
# Simulation step 826.4127063531766/2000
# Simulation step 827.4132066033017/2000
# Simulation step 828.4137068534268/2000
# Simulation step 829.4142071035518/2000
# Simulation step 830.4147073536769/2000
# Simulation step 831.415207603802/2000
# Simulation step 832.4157078539271/2000
# Simulation step 833.4162081040521/2000
# Simulation step 834.4167083541771/2000
# Simulation step 835.4172086043022/2000
# Simulation step 836.4177088544272/2000
# Simulation step 837.4182091045524/2000
# Simulation step 838.4187093546774/2000
# Simulation step 839.4192096048025/2000
# Simulation step 840.4197098549275/2000
# Simulation step 841.4202101050525/2000
# Simulation step 842.4207103551777/2000
# Simulation step 843.4212106053027/2000
# Simulation step 844.4217108554278/2000
# Simulation step 845.4222111055528/2000
# Simulation step 846.4227113556778/2000
# Simulation step 847.423211605803/2000
# Simulation step 848.423711855928/2000
# Simulation step 849.4242121060531/2000
# Simulation step 850.4247123561781/2000
# Simulation step 851.4252126063033/2000
# Simulation step 852.4257128564283/2000
# Simulation step 853.4262131065533/2000
# Simulation step 854.4267133566784/2000
# Simulation step 855.4272136068034/2000
# Simulation step 856.4277138569286/2000
# Simulation step 857.4282141070536/2000
# Simulation step 858.4287143571787/2000
# Simulation step 859.4292146073037/2000
# Simulation step 860.4297148574287/2000
# Simulation step 861.4302151075539/2000
# Simulation step 862.4307153576789/2000
# Simulation step 863.431215607804/2000
# Simulation step 864.431715857929/2000
# Simulation step 865.432216108054/2000
# Simulation step 866.4327163581792/2000
# Simulation step 867.4332166083042/2000
# Simulation step 868.4337168584293/2000
# Simulation step 869.4342171085543/2000
# Simulation step 870.4347173586794/2000
# Simulation step 871.4352176088045/2000
# Simulation step 872.4357178589295/2000
# Simulation step 873.4362181090546/2000
# Simulation step 874.4367183591796/2000
# Simulation step 875.4372186093048/2000
# Simulation step 876.4377188594298/2000
# Simulation step 877.4382191095549/2000
# Simulation step 878.4387193596799/2000
# Simulation step 879.4392196098049/2000
# Simulation step 880.43971985993/2000
# Simulation step 881.4402201100551/2000
# Simulation step 882.4407203601802/2000
# Simulation step 883.4412206103052/2000
# Simulation step 884.4417208604303/2000
# Simulation step 885.4422211105554/2000
# Simulation step 886.4427213606804/2000
# Simulation step 887.4432216108055/2000
# Simulation step 888.4437218609305/2000
# Simulation step 889.4442221110556/2000
# Simulation step 890.4447223611807/2000
# Simulation step 891.4452226113057/2000
# Simulation step 892.4457228614308/2000
# Simulation step 893.4462231115558/2000
# Simulation step 894.4467233616809/2000
# Simulation step 895.447223611806/2000
# Simulation step 896.4477238619311/2000
# Simulation step 897.4482241120561/2000
# Simulation step 898.4487243621811/2000
# Simulation step 899.4492246123062/2000
# Simulation step 900.4497248624313/2000
# Simulation step 901.4502251125564/2000
# Simulation step 902.4507253626814/2000
# Simulation step 903.4512256128065/2000
# Simulation step 904.4517258629315/2000
# Simulation step 905.4522261130566/2000
# Simulation step 906.4527263631817/2000
# Simulation step 907.4532266133067/2000
# Simulation step 908.4537268634318/2000
# Simulation step 909.4542271135568/2000
# Simulation step 910.4547273636819/2000
# Simulation step 911.455227613807/2000
# Simulation step 912.455727863932/2000
# Simulation step 913.4562281140571/2000
# Simulation step 914.4567283641821/2000
# Simulation step 915.4572286143073/2000
# Simulation step 916.4577288644323/2000
# Simulation step 917.4582291145573/2000
# Simulation step 918.4587293646824/2000
# Simulation step 919.4592296148074/2000
# Simulation step 920.4597298649326/2000
# Simulation step 921.4602301150576/2000
# Simulation step 922.4607303651827/2000
# Simulation step 923.4612306153077/2000
# Simulation step 924.4617308654327/2000
# Simulation step 925.4622311155579/2000
# Simulation step 926.4627313656829/2000
# Simulation step 927.463231615808/2000
# Simulation step 928.463731865933/2000
# Simulation step 929.4642321160582/2000
# Simulation step 930.4647323661832/2000
# Simulation step 931.4652326163082/2000
# Simulation step 932.4657328664333/2000
# Simulation step 933.4662331165583/2000
# Simulation step 934.4667333666835/2000
# Simulation step 935.4672336168085/2000
# Simulation step 936.4677338669335/2000
# Simulation step 937.4682341170586/2000
# Simulation step 938.4687343671836/2000
# Simulation step 939.4692346173088/2000
# Simulation step 940.4697348674338/2000
# Simulation step 941.4702351175589/2000
# Simulation step 942.4707353676839/2000
# Simulation step 943.4712356178089/2000
# Simulation step 944.4717358679341/2000
# Simulation step 945.4722361180591/2000
# Simulation step 946.4727363681842/2000
# Simulation step 947.4732366183092/2000
# Simulation step 948.4737368684343/2000
# Simulation step 949.4742371185594/2000
# Simulation step 950.4747373686844/2000
# Simulation step 951.4752376188095/2000
# Simulation step 952.4757378689345/2000
# Simulation step 953.4762381190596/2000
# Simulation step 954.4767383691847/2000
# Simulation step 955.4772386193097/2000
# Simulation step 956.4777388694348/2000
# Simulation step 957.4782391195598/2000
# Simulation step 958.478739369685/2000
# Simulation step 959.47923961981/2000
# Simulation step 960.4797398699351/2000
# Simulation step 961.4802401200601/2000
# Simulation step 962.4807403701851/2000
# Simulation step 963.4812406203102/2000
# Simulation step 964.4817408704353/2000
# Simulation step 965.4822411205604/2000
# Simulation step 966.4827413706854/2000
# Simulation step 967.4832416208105/2000
# Simulation step 968.4837418709355/2000
# Simulation step 969.4842421210606/2000
# Simulation step 970.4847423711857/2000
# Simulation step 971.4852426213107/2000
# Simulation step 972.4857428714358/2000
# Simulation step 973.4862431215608/2000
# Simulation step 974.4867433716859/2000
# Simulation step 975.487243621811/2000
# Simulation step 976.487743871936/2000
# Simulation step 977.4882441220611/2000
# Simulation step 978.4887443721861/2000
# Simulation step 979.4892446223113/2000
# Simulation step 980.4897448724363/2000
# Simulation step 981.4902451225613/2000
# Simulation step 982.4907453726864/2000
# Simulation step 983.4912456228114/2000
# Simulation step 984.4917458729366/2000
# Simulation step 985.4922461230616/2000
# Simulation step 986.4927463731867/2000
# Simulation step 987.4932466233117/2000
# Simulation step 988.4937468734367/2000
# Simulation step 989.4942471235619/2000
# Simulation step 990.4947473736869/2000
# Simulation step 991.495247623812/2000
# Simulation step 992.495747873937/2000
# Simulation step 993.496248124062/2000
# Simulation step 994.4967483741872/2000
# Simulation step 995.4972486243122/2000
# Simulation step 996.4977488744373/2000
# Simulation step 997.4982491245623/2000
# Simulation step 998.4987493746875/2000
# Simulation step 999.4992496248125/2000
# Simulation step 1000.4997498749375/2000
# Simulation step 1001.5002501250626/2000
# Simulation step 1002.5007503751876/2000
# Simulation step 1003.5012506253128/2000
# Simulation step 1004.5017508754378/2000
# Simulation step 1005.5022511255629/2000
# Simulation step 1006.5027513756879/2000
# Simulation step 1007.5032516258129/2000
# Simulation step 1008.5037518759381/2000
# Simulation step 1009.5042521260631/2000
# Simulation step 1010.5047523761882/2000
# Simulation step 1011.5052526263132/2000
# Simulation step 1012.5057528764384/2000
# Simulation step 1013.5062531265634/2000
# Simulation step 1014.5067533766884/2000
# Simulation step 1015.5072536268135/2000
# Simulation step 1016.5077538769385/2000
# Simulation step 1017.5082541270637/2000
# Simulation step 1018.5087543771887/2000
# Simulation step 1019.5092546273137/2000
# Simulation step 1020.5097548774388/2000
# Simulation step 1021.5102551275638/2000
# Simulation step 1022.510755377689/2000
# Simulation step 1023.511255627814/2000
# Simulation step 1024.511755877939/2000
# Simulation step 1025.512256128064/2000
# Simulation step 1026.5127563781891/2000
# Simulation step 1027.5132566283141/2000
# Simulation step 1028.5137568784394/2000
# Simulation step 1029.5142571285644/2000
# Simulation step 1030.5147573786894/2000
# Simulation step 1031.5152576288144/2000
# Simulation step 1032.5157578789394/2000
# Simulation step 1033.5162581290647/2000
# Simulation step 1034.5167583791897/2000
# Simulation step 1035.5172586293147/2000
# Simulation step 1036.5177588794397/2000
# Simulation step 1037.518259129565/2000
# Simulation step 1038.51875937969/2000
# Simulation step 1039.519259629815/2000
# Simulation step 1040.51975987994/2000
# Simulation step 1041.520260130065/2000
# Simulation step 1042.5207603801903/2000
# Simulation step 1043.5212606303153/2000
# Simulation step 1044.5217608804403/2000
# Simulation step 1045.5222611305653/2000
# Simulation step 1046.5227613806903/2000
# Simulation step 1047.5232616308156/2000
# Simulation step 1048.5237618809406/2000
# Simulation step 1049.5242621310656/2000
# Simulation step 1050.5247623811906/2000
# Simulation step 1051.5252626313156/2000
# Simulation step 1052.5257628814409/2000
# Simulation step 1053.5262631315659/2000
# Simulation step 1054.526763381691/2000
# Simulation step 1055.527263631816/2000
# Simulation step 1056.5277638819412/2000
# Simulation step 1057.5282641320662/2000
# Simulation step 1058.5287643821912/2000
# Simulation step 1059.5292646323162/2000
# Simulation step 1060.5297648824412/2000
# Simulation step 1061.5302651325665/2000
# Simulation step 1062.5307653826915/2000
# Simulation step 1063.5312656328165/2000
# Simulation step 1064.5317658829415/2000
# Simulation step 1065.5322661330665/2000
# Simulation step 1066.5327663831918/2000
# Simulation step 1067.5332666333168/2000
# Simulation step 1068.5337668834418/2000
# Simulation step 1069.5342671335668/2000
# Simulation step 1070.5347673836918/2000
# Simulation step 1071.535267633817/2000
# Simulation step 1072.535767883942/2000
# Simulation step 1073.536268134067/2000
# Simulation step 1074.536768384192/2000
# Simulation step 1075.5372686343173/2000
# Simulation step 1076.5377688844424/2000
# Simulation step 1077.5382691345674/2000
# Simulation step 1078.5387693846924/2000
# Simulation step 1079.5392696348174/2000
# Simulation step 1080.5397698849426/2000
# Simulation step 1081.5402701350677/2000
# Simulation step 1082.5407703851927/2000
# Simulation step 1083.5412706353177/2000
# Simulation step 1084.5417708854427/2000
# Simulation step 1085.542271135568/2000
# Simulation step 1086.542771385693/2000
# Simulation step 1087.543271635818/2000
# Simulation step 1088.543771885943/2000
# Simulation step 1089.5442721360682/2000
# Simulation step 1090.5447723861932/2000
# Simulation step 1091.5452726363183/2000
# Simulation step 1092.5457728864433/2000
# Simulation step 1093.5462731365683/2000
# Simulation step 1094.5467733866935/2000
# Simulation step 1095.5472736368185/2000
# Simulation step 1096.5477738869436/2000
# Simulation step 1097.5482741370686/2000
# Simulation step 1098.5487743871936/2000
# Simulation step 1099.5492746373188/2000
# Simulation step 1100.5497748874438/2000
# Simulation step 1101.5502751375689/2000
# Simulation step 1102.5507753876939/2000
# Simulation step 1103.551275637819/2000
# Simulation step 1104.5517758879441/2000
# Simulation step 1105.5522761380691/2000
# Simulation step 1106.5527763881942/2000
# Simulation step 1107.5532766383192/2000
# Simulation step 1108.5537768884444/2000
# Simulation step 1109.5542771385694/2000
# Simulation step 1110.5547773886944/2000
# Simulation step 1111.5552776388195/2000
# Simulation step 1112.5557778889445/2000
# Simulation step 1113.5562781390697/2000
# Simulation step 1114.5567783891947/2000
# Simulation step 1115.5572786393197/2000
# Simulation step 1116.5577788894448/2000
# Simulation step 1117.5582791395698/2000
# Simulation step 1118.558779389695/2000
# Simulation step 1119.55927963982/2000
# Simulation step 1120.559779889945/2000
# Simulation step 1121.56028014007/2000
# Simulation step 1122.560780390195/2000
# Simulation step 1123.5612806403203/2000
# Simulation step 1124.5617808904453/2000
# Simulation step 1125.5622811405703/2000
# Simulation step 1126.5627813906954/2000
# Simulation step 1127.5632816408206/2000
# Simulation step 1128.5637818909456/2000
# Simulation step 1129.5642821410706/2000
# Simulation step 1130.5647823911956/2000
# Simulation step 1131.5652826413207/2000
# Simulation step 1132.565782891446/2000
# Simulation step 1133.566283141571/2000
# Simulation step 1134.566783391696/2000
# Simulation step 1135.567283641821/2000
# Simulation step 1136.567783891946/2000
# Simulation step 1137.5682841420712/2000
# Simulation step 1138.5687843921962/2000
# Simulation step 1139.5692846423212/2000
# Simulation step 1140.5697848924463/2000
# Simulation step 1141.5702851425713/2000
# Simulation step 1142.5707853926965/2000
# Simulation step 1143.5712856428215/2000
# Simulation step 1144.5717858929465/2000
# Simulation step 1145.5722861430716/2000
# Simulation step 1146.5727863931968/2000
# Simulation step 1147.5732866433218/2000
# Simulation step 1148.5737868934468/2000
# Simulation step 1149.5742871435718/2000
# Simulation step 1150.5747873936969/2000
# Simulation step 1151.575287643822/2000
# Simulation step 1152.575787893947/2000
# Simulation step 1153.5762881440721/2000
# Simulation step 1154.5767883941971/2000
# Simulation step 1155.5772886443222/2000
# Simulation step 1156.5777888944474/2000
# Simulation step 1157.5782891445724/2000
# Simulation step 1158.5787893946974/2000
# Simulation step 1159.5792896448224/2000
# Simulation step 1160.5797898949475/2000
# Simulation step 1161.5802901450727/2000
# Simulation step 1162.5807903951977/2000
# Simulation step 1163.5812906453227/2000
# Simulation step 1164.5817908954477/2000
# Simulation step 1165.582291145573/2000
# Simulation step 1166.582791395698/2000
# Simulation step 1167.583291645823/2000
# Simulation step 1168.583791895948/2000
# Simulation step 1169.584292146073/2000
# Simulation step 1170.5847923961983/2000
# Simulation step 1171.5852926463233/2000
# Simulation step 1172.5857928964483/2000
# Simulation step 1173.5862931465733/2000
# Simulation step 1174.5867933966983/2000
# Simulation step 1175.5872936468236/2000
# Simulation step 1176.5877938969486/2000
# Simulation step 1177.5882941470736/2000
# Simulation step 1178.5887943971986/2000
# Simulation step 1179.5892946473236/2000
# Simulation step 1180.5897948974489/2000
# Simulation step 1181.590295147574/2000
# Simulation step 1182.590795397699/2000
# Simulation step 1183.591295647824/2000
# Simulation step 1184.5917958979492/2000
# Simulation step 1185.5922961480742/2000
# Simulation step 1186.5927963981992/2000
# Simulation step 1187.5932966483242/2000
# Simulation step 1188.5937968984492/2000
# Simulation step 1189.5942971485745/2000
# Simulation step 1190.5947973986995/2000
# Simulation step 1191.5952976488245/2000
# Simulation step 1192.5957978989495/2000
# Simulation step 1193.5962981490745/2000
# Simulation step 1194.5967983991998/2000
# Simulation step 1195.5972986493248/2000
# Simulation step 1196.5977988994498/2000
# Simulation step 1197.5982991495748/2000
# Simulation step 1198.5987993996998/2000
# Simulation step 1199.599299649825/2000
# Simulation step 1200.59979989995/2000
# Simulation step 1201.600300150075/2000
# Simulation step 1202.6008004002001/2000
# Simulation step 1203.6013006503254/2000
# Simulation step 1204.6018009004504/2000
# Simulation step 1205.6023011505754/2000
# Simulation step 1206.6028014007004/2000
# Simulation step 1207.6033016508254/2000
# Simulation step 1208.6038019009507/2000
# Simulation step 1209.6043021510757/2000
# Simulation step 1210.6048024012007/2000
# Simulation step 1211.6053026513257/2000
# Simulation step 1212.6058029014507/2000
# Simulation step 1213.606303151576/2000
# Simulation step 1214.606803401701/2000
# Simulation step 1215.607303651826/2000
# Simulation step 1216.607803901951/2000
# Simulation step 1217.608304152076/2000
# Simulation step 1218.6088044022013/2000
# Simulation step 1219.6093046523263/2000
# Simulation step 1220.6098049024513/2000
# Simulation step 1221.6103051525763/2000
# Simulation step 1222.6108054027015/2000
# ...
# Simulation step 1601.8004002001003/2000
# Simulation step 1602.8009004502253/2000
# Simulation step 1603.8014007003503/2000
# Simulation step 1604.8019009504753/2000
# Simulation step 1605.8024012006003/2000
# Simulation step 1606.8029014507256/2000
# Simulation step 1607.8034017008506/2000
# Simulation step 1608.8039019509756/2000
# Simulation step 1609.8044022011006/2000
# Simulation step 1610.8049024512256/2000
# Simulation step 1611.8054027013509/2000
# Simulation step 1612.805902951476/2000
# Simulation step 1613.806403201601/2000
# Simulation step 1614.806903451726/2000
# Simulation step 1615.807403701851/2000
# Simulation step 1616.8079039519762/2000
# Simulation step 1617.8084042021012/2000
# Simulation step 1618.8089044522262/2000
# Simulation step 1619.8094047023512/2000
# Simulation step 1620.8099049524765/2000
# Simulation step 1621.8104052026015/2000
# Simulation step 1622.8109054527265/2000
# Simulation step 1623.8114057028515/2000
# Simulation step 1624.8119059529765/2000
# Simulation step 1625.8124062031018/2000
# Simulation step 1626.8129064532268/2000
# Simulation step 1627.8134067033518/2000
# Simulation step 1628.8139069534768/2000
# Simulation step 1629.8144072036018/2000
# Simulation step 1630.814907453727/2000
# Simulation step 1631.815407703852/2000
# Simulation step 1632.815907953977/2000
# Simulation step 1633.8164082041021/2000
# Simulation step 1634.8169084542271/2000
# Simulation step 1635.8174087043524/2000
# Simulation step 1636.8179089544774/2000
# Simulation step 1637.8184092046024/2000
# Simulation step 1638.8189094547274/2000
# Simulation step 1639.8194097048527/2000
# Simulation step 1640.8199099549777/2000
# Simulation step 1641.8204102051027/2000
# Simulation step 1642.8209104552277/2000
# Simulation step 1643.8214107053527/2000
# Simulation step 1644.821910955478/2000
# Simulation step 1645.822411205603/2000
# Simulation step 1646.822911455728/2000
# Simulation step 1647.823411705853/2000
# Simulation step 1648.823911955978/2000
# Simulation step 1649.8244122061033/2000
# Simulation step 1650.8249124562283/2000
# Simulation step 1651.8254127063533/2000
# Simulation step 1652.8259129564783/2000
# Simulation step 1653.8264132066033/2000
# Simulation step 1654.8269134567286/2000
# Simulation step 1655.8274137068536/2000
# Simulation step 1656.8279139569786/2000
# Simulation step 1657.8284142071036/2000
# Simulation step 1658.8289144572288/2000
# Simulation step 1659.8294147073539/2000
# Simulation step 1660.8299149574789/2000
# Simulation step 1661.830415207604/2000
# Simulation step 1662.830915457729/2000
# Simulation step 1663.8314157078541/2000
# Simulation step 1664.8319159579792/2000
# Simulation step 1665.8324162081042/2000
# Simulation step 1666.8329164582292/2000
# Simulation step 1667.8334167083542/2000
# Simulation step 1668.8339169584794/2000
# Simulation step 1669.8344172086045/2000
# Simulation step 1670.8349174587295/2000
# Simulation step 1671.8354177088545/2000
# Simulation step 1672.8359179589795/2000
# Simulation step 1673.8364182091047/2000
# Simulation step 1674.8369184592298/2000
# Simulation step 1675.8374187093548/2000
# Simulation step 1676.8379189594798/2000
# Simulation step 1677.838419209605/2000
# Simulation step 1678.83891945973/2000
# Simulation step 1679.839419709855/2000
# Simulation step 1680.83991995998/2000
# Simulation step 1681.840420210105/2000
# Simulation step 1682.8409204602303/2000
# Simulation step 1683.8414207103554/2000
# Simulation step 1684.8419209604804/2000
# Simulation step 1685.8424212106054/2000
# Simulation step 1686.8429214607304/2000
# Simulation step 1687.8434217108556/2000
# Simulation step 1688.8439219609807/2000
# Simulation step 1689.8444222111057/2000
# Simulation step 1690.8449224612307/2000
# Simulation step 1691.8454227113557/2000
# Simulation step 1692.845922961481/2000
# Simulation step 1693.846423211606/2000
# Simulation step 1694.846923461731/2000
# Simulation step 1695.847423711856/2000
# Simulation step 1696.8479239619812/2000
# Simulation step 1697.8484242121062/2000
# Simulation step 1698.8489244622313/2000
# Simulation step 1699.8494247123563/2000
# Simulation step 1700.8499249624813/2000
# Simulation step 1701.8504252126065/2000
# Simulation step 1702.8509254627315/2000
# Simulation step 1703.8514257128566/2000
# Simulation step 1704.8519259629816/2000
# Simulation step 1705.8524262131066/2000
# Simulation step 1706.8529264632318/2000
# Simulation step 1707.8534267133568/2000
# Simulation step 1708.8539269634819/2000
# Simulation step 1709.8544272136069/2000
# Simulation step 1710.8549274637319/2000
# Simulation step 1711.8554277138571/2000
# Simulation step 1712.8559279639821/2000
# Simulation step 1713.8564282141072/2000
# Simulation step 1714.8569284642322/2000
# Simulation step 1715.8574287143574/2000
# Simulation step 1716.8579289644824/2000
# Simulation step 1717.8584292146074/2000
# Simulation step 1718.8589294647325/2000
# Simulation step 1719.8594297148575/2000
# Simulation step 1720.8599299649827/2000
# Simulation step 1721.8604302151077/2000
# Simulation step 1722.8609304652327/2000
# Simulation step 1723.8614307153578/2000
# Simulation step 1724.8619309654828/2000
# Simulation step 1725.862431215608/2000
# Simulation step 1726.862931465733/2000
# Simulation step 1727.863431715858/2000
# Simulation step 1728.863931965983/2000
# Simulation step 1729.864432216108/2000
# Simulation step 1730.8649324662333/2000
# Simulation step 1731.8654327163583/2000
# Simulation step 1732.8659329664833/2000
# Simulation step 1733.8664332166084/2000
# Simulation step 1734.8669334667336/2000
# Simulation step 1735.8674337168586/2000
# Simulation step 1736.8679339669836/2000
# Simulation step 1737.8684342171086/2000
# Simulation step 1738.8689344672337/2000
# Simulation step 1739.869434717359/2000
# Simulation step 1740.869934967484/2000
# Simulation step 1741.870435217609/2000
# Simulation step 1742.870935467734/2000
# Simulation step 1743.871435717859/2000
# Simulation step 1744.8719359679842/2000
# Simulation step 1745.8724362181092/2000
# Simulation step 1746.8729364682342/2000
# Simulation step 1747.8734367183592/2000
# Simulation step 1748.8739369684845/2000
# Simulation step 1749.8744372186095/2000
# Simulation step 1750.8749374687345/2000
# Simulation step 1751.8754377188595/2000
# Simulation step 1752.8759379689845/2000
# Simulation step 1753.8764382191098/2000
# Simulation step 1754.8769384692348/2000
# Simulation step 1755.8774387193598/2000
# Simulation step 1756.8779389694848/2000
# Simulation step 1757.8784392196098/2000
# Simulation step 1758.878939469735/2000
# Simulation step 1759.87943971986/2000
# Simulation step 1760.8799399699851/2000
# Simulation step 1761.8804402201101/2000
# Simulation step 1762.8809404702351/2000
# Simulation step 1763.8814407203604/2000
# Simulation step 1764.8819409704854/2000
# Simulation step 1765.8824412206104/2000
# Simulation step 1766.8829414707354/2000
# Simulation step 1767.8834417208607/2000
# Simulation step 1768.8839419709857/2000
# Simulation step 1769.8844422211107/2000
# Simulation step 1770.8849424712357/2000
# Simulation step 1771.8854427213607/2000
# Simulation step 1772.885942971486/2000
# Simulation step 1773.886443221611/2000
# Simulation step 1774.886943471736/2000
# Simulation step 1775.887443721861/2000
# Simulation step 1776.887943971986/2000
# Simulation step 1777.8884442221113/2000
# Simulation step 1778.8889444722363/2000
# Simulation step 1779.8894447223613/2000
# Simulation step 1780.8899449724863/2000
# Simulation step 1781.8904452226113/2000
# Simulation step 1782.8909454727366/2000
# Simulation step 1783.8914457228616/2000
# Simulation step 1784.8919459729866/2000
# Simulation step 1785.8924462231116/2000
# Simulation step 1786.8929464732369/2000
# Simulation step 1787.8934467233619/2000
# Simulation step 1788.893946973487/2000
# Simulation step 1789.894447223612/2000
# Simulation step 1790.894947473737/2000
# Simulation step 1791.8954477238622/2000
# Simulation step 1792.8959479739872/2000
# Simulation step 1793.8964482241122/2000
# Simulation step 1794.8969484742372/2000
# Simulation step 1795.8974487243622/2000
# Simulation step 1796.8979489744875/2000
# Simulation step 1797.8984492246125/2000
# Simulation step 1798.8989494747375/2000
# Simulation step 1799.8994497248625/2000
# Simulation step 1800.8999499749875/2000
# Simulation step 1801.9004502251128/2000
# Simulation step 1802.9009504752378/2000
# Simulation step 1803.9014507253628/2000
# Simulation step 1804.9019509754878/2000
# Simulation step 1805.902451225613/2000
# Simulation step 1806.902951475738/2000
# Simulation step 1807.903451725863/2000
# Simulation step 1808.903951975988/2000
# Simulation step 1809.904452226113/2000
# Simulation step 1810.9049524762383/2000
# Simulation step 1811.9054527263634/2000
# Simulation step 1812.9059529764884/2000
# Simulation step 1813.9064532266134/2000
# Simulation step 1814.9069534767384/2000
# Simulation step 1815.9074537268637/2000
# Simulation step 1816.9079539769887/2000
# Simulation step 1817.9084542271137/2000
# Simulation step 1818.9089544772387/2000
# Simulation step 1819.9094547273637/2000
# Simulation step 1820.909954977489/2000
# Simulation step 1821.910455227614/2000
# Simulation step 1822.910955477739/2000
# Simulation step 1823.911455727864/2000
# Simulation step 1824.9119559779892/2000
# Simulation step 1825.9124562281143/2000
# Simulation step 1826.9129564782393/2000
# Simulation step 1827.9134567283643/2000
# Simulation step 1828.9139569784893/2000
# Simulation step 1829.9144572286145/2000
# Simulation step 1830.9149574787396/2000
# Simulation step 1831.9154577288646/2000
# Simulation step 1832.9159579789896/2000
# Simulation step 1833.9164582291146/2000
# Simulation step 1834.9169584792398/2000
# Simulation step 1835.9174587293649/2000
# Simulation step 1836.9179589794899/2000
# Simulation step 1837.9184592296149/2000
# Simulation step 1838.91895947974/2000
# Simulation step 1839.9194597298651/2000
# Simulation step 1840.9199599799902/2000
# Simulation step 1841.9204602301152/2000
# Simulation step 1842.9209604802402/2000
# Simulation step 1843.9214607303654/2000
# Simulation step 1844.9219609804904/2000
# Simulation step 1845.9224612306155/2000
# Simulation step 1846.9229614807405/2000
# Simulation step 1847.9234617308655/2000
# Simulation step 1848.9239619809907/2000
# Simulation step 1849.9244622311157/2000
# Simulation step 1850.9249624812408/2000
# Simulation step 1851.9254627313658/2000
# Simulation step 1852.9259629814908/2000
# Simulation step 1853.926463231616/2000
# Simulation step 1854.926963481741/2000
# Simulation step 1855.927463731866/2000
# Simulation step 1856.927963981991/2000
# Simulation step 1857.9284642321163/2000
# Simulation step 1858.9289644822413/2000
# Simulation step 1859.9294647323663/2000
# Simulation step 1860.9299649824914/2000
# Simulation step 1861.9304652326164/2000
# Simulation step 1862.9309654827416/2000
# Simulation step 1863.9314657328666/2000
# Simulation step 1864.9319659829916/2000
# Simulation step 1865.9324662331167/2000
# Simulation step 1866.9329664832417/2000
# Simulation step 1867.933466733367/2000
# Simulation step 1868.933966983492/2000
# Simulation step 1869.934467233617/2000
# Simulation step 1870.934967483742/2000
# Simulation step 1871.935467733867/2000
# Simulation step 1872.9359679839922/2000
# Simulation step 1873.9364682341172/2000
# Simulation step 1874.9369684842422/2000
# Simulation step 1875.9374687343673/2000
# Simulation step 1876.9379689844925/2000
# Simulation step 1877.9384692346175/2000
# Simulation step 1878.9389694847425/2000
# Simulation step 1879.9394697348675/2000
# Simulation step 1880.9399699849926/2000
# Simulation step 1881.9404702351178/2000
# Simulation step 1882.9409704852428/2000
# Simulation step 1883.9414707353678/2000
# Simulation step 1884.9419709854928/2000
# Simulation step 1885.9424712356179/2000
# Simulation step 1886.942971485743/2000
# Simulation step 1887.9434717358681/2000
# Simulation step 1888.9439719859931/2000
# Simulation step 1889.9444722361181/2000
# Simulation step 1890.9449724862432/2000
# Simulation step 1891.9454727363684/2000
# Simulation step 1892.9459729864934/2000
# Simulation step 1893.9464732366184/2000
# Simulation step 1894.9469734867434/2000
# Simulation step 1895.9474737368687/2000
# Simulation step 1896.9479739869937/2000
# Simulation step 1897.9484742371187/2000
# Simulation step 1898.9489744872437/2000
# Simulation step 1899.9494747373687/2000
# Simulation step 1900.949974987494/2000
# Simulation step 1901.950475237619/2000
# Simulation step 1902.950975487744/2000
# Simulation step 1903.951475737869/2000
# Simulation step 1904.951975987994/2000
# Simulation step 1905.9524762381193/2000
# Simulation step 1906.9529764882443/2000
# Simulation step 1907.9534767383693/2000
# Simulation step 1908.9539769884943/2000
# Simulation step 1909.9544772386193/2000
# Simulation step 1910.9549774887446/2000
# Simulation step 1911.9554777388696/2000
# Simulation step 1912.9559779889946/2000
# Simulation step 1913.9564782391196/2000
# Simulation step 1914.9569784892449/2000
# Simulation step 1915.95747873937/2000
# Simulation step 1916.957978989495/2000
# Simulation step 1917.95847923962/2000
# Simulation step 1918.958979489745/2000
# Simulation step 1919.9594797398702/2000
# Simulation step 1920.9599799899952/2000
# Simulation step 1921.9604802401202/2000
# Simulation step 1922.9609804902452/2000
# Simulation step 1923.9614807403702/2000
# Simulation step 1924.9619809904955/2000
# Simulation step 1925.9624812406205/2000
# Simulation step 1926.9629814907455/2000
# Simulation step 1927.9634817408705/2000
# Simulation step 1928.9639819909955/2000
# Simulation step 1929.9644822411208/2000
# Simulation step 1930.9649824912458/2000
# Simulation step 1931.9654827413708/2000
# Simulation step 1932.9659829914958/2000
# Simulation step 1933.966483241621/2000
# Simulation step 1934.966983491746/2000
# Simulation step 1935.967483741871/2000
# Simulation step 1936.967983991996/2000
# Simulation step 1937.9684842421211/2000
# Simulation step 1938.9689844922464/2000
# Simulation step 1939.9694847423714/2000
# Simulation step 1940.9699849924964/2000
# Simulation step 1941.9704852426214/2000
# Simulation step 1942.9709854927464/2000
# Simulation step 1943.9714857428717/2000
# Simulation step 1944.9719859929967/2000
# Simulation step 1945.9724862431217/2000
# Simulation step 1946.9729864932467/2000
# Simulation step 1947.9734867433717/2000
# Simulation step 1948.973986993497/2000
# Simulation step 1949.974487243622/2000
# Simulation step 1950.974987493747/2000
# Simulation step 1951.975487743872/2000
# Simulation step 1952.9759879939973/2000
# Simulation step 1953.9764882441223/2000
# Simulation step 1954.9769884942473/2000
# Simulation step 1955.9774887443723/2000
# Simulation step 1956.9779889944973/2000
# Simulation step 1957.9784892446226/2000
# Simulation step 1958.9789894947476/2000
# Simulation step 1959.9794897448726/2000
# Simulation step 1960.9799899949976/2000
# Simulation step 1961.9804902451226/2000
# Simulation step 1962.9809904952479/2000
# Simulation step 1963.9814907453729/2000
# Simulation step 1964.9819909954979/2000
# Simulation step 1965.982491245623/2000
# Simulation step 1966.982991495748/2000
# Simulation step 1967.9834917458732/2000
# Simulation step 1968.9839919959982/2000
# Simulation step 1969.9844922461232/2000
# Simulation step 1970.9849924962482/2000
# Simulation step 1971.9854927463734/2000
# Simulation step 1972.9859929964985/2000
# Simulation step 1973.9864932466235/2000
# Simulation step 1974.9869934967485/2000
# Simulation step 1975.9874937468735/2000
# Simulation step 1976.9879939969987/2000
# Simulation step 1977.9884942471238/2000
# Simulation step 1978.9889944972488/2000
# Simulation step 1979.9894947473738/2000
# Simulation step 1980.9899949974988/2000
# Simulation step 1981.990495247624/2000
# Simulation step 1982.990995497749/2000
# Simulation step 1983.991495747874/2000
# Simulation step 1984.991995997999/2000
# Simulation step 1985.992496248124/2000
# Simulation step 1986.9929964982493/2000
# Simulation step 1987.9934967483744/2000
# Simulation step 1988.9939969984994/2000
# Simulation step 1989.9944972486244/2000
# Simulation step 1990.9949974987496/2000
# Simulation step 1991.9954977488746/2000
# Simulation step 1992.9959979989997/2000
# Simulation step 1993.9964982491247/2000
# Simulation step 1994.9969984992497/2000
# Simulation step 1995.997498749375/2000
# Simulation step 1996.9979989995/2000
# Simulation step 1997.998499249625/2000
# Simulation step 1998.99899949975/2000
# Simulation step 1999.999499749875/2000
# [ 9.93108663e-01  8.60424052e-02  5.13177682e-02  6.08338152e-02
#  -5.09539346e-09 -2.58200247e-09 -3.74129640e-09]

# %%
#plot angular velocity
plt.figure(figsize=(10, 6))
plt.plot(time_sec, states[:, 4:])
plt.plot(time_sec, np.tile(0.00269, (len(time_sec), 1)), '--')
plt.xlabel('Time')
plt.ylabel('Angular Velocity')
plt.title('Angular Velocity over Time')
plt.legend(['wx', 'wy', 'wz'])
plt.show()

# %%
#plot control torques
plt.figure(figsize=(10, 6))
time_sec_control = np.linspace(0, 2000, 2000)
plt.plot(time_sec_control, control_torques_history)
plt.xlabel('Time')
plt.ylabel('Control Torques')
plt.title('Control Torques over Time')
plt.legend(['Tx', 'Ty', 'Tz'])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem, t

# Assume `states` and `control_torques` are available from the simulation
# `states` contains quaternions and angular velocities
# `control_torques` contains the control torques for each timestep

# Extract angular velocities and time from simulation data
omega = states[:, 4:]  # Extract angular velocity components
time_sec = np.linspace(0, 2000, 2000)  # Time array matching simulation

# Parameters
threshold = 1e-6
window_size = 100
confidence = 0.97

# Calculate moving averages
omega_avg = np.array([
    np.convolve(omega[:, i], np.ones(window_size) / window_size, mode='valid')
    for i in range(3)
]).T

# Calculate standard errors of the mean (SEM)
omega_sem = np.array([
    np.array([sem(omega[j:j + window_size, i]) for j in range(len(omega) - window_size + 1)])
    for i in range(3)
]).T

# Calculate confidence intervals
degrees_freedom = window_size - 1
confidence_factor = t.ppf((1 + confidence) / 2., degrees_freedom)

omega_ci = omega_sem * confidence_factor

# Check when values are within threshold
def check_stability_with_ci(omega_avg, omega_ci, threshold, window_size):
    for i in range(len(omega_avg)):
        if (np.all(np.abs(omega_avg[i]) < threshold) and
            np.all(omega_ci[i] < threshold)):
            return time_sec[i + window_size - 1], i + window_size - 1
    return -1, -1

stable_time_step, stable_index = check_stability_with_ci(omega_avg, omega_ci, threshold, window_size)

print(f"The system stabilizes at time step: {stable_time_step} seconds")

# Plot angular velocities over time with a marker for stability time
plt.figure(figsize=(12, 8))
plt.plot(time_sec, omega[:, 0], label='Omega x')
plt.plot(time_sec, omega[:, 1], label='Omega y')
plt.plot(time_sec, omega[:, 2], label='Omega z')
if stable_time_step != -1:
    plt.axvline(x=stable_time_step, color='r', linestyle='--', label='Stability Time')
plt.xlabel('Time (s)')
plt.ylabel('Angular Velocities (rad/s)')
plt.title('Angular Velocities Over Time')
plt.legend()
plt.grid(True)
plt.show()

# Plot moving averages with confidence intervals
plt.figure(figsize=(12, 8))
plt.plot(time_sec[window_size - 1:], omega_avg[:, 0], label='Omega x Average')
plt.fill_between(time_sec[window_size - 1:], omega_avg[:, 0] - omega_ci[:, 0], omega_avg[:, 0] + omega_ci[:, 0], alpha=0.3)
plt.plot(time_sec[window_size - 1:], omega_avg[:, 1], label='Omega y Average')
plt.fill_between(time_sec[window_size - 1:], omega_avg[:, 1] - omega_ci[:, 1], omega_avg[:, 1] + omega_ci[:, 1], alpha=0.3)
plt.plot(time_sec[window_size - 1:], omega_avg[:, 2], label='Omega z Average')
plt.fill_between(time_sec[window_size - 1:], omega_avg[:, 2] - omega_ci[:, 2], omega_avg[:, 2] + omega_ci[:, 2], alpha=0.3)
if stable_time_step != -1:
    plt.axvline(x=stable_time_step, color='r', linestyle='--', label='Stability Time')
plt.xlabel('Time (s)')
plt.ylabel('Average Angular Velocities (rad/s)')
plt.title('Moving Averages of Angular Velocities with Confidence Intervals')
plt.legend()
plt.grid(True)
plt.show()

# Plot quaternion components over time with stability time
plt.figure(figsize=(12, 8))
plt.plot(time_sec, states[:, 0], label='q0')
plt.plot(time_sec, states[:, 1], label='q1')
plt.plot(time_sec, states[:, 2], label='q2')
plt.plot(time_sec, states[:, 3], label='q3')
if stable_time_step != -1:
    plt.axvline(x=stable_time_step, color='r', linestyle='--', label='Stability Time')
plt.xlabel('Time (s)')
plt.ylabel('Quaternion Components')
plt.title('Quaternion Over Time')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# The system stabilizes at time step: 763.3816908454228 seconds

# %%
# save to csv
import pandas as pd
from datetime import datetime

control_torques_history = np.array(control_torques_history)
# Exporting the data into a csv file
def save_simulation_to_csv(filename):
    data = {
        'time': time_history,
        'q0': states[:, 0],
        'q1': states[:, 1],
        'q2': states[:, 2],
        'q3': states[:, 3],
        'omega_x': states[:, 4],
        'omega_y': states[:, 5],
        'omega_z': states[:, 6],
        'Total_torque_x': control_torques_history[:, 0],
        'Total_torque_y': control_torques_history[:, 1],
        'Total_torque_z': control_torques_history[:, 2],
    }
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)

date_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
file_name = f"satellite_attitude_control_PID_RK4_p2p_Optimised_{date_time}.csv"
save_simulation_to_csv(file_name)

# %% [markdown]
# ## Now with the optimiser function results

# %%
import numpy as np
import matplotlib.pyplot as plt

def quaternion_product(q, p):
    w0, x0, y0, z0 = q
    w1, x1, y1, z1 = p
    return np.array([
        w0*w1 - x0*x1 - y0*y1 - z0*z1,
        w0*x1 + x0*w1 + y0*z1 - z0*y1,
        w0*y1 - x0*z1 + y0*w1 + z0*x1,
        w0*z1 + x0*y1 - y0*x1 + z0*w1
    ])

def quaternion_conjugate(q):
    return np.array([q[0], -q[1], -q[2], -q[3]])

def quaternion_error(q, q_target):
    return quaternion_product(quaternion_conjugate(q), q_target)


def pid_control(q, omega, q_target, integral_error, prev_error, dt):
    error = 2*quaternion_error(q, q_target)[1:]  # Vector part of the quaternion error
    
    integral_error += error * dt
    derivative_error = (error - prev_error) / dt
    
    control_torque = Kp * error + Ki * integral_error + Kd * derivative_error

    return control_torque, integral_error, error,

def dynamics(t, state, integral_error, prev_error, dt):
    q = state[:4]
    omega = state[4:]

    q = q / np.linalg.norm(q)  # Normalize quaternion

    dqdt = 0.5 * quaternion_product(q, np.append([0], omega))
    
    control_torque, integral_error, prev_error = pid_control(q, omega, q_target, integral_error, prev_error, dt)
    
    omega_cross_I_omega = np.cross(omega, I @ omega)
    dwdt = inv_I @ (control_torque - omega_cross_I_omega)

    return np.concatenate([dqdt, dwdt]), integral_error, prev_error


# RK4 integration method
def rk4_step(dynamics_func, t, state, dt, integral_error, prev_error):
    k1, integral_error1, prev_error1 = dynamics_func(t, state, integral_error, prev_error, dt)
    k2, integral_error2, prev_error2 = dynamics_func(t + 0.5 * dt, state + 0.5 * dt * k1, integral_error1, prev_error1, dt)
    k3, integral_error3, prev_error3 = dynamics_func(t + 0.5 * dt, state + 0.5 * dt * k2, integral_error2, prev_error2, dt)
    k4, integral_error4, prev_error4 = dynamics_func(t + dt, state + dt * k3, integral_error3, prev_error3, dt)

    new_state = state + (dt / 6) * (k1 + 2 * k2 + 2 * k3 + k4)
    return new_state, integral_error4, prev_error4

# Initialize simulation
Ix, Iy, Iz = 1191, 1844, 1798
I = np.diag([Ix, Iy, Iz])  # Inertia matrix
inv_I = np.linalg.inv(I)

# PID controller gains that the optimiser found
Kp = np.array([0.197959 ,0.197959 ,0.197959])
Ki = np.array([0.000001, 0.000001, 0.000001])
Kd = np.array([101.5151, 101.5151, 101.5151])

# PID controller gains working manually tuned
#Kp = np.array([0.2, 0.2, 0.2])
#Ki = np.array([0.000001, 0.000001, 0.000001])
#Kd = np.array([80.0, 80.0, 80.0])


# Target quaternion (example target)
q_target = np.array([0.9938, 0.086, 0.0513, 0.0608])
q_target = q_target / np.linalg.norm(q_target) 

q0 = np.array([1, 0, 0, 0])  # Initial quaternion
q0 = q0 / np.linalg.norm(q0)  # Normalize quaternion
omega0 = np.array([0, 0, 0])
state0 = np.concatenate([q0, omega0])

# Simulation parameters
t_span = (0, 2000)  # Time span for the simulation
t_eval = np.linspace(*t_span, 2000)  # Time points where the solution is computed
dt = 1

# Initialize PID errors
integral_error = np.zeros(3)
prev_error = np.zeros(3)
# Initialize storage for control torques
control_torques_history = [(0,0,0)]
time_history = [0]
# Run simulation using RK4
states = [state0]
t_values = [t_span[0]]

for t in t_eval[:-1]:
    new_state, integral_error, prev_error = rk4_step(dynamics, t, states[-1], dt, integral_error, prev_error)
    states.append(new_state)
    t_values.append(t + dt)
    control_torque_t, _, _ = pid_control(new_state[:4], new_state[4:], q_target, integral_error, prev_error, dt)
    # Store the control torque and time history
    control_torques_history.append(control_torque_t)
    time_history.append(t)
    #updater for sim
    print(f"Simulation step {t+1}/{len(t_eval)}")

states = np.array(states)
#time in seconds 5000s
time_sec = np.linspace(0, 2000, 2000)
# Output the final state for inspection
print(states[-1])

# Optional: Plot results
plt.figure(figsize=(10, 6))
plt.plot(time_sec, states[:, :4])
# Put in flat lines of the q target
plt.plot(time_sec, np.tile(q_target, (len(time_sec), 1)), '--')
plt.xlabel('Time')
plt.ylabel('Quaternion Components')
plt.title('Quaternion over Time')
plt.legend(['q0', 'q1', 'q2', 'q3'])
plt.show()
# Out:
# Simulation step 1.0/2000
# Simulation step 2.0005002501250626/2000
# Simulation step 3.001000500250125/2000
# Simulation step 4.001500750375188/2000
# Simulation step 5.00200100050025/2000
# Simulation step 6.002501250625313/2000
# Simulation step 7.003001500750376/2000
# Simulation step 8.003501750875438/2000
# Simulation step 9.0040020010005/2000
# Simulation step 10.004502251125563/2000
# Simulation step 11.005002501250626/2000
# Simulation step 12.005502751375689/2000
# Simulation step 13.006003001500751/2000
# Simulation step 14.006503251625814/2000
# Simulation step 15.007003501750876/2000
# Simulation step 16.007503751875937/2000
# Simulation step 17.008004002001/2000
# Simulation step 18.008504252126066/2000
# Simulation step 19.009004502251127/2000
# Simulation step 20.009504752376188/2000
# Simulation step 21.010005002501252/2000
# Simulation step 22.010505252626317/2000
# Simulation step 23.011005502751377/2000
# Simulation step 24.011505752876438/2000
# Simulation step 25.012006003001503/2000
# Simulation step 26.012506253126567/2000
# Simulation step 27.013006503251628/2000
# Simulation step 28.01350675337669/2000
# Simulation step 29.014007003501753/2000
# Simulation step 30.014507253626817/2000
# Simulation step 31.015007503751878/2000
# Simulation step 32.01550775387694/2000
# Simulation step 33.016008004002/2000
# Simulation step 34.01650825412707/2000
# Simulation step 35.01700850425213/2000
# Simulation step 36.01750875437719/2000
# Simulation step 37.018009004502254/2000
# Simulation step 38.01850925462732/2000
# Simulation step 39.019009504752376/2000
# Simulation step 40.01950975487744/2000
# Simulation step 41.020010005002504/2000
# Simulation step 42.02051025512757/2000
# Simulation step 43.02101050525263/2000
# Simulation step 44.02151075537769/2000
# Simulation step 45.022011005502755/2000
# Simulation step 46.02251125562782/2000
# Simulation step 47.023011505752876/2000
# Simulation step 48.02351175587794/2000
# Simulation step 49.024012006003005/2000
# Simulation step 50.02451225612807/2000
# Simulation step 51.025012506253134/2000
# Simulation step 52.02551275637819/2000
# Simulation step 53.026013006503256/2000
# Simulation step 54.02651325662832/2000
# Simulation step 55.02701350675338/2000
# Simulation step 56.02751375687844/2000
# Simulation step 57.028014007003506/2000
# Simulation step 58.02851425712857/2000
# Simulation step 59.029014507253635/2000
# Simulation step 60.02951475737869/2000
# Simulation step 61.030015007503756/2000
# Simulation step 62.03051525762882/2000
# Simulation step 63.03101550775388/2000
# Simulation step 64.03151575787894/2000
# Simulation step 65.032016008004/2000
# Simulation step 66.03251625812906/2000
# Simulation step 67.03301650825414/2000
# Simulation step 68.03351675837919/2000
# Simulation step 69.03401700850426/2000
# Simulation step 70.03451725862932/2000
# Simulation step 71.03501750875438/2000
# Simulation step 72.03551775887945/2000
# Simulation step 73.03601800900451/2000
# Simulation step 74.03651825912956/2000
# Simulation step 75.03701850925464/2000
# Simulation step 76.0375187593797/2000
# Simulation step 77.03801900950475/2000
# Simulation step 78.03851925962982/2000
# Simulation step 79.03901950975488/2000
# Simulation step 80.03951975987995/2000
# Simulation step 81.04002001000501/2000
# Simulation step 82.04052026013007/2000
# Simulation step 83.04102051025514/2000
# Simulation step 84.0415207603802/2000
# Simulation step 85.04202101050527/2000
# Simulation step 86.04252126063032/2000
# Simulation step 87.04302151075538/2000
# Simulation step 88.04352176088045/2000
# Simulation step 89.04402201100551/2000
# Simulation step 90.04452226113057/2000
# Simulation step 91.04502251125564/2000
# Simulation step 92.0455227613807/2000
# Simulation step 93.04602301150575/2000
# Simulation step 94.04652326163082/2000
# Simulation step 95.04702351175588/2000
# Simulation step 96.04752376188095/2000
# Simulation step 97.04802401200601/2000
# Simulation step 98.04852426213107/2000
# Simulation step 99.04902451225614/2000
# Simulation step 100.0495247623812/2000
# Simulation step 101.05002501250627/2000
# Simulation step 102.05052526263133/2000
# Simulation step 103.05102551275638/2000
# Simulation step 104.05152576288145/2000
# Simulation step 105.05202601300651/2000
# Simulation step 106.05252626313157/2000
# Simulation step 107.05302651325664/2000
# Simulation step 108.0535267633817/2000
# Simulation step 109.05402701350675/2000
# Simulation step 110.05452726363183/2000
# Simulation step 111.05502751375688/2000
# Simulation step 112.05552776388195/2000
# Simulation step 113.05602801400701/2000
# Simulation step 114.05652826413207/2000
# Simulation step 115.05702851425714/2000
# Simulation step 116.0575287643822/2000
# Simulation step 117.05802901450727/2000
# Simulation step 118.05852926463233/2000
# Simulation step 119.05902951475738/2000
# Simulation step 120.05952976488246/2000
# Simulation step 121.06003001500751/2000
# Simulation step 122.06053026513257/2000
# Simulation step 123.06103051525764/2000
# Simulation step 124.0615307653827/2000
# Simulation step 125.06203101550776/2000
# Simulation step 126.06253126563283/2000
# Simulation step 127.06303151575788/2000
# Simulation step 128.06353176588294/2000
# Simulation step 129.064032016008/2000
# Simulation step 130.06453226613309/2000
# Simulation step 131.06503251625813/2000
# Simulation step 132.0655327663832/2000
# Simulation step 133.06603301650827/2000
# Simulation step 134.06653326663331/2000
# Simulation step 135.06703351675839/2000
# Simulation step 136.06753376688346/2000
# Simulation step 137.06803401700853/2000
# Simulation step 138.06853426713357/2000
# Simulation step 139.06903451725864/2000
# Simulation step 140.06953476738371/2000
# Simulation step 141.07003501750876/2000
# Simulation step 142.07053526763383/2000
# Simulation step 143.0710355177589/2000
# Simulation step 144.07153576788394/2000
# Simulation step 145.07203601800902/2000
# Simulation step 146.0725362681341/2000
# Simulation step 147.07303651825913/2000
# Simulation step 148.0735367683842/2000
# Simulation step 149.07403701850927/2000
# Simulation step 150.07453726863432/2000
# Simulation step 151.0750375187594/2000
# Simulation step 152.07553776888446/2000
# Simulation step 153.0760380190095/2000
# Simulation step 154.07653826913457/2000
# Simulation step 155.07703851925964/2000
# Simulation step 156.07753876938472/2000
# Simulation step 157.07803901950976/2000
# Simulation step 158.07853926963483/2000
# Simulation step 159.0790395197599/2000
# Simulation step 160.07953976988495/2000
# Simulation step 161.08004002001002/2000
# Simulation step 162.0805402701351/2000
# Simulation step 163.08104052026013/2000
# Simulation step 164.0815407703852/2000
# Simulation step 165.08204102051027/2000
# Simulation step 166.08254127063532/2000
# Simulation step 167.0830415207604/2000
# Simulation step 168.08354177088546/2000
# Simulation step 169.08404202101053/2000
# Simulation step 170.08454227113558/2000
# Simulation step 171.08504252126065/2000
# Simulation step 172.08554277138572/2000
# Simulation step 173.08604302151076/2000
# Simulation step 174.08654327163583/2000
# Simulation step 175.0870435217609/2000
# Simulation step 176.08754377188595/2000
# Simulation step 177.08804402201102/2000
# Simulation step 178.0885442721361/2000
# Simulation step 179.08904452226113/2000
# Simulation step 180.0895447723862/2000
# Simulation step 181.09004502251128/2000
# Simulation step 182.09054527263632/2000
# Simulation step 183.0910455227614/2000
# Simulation step 184.09154577288646/2000
# Simulation step 185.0920460230115/2000
# Simulation step 186.09254627313658/2000
# Simulation step 187.09304652326165/2000
# Simulation step 188.09354677338672/2000
# Simulation step 189.09404702351176/2000
# Simulation step 190.09454727363683/2000
# Simulation step 191.0950475237619/2000
# Simulation step 192.09554777388695/2000
# Simulation step 193.09604802401202/2000
# Simulation step 194.0965482741371/2000
# Simulation step 195.09704852426214/2000
# Simulation step 196.0975487743872/2000
# Simulation step 197.09804902451228/2000
# Simulation step 198.09854927463732/2000
# Simulation step 199.0990495247624/2000
# Simulation step 200.09954977488746/2000
# Simulation step 201.10005002501254/2000
# Simulation step 202.10055027513758/2000
# Simulation step 203.10105052526265/2000
# Simulation step 204.10155077538772/2000
# Simulation step 205.10205102551276/2000
# Simulation step 206.10255127563784/2000
# Simulation step 207.1030515257629/2000
# Simulation step 208.10355177588795/2000
# Simulation step 209.10405202601302/2000
# Simulation step 210.1045522761381/2000
# Simulation step 211.10505252626314/2000
# Simulation step 212.1055527763882/2000
# Simulation step 213.10605302651328/2000
# Simulation step 214.10655327663832/2000
# Simulation step 215.1070535267634/2000
# Simulation step 216.10755377688847/2000
# Simulation step 217.1080540270135/2000
# Simulation step 218.10855427713858/2000
# Simulation step 219.10905452726365/2000
# Simulation step 220.10955477738872/2000
# Simulation step 221.11005502751377/2000
# Simulation step 222.11055527763884/2000
# Simulation step 223.1110555277639/2000
# Simulation step 224.11155577788895/2000
# Simulation step 225.11205602801402/2000
# Simulation step 226.1125562781391/2000
# Simulation step 227.11305652826414/2000
# Simulation step 228.1135567783892/2000
# Simulation step 229.11405702851428/2000
# Simulation step 230.11455727863932/2000
# Simulation step 231.1150575287644/2000
# Simulation step 232.11555777888947/2000
# Simulation step 233.11605802901454/2000
# Simulation step 234.11655827913958/2000
# Simulation step 235.11705852926465/2000
# Simulation step 236.11755877938973/2000
# Simulation step 237.11805902951477/2000
# Simulation step 238.11855927963984/2000
# Simulation step 239.1190595297649/2000
# Simulation step 240.11955977988995/2000
# Simulation step 241.12006003001503/2000
# Simulation step 242.1205602801401/2000
# Simulation step 243.12106053026514/2000
# Simulation step 244.1215607803902/2000
# Simulation step 245.12206103051528/2000
# Simulation step 246.12256128064033/2000
# Simulation step 247.1230615307654/2000
# Simulation step 248.12356178089047/2000
# Simulation step 249.1240620310155/2000
# Simulation step 250.12456228114058/2000
# Simulation step 251.12506253126566/2000
# Simulation step 252.12556278139073/2000
# Simulation step 253.12606303151577/2000
# Simulation step 254.12656328164084/2000
# Simulation step 255.1270635317659/2000
# Simulation step 256.12756378189096/2000
# Simulation step 257.128064032016/2000
# Simulation step 258.1285642821411/2000
# Simulation step 259.12906453226617/2000
# Simulation step 260.12956478239124/2000
# Simulation step 261.13006503251626/2000
# Simulation step 262.1305652826413/2000
# Simulation step 263.1310655327664/2000
# Simulation step 264.13156578289147/2000
# Simulation step 265.13206603301654/2000
# Simulation step 266.1325662831416/2000
# Simulation step 267.13306653326663/2000
# Simulation step 268.1335667833917/2000
# Simulation step 269.13406703351677/2000
# Simulation step 270.13456728364184/2000
# Simulation step 271.1350675337669/2000
# Simulation step 272.135567783892/2000
# Simulation step 273.13606803401706/2000
# Simulation step 274.1365682841421/2000
# Simulation step 275.13706853426714/2000
# Simulation step 276.1375687843922/2000
# Simulation step 277.1380690345173/2000
# Simulation step 278.13856928464236/2000
# Simulation step 279.13906953476743/2000
# Simulation step 280.13956978489244/2000
# Simulation step 281.1400700350175/2000
# Simulation step 282.1405702851426/2000
# Simulation step 283.14107053526766/2000
# Simulation step 284.14157078539273/2000
# Simulation step 285.1420710355178/2000
# Simulation step 286.1425712856428/2000
# Simulation step 287.1430715357679/2000
# Simulation step 288.14357178589296/2000
# Simulation step 289.14407203601803/2000
# Simulation step 290.1445722861431/2000
# Simulation step 291.1450725362682/2000
# Simulation step 292.14557278639325/2000
# Simulation step 293.14607303651826/2000
# Simulation step 294.14657328664333/2000
# Simulation step 295.1470735367684/2000
# Simulation step 296.1475737868935/2000
# Simulation step 297.14807403701855/2000
# Simulation step 298.1485742871436/2000
# Simulation step 299.14907453726863/2000
# Simulation step 300.1495747873937/2000
# Simulation step 301.1500750375188/2000
# Simulation step 302.15057528764385/2000
# Simulation step 303.1510755377689/2000
# Simulation step 304.151575787894/2000
# Simulation step 305.152076038019/2000
# Simulation step 306.1525762881441/2000
# Simulation step 307.15307653826915/2000
# Simulation step 308.1535767883942/2000
# Simulation step 309.1540770385193/2000
# Simulation step 310.15457728864436/2000
# Simulation step 311.15507753876943/2000
# Simulation step 312.15557778889445/2000
# Simulation step 313.1560780390195/2000
# Simulation step 314.1565782891446/2000
# Simulation step 315.15707853926966/2000
# Simulation step 316.15757878939473/2000
# Simulation step 317.1580790395198/2000
# Simulation step 318.1585792896448/2000
# Simulation step 319.1590795397699/2000
# Simulation step 320.15957978989496/2000
# Simulation step 321.16008004002003/2000
# Simulation step 322.1605802901451/2000
# Simulation step 323.1610805402702/2000
# Simulation step 324.16158079039525/2000
# Simulation step 325.16208104052026/2000
# Simulation step 326.16258129064533/2000
# Simulation step 327.1630815407704/2000
# Simulation step 328.1635817908955/2000
# Simulation step 329.16408204102055/2000
# Simulation step 330.1645822911456/2000
# Simulation step 331.16508254127064/2000
# Simulation step 332.1655827913957/2000
# Simulation step 333.1660830415208/2000
# Simulation step 334.16658329164585/2000
# Simulation step 335.1670835417709/2000
# Simulation step 336.167583791896/2000
# Simulation step 337.16808404202106/2000
# Simulation step 338.1685842921461/2000
# Simulation step 339.16908454227115/2000
# Simulation step 340.1695847923962/2000
# Simulation step 341.1700850425213/2000
# Simulation step 342.17058529264636/2000
# Simulation step 343.17108554277144/2000
# Simulation step 344.17158579289645/2000
# Simulation step 345.1720860430215/2000
# Simulation step 346.1725862931466/2000
# Simulation step 347.17308654327167/2000
# Simulation step 348.17358679339674/2000
# Simulation step 349.1740870435218/2000
# Simulation step 350.1745872936468/2000
# Simulation step 351.1750875437719/2000
# Simulation step 352.17558779389697/2000
# Simulation step 353.17608804402204/2000
# Simulation step 354.1765882941471/2000
# Simulation step 355.1770885442722/2000
# Simulation step 356.17758879439725/2000
# Simulation step 357.17808904452227/2000
# Simulation step 358.17858929464734/2000
# Simulation step 359.1790895447724/2000
# Simulation step 360.1795897948975/2000
# Simulation step 361.18009004502255/2000
# Simulation step 362.1805902951476/2000
# Simulation step 363.18109054527264/2000
# Simulation step 364.1815907953977/2000
# Simulation step 365.1820910455228/2000
# Simulation step 366.18259129564785/2000
# Simulation step 367.1830915457729/2000
# Simulation step 368.183591795898/2000
# Simulation step 369.184092046023/2000
# Simulation step 370.1845922961481/2000
# Simulation step 371.18509254627315/2000
# Simulation step 372.1855927963982/2000
# Simulation step 373.1860930465233/2000
# Simulation step 374.18659329664837/2000
# Simulation step 375.18709354677344/2000
# Simulation step 376.18759379689845/2000
# Simulation step 377.1880940470235/2000
# Simulation step 378.1885942971486/2000
# Simulation step 379.18909454727367/2000
# Simulation step 380.18959479739874/2000
# Simulation step 381.1900950475238/2000
# Simulation step 382.1905952976488/2000
# Simulation step 383.1910955477739/2000
# Simulation step 384.19159579789897/2000
# Simulation step 385.19209604802404/2000
# Simulation step 386.1925962981491/2000
# Simulation step 387.1930965482742/2000
# Simulation step 388.19359679839926/2000
# Simulation step 389.19409704852427/2000
# Simulation step 390.19459729864934/2000
# Simulation step 391.1950975487744/2000
# Simulation step 392.1955977988995/2000
# Simulation step 393.19609804902456/2000
# Simulation step 394.1965982991496/2000
# Simulation step 395.19709854927464/2000
# Simulation step 396.1975987993997/2000
# Simulation step 397.1980990495248/2000
# Simulation step 398.19859929964986/2000
# Simulation step 399.1990995497749/2000
# Simulation step 400.1995997999/2000
# Simulation step 401.20010005002507/2000
# Simulation step 402.2006003001501/2000
# Simulation step 403.20110055027516/2000
# Simulation step 404.20160080040023/2000
# Simulation step 405.2021010505253/2000
# Simulation step 406.2026013006504/2000
# Simulation step 407.20310155077544/2000
# Simulation step 408.20360180090046/2000
# Simulation step 409.20410205102553/2000
# Simulation step 410.2046023011506/2000
# Simulation step 411.2051025512757/2000
# Simulation step 412.20560280140074/2000
# Simulation step 413.2061030515258/2000
# Simulation step 414.20660330165083/2000
# Simulation step 415.2071035517759/2000
# Simulation step 416.207603801901/2000
# Simulation step 417.20810405202604/2000
# Simulation step 418.2086043021511/2000
# Simulation step 419.2091045522762/2000
# Simulation step 420.20960480240126/2000
# Simulation step 421.2101050525263/2000
# Simulation step 422.21060530265135/2000
# Simulation step 423.2111055527764/2000
# Simulation step 424.2116058029015/2000
# Simulation step 425.21210605302656/2000
# Simulation step 426.21260630315163/2000
# Simulation step 427.21310655327665/2000
# Simulation step 428.2136068034017/2000
# Simulation step 429.2141070535268/2000
# Simulation step 430.21460730365186/2000
# Simulation step 431.21510755377693/2000
# Simulation step 432.215607803902/2000
# Simulation step 433.216108054027/2000
# Simulation step 434.2166083041521/2000
# Simulation step 435.21710855427716/2000
# Simulation step 436.21760880440223/2000
# Simulation step 437.2181090545273/2000
# Simulation step 438.2186093046524/2000
# Simulation step 439.21910955477745/2000
# Simulation step 440.21960980490246/2000
# Simulation step 441.22011005502753/2000
# Simulation step 442.2206103051526/2000
# Simulation step 443.2211105552777/2000
# Simulation step 444.22161080540275/2000
# Simulation step 445.2221110555278/2000
# Simulation step 446.22261130565283/2000
# Simulation step 447.2231115557779/2000
# Simulation step 448.223611805903/2000
# Simulation step 449.22411205602805/2000
# Simulation step 450.2246123061531/2000
# Simulation step 451.2251125562782/2000
# Simulation step 452.22561280640326/2000
# Simulation step 453.2261130565283/2000
# Simulation step 454.22661330665335/2000
# Simulation step 455.2271135567784/2000
# Simulation step 456.2276138069035/2000
# Simulation step 457.22811405702856/2000
# Simulation step 458.22861430715363/2000
# Simulation step 459.22911455727865/2000
# Simulation step 460.2296148074037/2000
# Simulation step 461.2301150575288/2000
# Simulation step 462.23061530765386/2000
# Simulation step 463.23111555777893/2000
# Simulation step 464.231615807904/2000
# Simulation step 465.2321160580291/2000
# Simulation step 466.2326163081541/2000
# Simulation step 467.23311655827916/2000
# Simulation step 468.23361680840424/2000
# Simulation step 469.2341170585293/2000
# Simulation step 470.2346173086544/2000
# Simulation step 471.23511755877945/2000
# Simulation step 472.23561780890446/2000
# Simulation step 473.23611805902954/2000
# Simulation step 474.2366183091546/2000
# Simulation step 475.2371185592797/2000
# Simulation step 476.23761880940475/2000
# Simulation step 477.2381190595298/2000
# Simulation step 478.23861930965484/2000
# Simulation step 479.2391195597799/2000
# Simulation step 480.239619809905/2000
# Simulation step 481.24012006003005/2000
# Simulation step 482.2406203101551/2000
# Simulation step 483.2411205602802/2000
# Simulation step 484.24162081040527/2000
# Simulation step 485.2421210605303/2000
# Simulation step 486.24262131065535/2000
# Simulation step 487.2431215607804/2000
# Simulation step 488.2436218109055/2000
# Simulation step 489.24412206103057/2000
# Simulation step 490.24462231115564/2000
# Simulation step 491.24512256128065/2000
# Simulation step 492.2456228114057/2000
# Simulation step 493.2461230615308/2000
# Simulation step 494.24662331165587/2000
# Simulation step 495.24712356178094/2000
# Simulation step 496.247623811906/2000
# Simulation step 497.248124062031/2000
# Simulation step 498.2486243121561/2000
# Simulation step 499.24912456228117/2000
# Simulation step 500.24962481240624/2000
# Simulation step 501.2501250625313/2000
# Simulation step 502.2506253126564/2000
# Simulation step 503.25112556278145/2000
# Simulation step 504.25162581290647/2000
# Simulation step 505.25212606303154/2000
# Simulation step 506.2526263131566/2000
# Simulation step 507.2531265632817/2000
# Simulation step 508.25362681340675/2000
# Simulation step 509.2541270635318/2000
# Simulation step 510.25462731365684/2000
# Simulation step 511.2551275637819/2000
# Simulation step 512.255627813907/2000
# Simulation step 513.256128064032/2000
# Simulation step 514.2566283141571/2000
# Simulation step 515.2571285642822/2000
# Simulation step 516.2576288144072/2000
# Simulation step 517.2581290645323/2000
# Simulation step 518.2586293146574/2000
# Simulation step 519.2591295647825/2000
# Simulation step 520.2596298149075/2000
# Simulation step 521.2601300650325/2000
# Simulation step 522.2606303151576/2000
# Simulation step 523.2611305652827/2000
# Simulation step 524.2616308154078/2000
# Simulation step 525.2621310655328/2000
# Simulation step 526.2626313156578/2000
# Simulation step 527.2631315657829/2000
# Simulation step 528.263631815908/2000
# Simulation step 529.2641320660331/2000
# Simulation step 530.2646323161581/2000
# Simulation step 531.2651325662832/2000
# Simulation step 532.2656328164082/2000
# Simulation step 533.2661330665333/2000
# Simulation step 534.2666333166584/2000
# Simulation step 535.2671335667834/2000
# Simulation step 536.2676338169085/2000
# Simulation step 537.2681340670335/2000
# Simulation step 538.2686343171587/2000
# Simulation step 539.2691345672837/2000
# Simulation step 540.2696348174087/2000
# Simulation step 541.2701350675338/2000
# Simulation step 542.2706353176588/2000
# Simulation step 543.271135567784/2000
# Simulation step 544.271635817909/2000
# Simulation step 545.2721360680341/2000
# Simulation step 546.2726363181591/2000
# Simulation step 547.2731365682841/2000
# Simulation step 548.2736368184093/2000
# Simulation step 549.2741370685343/2000
# Simulation step 550.2746373186594/2000
# Simulation step 551.2751375687844/2000
# Simulation step 552.2756378189094/2000
# Simulation step 553.2761380690346/2000
# Simulation step 554.2766383191596/2000
# Simulation step 555.2771385692847/2000
# Simulation step 556.2776388194097/2000
# Simulation step 557.2781390695349/2000
# Simulation step 558.2786393196599/2000
# Simulation step 559.2791395697849/2000
# Simulation step 560.27963981991/2000
# Simulation step 561.280140070035/2000
# Simulation step 562.2806403201602/2000
# Simulation step 563.2811405702852/2000
# Simulation step 564.2816408204103/2000
# Simulation step 565.2821410705353/2000
# Simulation step 566.2826413206603/2000
# Simulation step 567.2831415707855/2000
# Simulation step 568.2836418209105/2000
# Simulation step 569.2841420710356/2000
# Simulation step 570.2846423211606/2000
# Simulation step 571.2851425712856/2000
# Simulation step 572.2856428214108/2000
# Simulation step 573.2861430715358/2000
# Simulation step 574.2866433216609/2000
# Simulation step 575.2871435717859/2000
# Simulation step 576.287643821911/2000
# Simulation step 577.2881440720361/2000
# Simulation step 578.2886443221611/2000
# Simulation step 579.2891445722862/2000
# Simulation step 580.2896448224112/2000
# Simulation step 581.2901450725363/2000
# Simulation step 582.2906453226614/2000
# Simulation step 583.2911455727865/2000
# Simulation step 584.2916458229115/2000
# Simulation step 585.2921460730365/2000
# Simulation step 586.2926463231616/2000
# Simulation step 587.2931465732867/2000
# Simulation step 588.2936468234118/2000
# Simulation step 589.2941470735368/2000
# Simulation step 590.2946473236618/2000
# Simulation step 591.295147573787/2000
# Simulation step 592.295647823912/2000
# Simulation step 593.2961480740371/2000
# Simulation step 594.2966483241621/2000
# Simulation step 595.2971485742872/2000
# Simulation step 596.2976488244122/2000
# Simulation step 597.2981490745373/2000
# Simulation step 598.2986493246624/2000
# Simulation step 599.2991495747874/2000
# Simulation step 600.2996498249125/2000
# Simulation step 601.3001500750375/2000
# Simulation step 602.3006503251627/2000
# Simulation step 603.3011505752877/2000
# Simulation step 604.3016508254127/2000
# Simulation step 605.3021510755378/2000
# Simulation step 606.3026513256629/2000
# Simulation step 607.303151575788/2000
# Simulation step 608.303651825913/2000
# Simulation step 609.304152076038/2000
# Simulation step 610.3046523261631/2000
# Simulation step 611.3051525762882/2000
# Simulation step 612.3056528264133/2000
# Simulation step 613.3061530765383/2000
# Simulation step 614.3066533266634/2000
# Simulation step 615.3071535767884/2000
# Simulation step 616.3076538269135/2000
# Simulation step 617.3081540770386/2000
# Simulation step 618.3086543271636/2000
# Simulation step 619.3091545772887/2000
# Simulation step 620.3096548274137/2000
# Simulation step 621.3101550775389/2000
# Simulation step 622.3106553276639/2000
# Simulation step 623.3111555777889/2000
# Simulation step 624.311655827914/2000
# Simulation step 625.312156078039/2000
# Simulation step 626.3126563281642/2000
# Simulation step 627.3131565782892/2000
# Simulation step 628.3136568284143/2000
# Simulation step 629.3141570785393/2000
# Simulation step 630.3146573286643/2000
# Simulation step 631.3151575787895/2000
# Simulation step 632.3156578289145/2000
# Simulation step 633.3161580790396/2000
# Simulation step 634.3166583291646/2000
# Simulation step 635.3171585792896/2000
# Simulation step 636.3176588294148/2000
# Simulation step 637.3181590795398/2000
# Simulation step 638.3186593296649/2000
# Simulation step 639.3191595797899/2000
# Simulation step 640.319659829915/2000
# Simulation step 641.3201600800401/2000
# Simulation step 642.3206603301651/2000
# Simulation step 643.3211605802902/2000
# Simulation step 644.3216608304152/2000
# Simulation step 645.3221610805404/2000
# Simulation step 646.3226613306654/2000
# Simulation step 647.3231615807905/2000
# Simulation step 648.3236618309155/2000
# Simulation step 649.3241620810405/2000
# Simulation step 650.3246623311657/2000
# Simulation step 651.3251625812907/2000
# Simulation step 652.3256628314158/2000
# Simulation step 653.3261630815408/2000
# Simulation step 654.3266633316658/2000
# Simulation step 655.327163581791/2000
# Simulation step 656.327663831916/2000
# Simulation step 657.3281640820411/2000
# Simulation step 658.3286643321661/2000
# Simulation step 659.3291645822912/2000
# Simulation step 660.3296648324163/2000
# Simulation step 661.3301650825413/2000
# Simulation step 662.3306653326664/2000
# Simulation step 663.3311655827914/2000
# Simulation step 664.3316658329165/2000
# Simulation step 665.3321660830416/2000
# Simulation step 666.3326663331667/2000
# Simulation step 667.3331665832917/2000
# Simulation step 668.3336668334167/2000
# Simulation step 669.3341670835418/2000
# Simulation step 670.3346673336669/2000
# Simulation step 671.335167583792/2000
# Simulation step 672.335667833917/2000
# Simulation step 673.3361680840421/2000
# Simulation step 674.3366683341671/2000
# Simulation step 675.3371685842922/2000
# Simulation step 676.3376688344173/2000
# Simulation step 677.3381690845423/2000
# Simulation step 678.3386693346674/2000
# Simulation step 679.3391695847924/2000
# Simulation step 680.3396698349175/2000
# Simulation step 681.3401700850426/2000
# Simulation step 682.3406703351676/2000
# Simulation step 683.3411705852927/2000
# Simulation step 684.3416708354177/2000
# Simulation step 685.3421710855429/2000
# Simulation step 686.3426713356679/2000
# Simulation step 687.3431715857929/2000
# Simulation step 688.343671835918/2000
# Simulation step 689.344172086043/2000
# Simulation step 690.3446723361682/2000
# Simulation step 691.3451725862932/2000
# Simulation step 692.3456728364183/2000
# Simulation step 693.3461730865433/2000
# Simulation step 694.3466733366683/2000
# Simulation step 695.3471735867935/2000
# Simulation step 696.3476738369185/2000
# Simulation step 697.3481740870436/2000
# Simulation step 698.3486743371686/2000
# Simulation step 699.3491745872936/2000
# Simulation step 700.3496748374188/2000
# Simulation step 701.3501750875438/2000
# Simulation step 702.3506753376689/2000
# Simulation step 703.3511755877939/2000
# Simulation step 704.3516758379191/2000
# Simulation step 705.3521760880441/2000
# Simulation step 706.3526763381691/2000
# Simulation step 707.3531765882942/2000
# Simulation step 708.3536768384192/2000
# Simulation step 709.3541770885444/2000
# Simulation step 710.3546773386694/2000
# Simulation step 711.3551775887945/2000
# Simulation step 712.3556778389195/2000
# Simulation step 713.3561780890445/2000
# Simulation step 714.3566783391697/2000
# Simulation step 715.3571785892947/2000
# Simulation step 716.3576788394198/2000
# Simulation step 717.3581790895448/2000
# Simulation step 718.3586793396698/2000
# Simulation step 719.359179589795/2000
# Simulation step 720.35967983992/2000
# Simulation step 721.3601800900451/2000
# Simulation step 722.3606803401701/2000
# Simulation step 723.3611805902952/2000
# Simulation step 724.3616808404203/2000
# Simulation step 725.3621810905453/2000
# Simulation step 726.3626813406704/2000
# Simulation step 727.3631815907954/2000
# Simulation step 728.3636818409205/2000
# Simulation step 729.3641820910456/2000
# Simulation step 730.3646823411707/2000
# Simulation step 731.3651825912957/2000
# Simulation step 732.3656828414207/2000
# Simulation step 733.3661830915458/2000
# Simulation step 734.3666833416709/2000
# Simulation step 735.367183591796/2000
# Simulation step 736.367683841921/2000
# Simulation step 737.368184092046/2000
# Simulation step 738.3686843421712/2000
# Simulation step 739.3691845922962/2000
# Simulation step 740.3696848424213/2000
# Simulation step 741.3701850925463/2000
# Simulation step 742.3706853426714/2000
# Simulation step 743.3711855927965/2000
# Simulation step 744.3716858429215/2000
# Simulation step 745.3721860930466/2000
# Simulation step 746.3726863431716/2000
# Simulation step 747.3731865932967/2000
# Simulation step 748.3736868434218/2000
# Simulation step 749.3741870935469/2000
# Simulation step 750.3746873436719/2000
# Simulation step 751.3751875937969/2000
# Simulation step 752.375687843922/2000
# Simulation step 753.376188094047/2000
# Simulation step 754.3766883441722/2000
# Simulation step 755.3771885942972/2000
# Simulation step 756.3776888444223/2000
# Simulation step 757.3781890945473/2000
# Simulation step 758.3786893446724/2000
# Simulation step 759.3791895947975/2000
# Simulation step 760.3796898449225/2000
# Simulation step 761.3801900950476/2000
# Simulation step 762.3806903451726/2000
# Simulation step 763.3811905952977/2000
# Simulation step 764.3816908454228/2000
# Simulation step 765.3821910955478/2000
# Simulation step 766.3826913456729/2000
# Simulation step 767.3831915957979/2000
# Simulation step 768.3836918459231/2000
# Simulation step 769.3841920960481/2000
# Simulation step 770.3846923461731/2000
# Simulation step 771.3851925962982/2000
# Simulation step 772.3856928464232/2000
# Simulation step 773.3861930965484/2000
# Simulation step 774.3866933466734/2000
# Simulation step 775.3871935967985/2000
# Simulation step 776.3876938469235/2000
# Simulation step 777.3881940970485/2000
# Simulation step 778.3886943471737/2000
# Simulation step 779.3891945972987/2000
# Simulation step 780.3896948474238/2000
# Simulation step 781.3901950975488/2000
# Simulation step 782.3906953476738/2000
# Simulation step 783.391195597799/2000
# Simulation step 784.391695847924/2000
# Simulation step 785.3921960980491/2000
# Simulation step 786.3926963481741/2000
# Simulation step 787.3931965982993/2000
# Simulation step 788.3936968484243/2000
# Simulation step 789.3941970985493/2000
# Simulation step 790.3946973486744/2000
# Simulation step 791.3951975987994/2000
# Simulation step 792.3956978489246/2000
# Simulation step 793.3961980990496/2000
# Simulation step 794.3966983491747/2000
# Simulation step 795.3971985992997/2000
# Simulation step 796.3976988494247/2000
# Simulation step 797.3981990995499/2000
# Simulation step 798.3986993496749/2000
# Simulation step 799.3991995998/2000
# Simulation step 800.399699849925/2000
# Simulation step 801.4002001000501/2000
# Simulation step 802.4007003501752/2000
# Simulation step 803.4012006003002/2000
# Simulation step 804.4017008504253/2000
# Simulation step 805.4022011005503/2000
# Simulation step 806.4027013506754/2000
# Simulation step 807.4032016008005/2000
# Simulation step 808.4037018509255/2000
# Simulation step 809.4042021010506/2000
# Simulation step 810.4047023511756/2000
# Simulation step 811.4052026013007/2000
# Simulation step 812.4057028514258/2000
# Simulation step 813.4062031015509/2000
# Simulation step 814.4067033516759/2000
# Simulation step 815.4072036018009/2000
# Simulation step 816.407703851926/2000
# Simulation step 817.4082041020511/2000
# Simulation step 818.4087043521762/2000
# Simulation step 819.4092046023012/2000
# Simulation step 820.4097048524263/2000
# Simulation step 821.4102051025513/2000
# Simulation step 822.4107053526764/2000
# Simulation step 823.4112056028015/2000
# Simulation step 824.4117058529265/2000
# Simulation step 825.4122061030516/2000
# Simulation step 826.4127063531766/2000
# Simulation step 827.4132066033017/2000
# Simulation step 828.4137068534268/2000
# Simulation step 829.4142071035518/2000
# Simulation step 830.4147073536769/2000
# Simulation step 831.415207603802/2000
# Simulation step 832.4157078539271/2000
# Simulation step 833.4162081040521/2000
# Simulation step 834.4167083541771/2000
# Simulation step 835.4172086043022/2000
# Simulation step 836.4177088544272/2000
# Simulation step 837.4182091045524/2000
# Simulation step 838.4187093546774/2000
# Simulation step 839.4192096048025/2000
# Simulation step 840.4197098549275/2000
# Simulation step 841.4202101050525/2000
# Simulation step 842.4207103551777/2000
# Simulation step 843.4212106053027/2000
# Simulation step 844.4217108554278/2000
# Simulation step 845.4222111055528/2000
# Simulation step 846.4227113556778/2000
# Simulation step 847.423211605803/2000
# Simulation step 848.423711855928/2000
# Simulation step 849.4242121060531/2000
# Simulation step 850.4247123561781/2000
# Simulation step 851.4252126063033/2000
# Simulation step 852.4257128564283/2000
# Simulation step 853.4262131065533/2000
# Simulation step 854.4267133566784/2000
# Simulation step 855.4272136068034/2000
# Simulation step 856.4277138569286/2000
# Simulation step 857.4282141070536/2000
# Simulation step 858.4287143571787/2000
# Simulation step 859.4292146073037/2000
# Simulation step 860.4297148574287/2000
# Simulation step 861.4302151075539/2000
# Simulation step 862.4307153576789/2000
# Simulation step 863.431215607804/2000
# Simulation step 864.431715857929/2000
# Simulation step 865.432216108054/2000
# Simulation step 866.4327163581792/2000
# Simulation step 867.4332166083042/2000
# Simulation step 868.4337168584293/2000
# Simulation step 869.4342171085543/2000
# Simulation step 870.4347173586794/2000
# Simulation step 871.4352176088045/2000
# Simulation step 872.4357178589295/2000
# Simulation step 873.4362181090546/2000
# Simulation step 874.4367183591796/2000
# Simulation step 875.4372186093048/2000
# Simulation step 876.4377188594298/2000
# Simulation step 877.4382191095549/2000
# Simulation step 878.4387193596799/2000
# Simulation step 879.4392196098049/2000
# Simulation step 880.43971985993/2000
# Simulation step 881.4402201100551/2000
# Simulation step 882.4407203601802/2000
# Simulation step 883.4412206103052/2000
# Simulation step 884.4417208604303/2000
# Simulation step 885.4422211105554/2000
# Simulation step 886.4427213606804/2000
# Simulation step 887.4432216108055/2000
# Simulation step 888.4437218609305/2000
# Simulation step 889.4442221110556/2000
# Simulation step 890.4447223611807/2000
# Simulation step 891.4452226113057/2000
# Simulation step 892.4457228614308/2000
# Simulation step 893.4462231115558/2000
# Simulation step 894.4467233616809/2000
# Simulation step 895.447223611806/2000
# Simulation step 896.4477238619311/2000
# Simulation step 897.4482241120561/2000
# Simulation step 898.4487243621811/2000
# Simulation step 899.4492246123062/2000
# Simulation step 900.4497248624313/2000
# Simulation step 901.4502251125564/2000
# Simulation step 902.4507253626814/2000
# Simulation step 903.4512256128065/2000
# Simulation step 904.4517258629315/2000
# Simulation step 905.4522261130566/2000
# Simulation step 906.4527263631817/2000
# Simulation step 907.4532266133067/2000
# Simulation step 908.4537268634318/2000
# Simulation step 909.4542271135568/2000
# Simulation step 910.4547273636819/2000
# Simulation step 911.455227613807/2000
# Simulation step 912.455727863932/2000
# Simulation step 913.4562281140571/2000
# Simulation step 914.4567283641821/2000
# Simulation step 915.4572286143073/2000
# Simulation step 916.4577288644323/2000
# Simulation step 917.4582291145573/2000
# Simulation step 918.4587293646824/2000
# Simulation step 919.4592296148074/2000
# Simulation step 920.4597298649326/2000
# Simulation step 921.4602301150576/2000
# Simulation step 922.4607303651827/2000
# Simulation step 923.4612306153077/2000
# Simulation step 924.4617308654327/2000
# Simulation step 925.4622311155579/2000
# Simulation step 926.4627313656829/2000
# Simulation step 927.463231615808/2000
# Simulation step 928.463731865933/2000
# Simulation step 929.4642321160582/2000
# Simulation step 930.4647323661832/2000
# Simulation step 931.4652326163082/2000
# Simulation step 932.4657328664333/2000
# Simulation step 933.4662331165583/2000
# Simulation step 934.4667333666835/2000
# Simulation step 935.4672336168085/2000
# Simulation step 936.4677338669335/2000
# Simulation step 937.4682341170586/2000
# Simulation step 938.4687343671836/2000
# Simulation step 939.4692346173088/2000
# Simulation step 940.4697348674338/2000
# Simulation step 941.4702351175589/2000
# Simulation step 942.4707353676839/2000
# Simulation step 943.4712356178089/2000
# Simulation step 944.4717358679341/2000
# Simulation step 945.4722361180591/2000
# Simulation step 946.4727363681842/2000
# Simulation step 947.4732366183092/2000
# Simulation step 948.4737368684343/2000
# Simulation step 949.4742371185594/2000
# Simulation step 950.4747373686844/2000
# Simulation step 951.4752376188095/2000
# Simulation step 952.4757378689345/2000
# Simulation step 953.4762381190596/2000
# Simulation step 954.4767383691847/2000
# Simulation step 955.4772386193097/2000
# Simulation step 956.4777388694348/2000
# Simulation step 957.4782391195598/2000
# Simulation step 958.478739369685/2000
# Simulation step 959.47923961981/2000
# Simulation step 960.4797398699351/2000
# Simulation step 961.4802401200601/2000
# Simulation step 962.4807403701851/2000
# Simulation step 963.4812406203102/2000
# Simulation step 964.4817408704353/2000
# Simulation step 965.4822411205604/2000
# Simulation step 966.4827413706854/2000
# Simulation step 967.4832416208105/2000
# Simulation step 968.4837418709355/2000
# Simulation step 969.4842421210606/2000
# Simulation step 970.4847423711857/2000
# Simulation step 971.4852426213107/2000
# Simulation step 972.4857428714358/2000
# Simulation step 973.4862431215608/2000
# Simulation step 974.4867433716859/2000
# Simulation step 975.487243621811/2000
# Simulation step 976.487743871936/2000
# Simulation step 977.4882441220611/2000
# Simulation step 978.4887443721861/2000
# Simulation step 979.4892446223113/2000
# Simulation step 980.4897448724363/2000
# Simulation step 981.4902451225613/2000
# Simulation step 982.4907453726864/2000
# Simulation step 983.4912456228114/2000
# Simulation step 984.4917458729366/2000
# Simulation step 985.4922461230616/2000
# Simulation step 986.4927463731867/2000
# Simulation step 987.4932466233117/2000
# Simulation step 988.4937468734367/2000
# Simulation step 989.4942471235619/2000
# Simulation step 990.4947473736869/2000
# Simulation step 991.495247623812/2000
# Simulation step 992.495747873937/2000
# Simulation step 993.496248124062/2000
# Simulation step 994.4967483741872/2000
# Simulation step 995.4972486243122/2000
# Simulation step 996.4977488744373/2000
# Simulation step 997.4982491245623/2000
# Simulation step 998.4987493746875/2000
# Simulation step 999.4992496248125/2000
# Simulation step 1000.4997498749375/2000
# Simulation step 1001.5002501250626/2000
# Simulation step 1002.5007503751876/2000
# Simulation step 1003.5012506253128/2000
# Simulation step 1004.5017508754378/2000
# Simulation step 1005.5022511255629/2000
# Simulation step 1006.5027513756879/2000
# Simulation step 1007.5032516258129/2000
# Simulation step 1008.5037518759381/2000
# Simulation step 1009.5042521260631/2000
# Simulation step 1010.5047523761882/2000
# Simulation step 1011.5052526263132/2000
# Simulation step 1012.5057528764384/2000
# Simulation step 1013.5062531265634/2000
# Simulation step 1014.5067533766884/2000
# Simulation step 1015.5072536268135/2000
# Simulation step 1016.5077538769385/2000
# Simulation step 1017.5082541270637/2000
# Simulation step 1018.5087543771887/2000
# Simulation step 1019.5092546273137/2000
# Simulation step 1020.5097548774388/2000
# Simulation step 1021.5102551275638/2000
# Simulation step 1022.510755377689/2000
# Simulation step 1023.511255627814/2000
# Simulation step 1024.511755877939/2000
# Simulation step 1025.512256128064/2000
# Simulation step 1026.5127563781891/2000
# Simulation step 1027.5132566283141/2000
# Simulation step 1028.5137568784394/2000
# Simulation step 1029.5142571285644/2000
# Simulation step 1030.5147573786894/2000
# Simulation step 1031.5152576288144/2000
# Simulation step 1032.5157578789394/2000
# Simulation step 1033.5162581290647/2000
# Simulation step 1034.5167583791897/2000
# Simulation step 1035.5172586293147/2000
# Simulation step 1036.5177588794397/2000
# Simulation step 1037.518259129565/2000
# Simulation step 1038.51875937969/2000
# Simulation step 1039.519259629815/2000
# Simulation step 1040.51975987994/2000
# Simulation step 1041.520260130065/2000
# Simulation step 1042.5207603801903/2000
# Simulation step 1043.5212606303153/2000
# Simulation step 1044.5217608804403/2000
# Simulation step 1045.5222611305653/2000
# Simulation step 1046.5227613806903/2000
# Simulation step 1047.5232616308156/2000
# Simulation step 1048.5237618809406/2000
# Simulation step 1049.5242621310656/2000
# Simulation step 1050.5247623811906/2000
# Simulation step 1051.5252626313156/2000
# Simulation step 1052.5257628814409/2000
# Simulation step 1053.5262631315659/2000
# Simulation step 1054.526763381691/2000
# Simulation step 1055.527263631816/2000
# Simulation step 1056.5277638819412/2000
# Simulation step 1057.5282641320662/2000
# Simulation step 1058.5287643821912/2000
# Simulation step 1059.5292646323162/2000
# Simulation step 1060.5297648824412/2000
# Simulation step 1061.5302651325665/2000
# Simulation step 1062.5307653826915/2000
# Simulation step 1063.5312656328165/2000
# Simulation step 1064.5317658829415/2000
# Simulation step 1065.5322661330665/2000
# Simulation step 1066.5327663831918/2000
# Simulation step 1067.5332666333168/2000
# Simulation step 1068.5337668834418/2000
# Simulation step 1069.5342671335668/2000
# Simulation step 1070.5347673836918/2000
# Simulation step 1071.535267633817/2000
# Simulation step 1072.535767883942/2000
# Simulation step 1073.536268134067/2000
# Simulation step 1074.536768384192/2000
# Simulation step 1075.5372686343173/2000
# Simulation step 1076.5377688844424/2000
# Simulation step 1077.5382691345674/2000
# Simulation step 1078.5387693846924/2000
# Simulation step 1079.5392696348174/2000
# Simulation step 1080.5397698849426/2000
# Simulation step 1081.5402701350677/2000
# Simulation step 1082.5407703851927/2000
# Simulation step 1083.5412706353177/2000
# Simulation step 1084.5417708854427/2000
# Simulation step 1085.542271135568/2000
# Simulation step 1086.542771385693/2000
# Simulation step 1087.543271635818/2000
# Simulation step 1088.543771885943/2000
# Simulation step 1089.5442721360682/2000
# Simulation step 1090.5447723861932/2000
# Simulation step 1091.5452726363183/2000
# Simulation step 1092.5457728864433/2000
# Simulation step 1093.5462731365683/2000
# Simulation step 1094.5467733866935/2000
# Simulation step 1095.5472736368185/2000
# Simulation step 1096.5477738869436/2000
# Simulation step 1097.5482741370686/2000
# Simulation step 1098.5487743871936/2000
# Simulation step 1099.5492746373188/2000
# Simulation step 1100.5497748874438/2000
# Simulation step 1101.5502751375689/2000
# Simulation step 1102.5507753876939/2000
# Simulation step 1103.551275637819/2000
# Simulation step 1104.5517758879441/2000
# Simulation step 1105.5522761380691/2000
# Simulation step 1106.5527763881942/2000
# Simulation step 1107.5532766383192/2000
# Simulation step 1108.5537768884444/2000
# Simulation step 1109.5542771385694/2000
# Simulation step 1110.5547773886944/2000
# Simulation step 1111.5552776388195/2000
# Simulation step 1112.5557778889445/2000
# Simulation step 1113.5562781390697/2000
# Simulation step 1114.5567783891947/2000
# Simulation step 1115.5572786393197/2000
# Simulation step 1116.5577788894448/2000
# Simulation step 1117.5582791395698/2000
# Simulation step 1118.558779389695/2000
# Simulation step 1119.55927963982/2000
# Simulation step 1120.559779889945/2000
# Simulation step 1121.56028014007/2000
# Simulation step 1122.560780390195/2000
# Simulation step 1123.5612806403203/2000
# Simulation step 1124.5617808904453/2000
# Simulation step 1125.5622811405703/2000
# Simulation step 1126.5627813906954/2000
# Simulation step 1127.5632816408206/2000
# Simulation step 1128.5637818909456/2000
# Simulation step 1129.5642821410706/2000
# Simulation step 1130.5647823911956/2000
# Simulation step 1131.5652826413207/2000
# Simulation step 1132.565782891446/2000
# Simulation step 1133.566283141571/2000
# Simulation step 1134.566783391696/2000
# Simulation step 1135.567283641821/2000
# Simulation step 1136.567783891946/2000
# Simulation step 1137.5682841420712/2000
# Simulation step 1138.5687843921962/2000
# Simulation step 1139.5692846423212/2000
# Simulation step 1140.5697848924463/2000
# Simulation step 1141.5702851425713/2000
# Simulation step 1142.5707853926965/2000
# Simulation step 1143.5712856428215/2000
# Simulation step 1144.5717858929465/2000
# Simulation step 1145.5722861430716/2000
# Simulation step 1146.5727863931968/2000
# Simulation step 1147.5732866433218/2000
# Simulation step 1148.5737868934468/2000
# Simulation step 1149.5742871435718/2000
# Simulation step 1150.5747873936969/2000
# Simulation step 1151.575287643822/2000
# Simulation step 1152.575787893947/2000
# Simulation step 1153.5762881440721/2000
# Simulation step 1154.5767883941971/2000
# Simulation step 1155.5772886443222/2000
# Simulation step 1156.5777888944474/2000
# Simulation step 1157.5782891445724/2000
# Simulation step 1158.5787893946974/2000
# Simulation step 1159.5792896448224/2000
# Simulation step 1160.5797898949475/2000
# Simulation step 1161.5802901450727/2000
# Simulation step 1162.5807903951977/2000
# Simulation step 1163.5812906453227/2000
# Simulation step 1164.5817908954477/2000
# Simulation step 1165.582291145573/2000
# Simulation step 1166.582791395698/2000
# Simulation step 1167.583291645823/2000
# Simulation step 1168.583791895948/2000
# Simulation step 1169.584292146073/2000
# Simulation step 1170.5847923961983/2000
# Simulation step 1171.5852926463233/2000
# Simulation step 1172.5857928964483/2000
# Simulation step 1173.5862931465733/2000
# Simulation step 1174.5867933966983/2000
# Simulation step 1175.5872936468236/2000
# Simulation step 1176.5877938969486/2000
# Simulation step 1177.5882941470736/2000
# Simulation step 1178.5887943971986/2000
# Simulation step 1179.5892946473236/2000
# Simulation step 1180.5897948974489/2000
# Simulation step 1181.590295147574/2000
# Simulation step 1182.590795397699/2000
# Simulation step 1183.591295647824/2000
# Simulation step 1184.5917958979492/2000
# Simulation step 1185.5922961480742/2000
# Simulation step 1186.5927963981992/2000
# Simulation step 1187.5932966483242/2000
# Simulation step 1188.5937968984492/2000
# Simulation step 1189.5942971485745/2000
# Simulation step 1190.5947973986995/2000
# Simulation step 1191.5952976488245/2000
# Simulation step 1192.5957978989495/2000
# Simulation step 1193.5962981490745/2000
# Simulation step 1194.5967983991998/2000
# Simulation step 1195.5972986493248/2000
# Simulation step 1196.5977988994498/2000
# Simulation step 1197.5982991495748/2000
# Simulation step 1198.5987993996998/2000
# Simulation step 1199.599299649825/2000
# Simulation step 1200.59979989995/2000
# Simulation step 1201.600300150075/2000
# Simulation step 1202.6008004002001/2000
# Simulation step 1203.6013006503254/2000
# Simulation step 1204.6018009004504/2000
# Simulation step 1205.6023011505754/2000
# Simulation step 1206.6028014007004/2000
# Simulation step 1207.6033016508254/2000
# Simulation step 1208.6038019009507/2000
# Simulation step 1209.6043021510757/2000
# Simulation step 1210.6048024012007/2000
# Simulation step 1211.6053026513257/2000
# Simulation step 1212.6058029014507/2000
# Simulation step 1213.606303151576/2000
# Simulation step 1214.606803401701/2000
# Simulation step 1215.607303651826/2000
# Simulation step 1216.607803901951/2000
# Simulation step 1217.608304152076/2000
# Simulation step 1218.6088044022013/2000
# Simulation step 1219.6093046523263/2000
# Simulation step 1220.6098049024513/2000
# Simulation step 1221.6103051525763/2000
# Simulation step 1222.6108054027015/2000
# ...
# Simulation step 1601.8004002001003/2000
# Simulation step 1602.8009004502253/2000
# Simulation step 1603.8014007003503/2000
# Simulation step 1604.8019009504753/2000
# Simulation step 1605.8024012006003/2000
# Simulation step 1606.8029014507256/2000
# Simulation step 1607.8034017008506/2000
# Simulation step 1608.8039019509756/2000
# Simulation step 1609.8044022011006/2000
# Simulation step 1610.8049024512256/2000
# Simulation step 1611.8054027013509/2000
# Simulation step 1612.805902951476/2000
# Simulation step 1613.806403201601/2000
# Simulation step 1614.806903451726/2000
# Simulation step 1615.807403701851/2000
# Simulation step 1616.8079039519762/2000
# Simulation step 1617.8084042021012/2000
# Simulation step 1618.8089044522262/2000
# Simulation step 1619.8094047023512/2000
# Simulation step 1620.8099049524765/2000
# Simulation step 1621.8104052026015/2000
# Simulation step 1622.8109054527265/2000
# Simulation step 1623.8114057028515/2000
# Simulation step 1624.8119059529765/2000
# Simulation step 1625.8124062031018/2000
# Simulation step 1626.8129064532268/2000
# Simulation step 1627.8134067033518/2000
# Simulation step 1628.8139069534768/2000
# Simulation step 1629.8144072036018/2000
# Simulation step 1630.814907453727/2000
# Simulation step 1631.815407703852/2000
# Simulation step 1632.815907953977/2000
# Simulation step 1633.8164082041021/2000
# Simulation step 1634.8169084542271/2000
# Simulation step 1635.8174087043524/2000
# Simulation step 1636.8179089544774/2000
# Simulation step 1637.8184092046024/2000
# Simulation step 1638.8189094547274/2000
# Simulation step 1639.8194097048527/2000
# Simulation step 1640.8199099549777/2000
# Simulation step 1641.8204102051027/2000
# Simulation step 1642.8209104552277/2000
# Simulation step 1643.8214107053527/2000
# Simulation step 1644.821910955478/2000
# Simulation step 1645.822411205603/2000
# Simulation step 1646.822911455728/2000
# Simulation step 1647.823411705853/2000
# Simulation step 1648.823911955978/2000
# Simulation step 1649.8244122061033/2000
# Simulation step 1650.8249124562283/2000
# Simulation step 1651.8254127063533/2000
# Simulation step 1652.8259129564783/2000
# Simulation step 1653.8264132066033/2000
# Simulation step 1654.8269134567286/2000
# Simulation step 1655.8274137068536/2000
# Simulation step 1656.8279139569786/2000
# Simulation step 1657.8284142071036/2000
# Simulation step 1658.8289144572288/2000
# Simulation step 1659.8294147073539/2000
# Simulation step 1660.8299149574789/2000
# Simulation step 1661.830415207604/2000
# Simulation step 1662.830915457729/2000
# Simulation step 1663.8314157078541/2000
# Simulation step 1664.8319159579792/2000
# Simulation step 1665.8324162081042/2000
# Simulation step 1666.8329164582292/2000
# Simulation step 1667.8334167083542/2000
# Simulation step 1668.8339169584794/2000
# Simulation step 1669.8344172086045/2000
# Simulation step 1670.8349174587295/2000
# Simulation step 1671.8354177088545/2000
# Simulation step 1672.8359179589795/2000
# Simulation step 1673.8364182091047/2000
# Simulation step 1674.8369184592298/2000
# Simulation step 1675.8374187093548/2000
# Simulation step 1676.8379189594798/2000
# Simulation step 1677.838419209605/2000
# Simulation step 1678.83891945973/2000
# Simulation step 1679.839419709855/2000
# Simulation step 1680.83991995998/2000
# Simulation step 1681.840420210105/2000
# Simulation step 1682.8409204602303/2000
# Simulation step 1683.8414207103554/2000
# Simulation step 1684.8419209604804/2000
# Simulation step 1685.8424212106054/2000
# Simulation step 1686.8429214607304/2000
# Simulation step 1687.8434217108556/2000
# Simulation step 1688.8439219609807/2000
# Simulation step 1689.8444222111057/2000
# Simulation step 1690.8449224612307/2000
# Simulation step 1691.8454227113557/2000
# Simulation step 1692.845922961481/2000
# Simulation step 1693.846423211606/2000
# Simulation step 1694.846923461731/2000
# Simulation step 1695.847423711856/2000
# Simulation step 1696.8479239619812/2000
# Simulation step 1697.8484242121062/2000
# Simulation step 1698.8489244622313/2000
# Simulation step 1699.8494247123563/2000
# Simulation step 1700.8499249624813/2000
# Simulation step 1701.8504252126065/2000
# Simulation step 1702.8509254627315/2000
# Simulation step 1703.8514257128566/2000
# Simulation step 1704.8519259629816/2000
# Simulation step 1705.8524262131066/2000
# Simulation step 1706.8529264632318/2000
# Simulation step 1707.8534267133568/2000
# Simulation step 1708.8539269634819/2000
# Simulation step 1709.8544272136069/2000
# Simulation step 1710.8549274637319/2000
# Simulation step 1711.8554277138571/2000
# Simulation step 1712.8559279639821/2000
# Simulation step 1713.8564282141072/2000
# Simulation step 1714.8569284642322/2000
# Simulation step 1715.8574287143574/2000
# Simulation step 1716.8579289644824/2000
# Simulation step 1717.8584292146074/2000
# Simulation step 1718.8589294647325/2000
# Simulation step 1719.8594297148575/2000
# Simulation step 1720.8599299649827/2000
# Simulation step 1721.8604302151077/2000
# Simulation step 1722.8609304652327/2000
# Simulation step 1723.8614307153578/2000
# Simulation step 1724.8619309654828/2000
# Simulation step 1725.862431215608/2000
# Simulation step 1726.862931465733/2000
# Simulation step 1727.863431715858/2000
# Simulation step 1728.863931965983/2000
# Simulation step 1729.864432216108/2000
# Simulation step 1730.8649324662333/2000
# Simulation step 1731.8654327163583/2000
# Simulation step 1732.8659329664833/2000
# Simulation step 1733.8664332166084/2000
# Simulation step 1734.8669334667336/2000
# Simulation step 1735.8674337168586/2000
# Simulation step 1736.8679339669836/2000
# Simulation step 1737.8684342171086/2000
# Simulation step 1738.8689344672337/2000
# Simulation step 1739.869434717359/2000
# Simulation step 1740.869934967484/2000
# Simulation step 1741.870435217609/2000
# Simulation step 1742.870935467734/2000
# Simulation step 1743.871435717859/2000
# Simulation step 1744.8719359679842/2000
# Simulation step 1745.8724362181092/2000
# Simulation step 1746.8729364682342/2000
# Simulation step 1747.8734367183592/2000
# Simulation step 1748.8739369684845/2000
# Simulation step 1749.8744372186095/2000
# Simulation step 1750.8749374687345/2000
# Simulation step 1751.8754377188595/2000
# Simulation step 1752.8759379689845/2000
# Simulation step 1753.8764382191098/2000
# Simulation step 1754.8769384692348/2000
# Simulation step 1755.8774387193598/2000
# Simulation step 1756.8779389694848/2000
# Simulation step 1757.8784392196098/2000
# Simulation step 1758.878939469735/2000
# Simulation step 1759.87943971986/2000
# Simulation step 1760.8799399699851/2000
# Simulation step 1761.8804402201101/2000
# Simulation step 1762.8809404702351/2000
# Simulation step 1763.8814407203604/2000
# Simulation step 1764.8819409704854/2000
# Simulation step 1765.8824412206104/2000
# Simulation step 1766.8829414707354/2000
# Simulation step 1767.8834417208607/2000
# Simulation step 1768.8839419709857/2000
# Simulation step 1769.8844422211107/2000
# Simulation step 1770.8849424712357/2000
# Simulation step 1771.8854427213607/2000
# Simulation step 1772.885942971486/2000
# Simulation step 1773.886443221611/2000
# Simulation step 1774.886943471736/2000
# Simulation step 1775.887443721861/2000
# Simulation step 1776.887943971986/2000
# Simulation step 1777.8884442221113/2000
# Simulation step 1778.8889444722363/2000
# Simulation step 1779.8894447223613/2000
# Simulation step 1780.8899449724863/2000
# Simulation step 1781.8904452226113/2000
# Simulation step 1782.8909454727366/2000
# Simulation step 1783.8914457228616/2000
# Simulation step 1784.8919459729866/2000
# Simulation step 1785.8924462231116/2000
# Simulation step 1786.8929464732369/2000
# Simulation step 1787.8934467233619/2000
# Simulation step 1788.893946973487/2000
# Simulation step 1789.894447223612/2000
# Simulation step 1790.894947473737/2000
# Simulation step 1791.8954477238622/2000
# Simulation step 1792.8959479739872/2000
# Simulation step 1793.8964482241122/2000
# Simulation step 1794.8969484742372/2000
# Simulation step 1795.8974487243622/2000
# Simulation step 1796.8979489744875/2000
# Simulation step 1797.8984492246125/2000
# Simulation step 1798.8989494747375/2000
# Simulation step 1799.8994497248625/2000
# Simulation step 1800.8999499749875/2000
# Simulation step 1801.9004502251128/2000
# Simulation step 1802.9009504752378/2000
# Simulation step 1803.9014507253628/2000
# Simulation step 1804.9019509754878/2000
# Simulation step 1805.902451225613/2000
# Simulation step 1806.902951475738/2000
# Simulation step 1807.903451725863/2000
# Simulation step 1808.903951975988/2000
# Simulation step 1809.904452226113/2000
# Simulation step 1810.9049524762383/2000
# Simulation step 1811.9054527263634/2000
# Simulation step 1812.9059529764884/2000
# Simulation step 1813.9064532266134/2000
# Simulation step 1814.9069534767384/2000
# Simulation step 1815.9074537268637/2000
# Simulation step 1816.9079539769887/2000
# Simulation step 1817.9084542271137/2000
# Simulation step 1818.9089544772387/2000
# Simulation step 1819.9094547273637/2000
# Simulation step 1820.909954977489/2000
# Simulation step 1821.910455227614/2000
# Simulation step 1822.910955477739/2000
# Simulation step 1823.911455727864/2000
# Simulation step 1824.9119559779892/2000
# Simulation step 1825.9124562281143/2000
# Simulation step 1826.9129564782393/2000
# Simulation step 1827.9134567283643/2000
# Simulation step 1828.9139569784893/2000
# Simulation step 1829.9144572286145/2000
# Simulation step 1830.9149574787396/2000
# Simulation step 1831.9154577288646/2000
# Simulation step 1832.9159579789896/2000
# Simulation step 1833.9164582291146/2000
# Simulation step 1834.9169584792398/2000
# Simulation step 1835.9174587293649/2000
# Simulation step 1836.9179589794899/2000
# Simulation step 1837.9184592296149/2000
# Simulation step 1838.91895947974/2000
# Simulation step 1839.9194597298651/2000
# Simulation step 1840.9199599799902/2000
# Simulation step 1841.9204602301152/2000
# Simulation step 1842.9209604802402/2000
# Simulation step 1843.9214607303654/2000
# Simulation step 1844.9219609804904/2000
# Simulation step 1845.9224612306155/2000
# Simulation step 1846.9229614807405/2000
# Simulation step 1847.9234617308655/2000
# Simulation step 1848.9239619809907/2000
# Simulation step 1849.9244622311157/2000
# Simulation step 1850.9249624812408/2000
# Simulation step 1851.9254627313658/2000
# Simulation step 1852.9259629814908/2000
# Simulation step 1853.926463231616/2000
# Simulation step 1854.926963481741/2000
# Simulation step 1855.927463731866/2000
# Simulation step 1856.927963981991/2000
# Simulation step 1857.9284642321163/2000
# Simulation step 1858.9289644822413/2000
# Simulation step 1859.9294647323663/2000
# Simulation step 1860.9299649824914/2000
# Simulation step 1861.9304652326164/2000
# Simulation step 1862.9309654827416/2000
# Simulation step 1863.9314657328666/2000
# Simulation step 1864.9319659829916/2000
# Simulation step 1865.9324662331167/2000
# Simulation step 1866.9329664832417/2000
# Simulation step 1867.933466733367/2000
# Simulation step 1868.933966983492/2000
# Simulation step 1869.934467233617/2000
# Simulation step 1870.934967483742/2000
# Simulation step 1871.935467733867/2000
# Simulation step 1872.9359679839922/2000
# Simulation step 1873.9364682341172/2000
# Simulation step 1874.9369684842422/2000
# Simulation step 1875.9374687343673/2000
# Simulation step 1876.9379689844925/2000
# Simulation step 1877.9384692346175/2000
# Simulation step 1878.9389694847425/2000
# Simulation step 1879.9394697348675/2000
# Simulation step 1880.9399699849926/2000
# Simulation step 1881.9404702351178/2000
# Simulation step 1882.9409704852428/2000
# Simulation step 1883.9414707353678/2000
# Simulation step 1884.9419709854928/2000
# Simulation step 1885.9424712356179/2000
# Simulation step 1886.942971485743/2000
# Simulation step 1887.9434717358681/2000
# Simulation step 1888.9439719859931/2000
# Simulation step 1889.9444722361181/2000
# Simulation step 1890.9449724862432/2000
# Simulation step 1891.9454727363684/2000
# Simulation step 1892.9459729864934/2000
# Simulation step 1893.9464732366184/2000
# Simulation step 1894.9469734867434/2000
# Simulation step 1895.9474737368687/2000
# Simulation step 1896.9479739869937/2000
# Simulation step 1897.9484742371187/2000
# Simulation step 1898.9489744872437/2000
# Simulation step 1899.9494747373687/2000
# Simulation step 1900.949974987494/2000
# Simulation step 1901.950475237619/2000
# Simulation step 1902.950975487744/2000
# Simulation step 1903.951475737869/2000
# Simulation step 1904.951975987994/2000
# Simulation step 1905.9524762381193/2000
# Simulation step 1906.9529764882443/2000
# Simulation step 1907.9534767383693/2000
# Simulation step 1908.9539769884943/2000
# Simulation step 1909.9544772386193/2000
# Simulation step 1910.9549774887446/2000
# Simulation step 1911.9554777388696/2000
# Simulation step 1912.9559779889946/2000
# Simulation step 1913.9564782391196/2000
# Simulation step 1914.9569784892449/2000
# Simulation step 1915.95747873937/2000
# Simulation step 1916.957978989495/2000
# Simulation step 1917.95847923962/2000
# Simulation step 1918.958979489745/2000
# Simulation step 1919.9594797398702/2000
# Simulation step 1920.9599799899952/2000
# Simulation step 1921.9604802401202/2000
# Simulation step 1922.9609804902452/2000
# Simulation step 1923.9614807403702/2000
# Simulation step 1924.9619809904955/2000
# Simulation step 1925.9624812406205/2000
# Simulation step 1926.9629814907455/2000
# Simulation step 1927.9634817408705/2000
# Simulation step 1928.9639819909955/2000
# Simulation step 1929.9644822411208/2000
# Simulation step 1930.9649824912458/2000
# Simulation step 1931.9654827413708/2000
# Simulation step 1932.9659829914958/2000
# Simulation step 1933.966483241621/2000
# Simulation step 1934.966983491746/2000
# Simulation step 1935.967483741871/2000
# Simulation step 1936.967983991996/2000
# Simulation step 1937.9684842421211/2000
# Simulation step 1938.9689844922464/2000
# Simulation step 1939.9694847423714/2000
# Simulation step 1940.9699849924964/2000
# Simulation step 1941.9704852426214/2000
# Simulation step 1942.9709854927464/2000
# Simulation step 1943.9714857428717/2000
# Simulation step 1944.9719859929967/2000
# Simulation step 1945.9724862431217/2000
# Simulation step 1946.9729864932467/2000
# Simulation step 1947.9734867433717/2000
# Simulation step 1948.973986993497/2000
# Simulation step 1949.974487243622/2000
# Simulation step 1950.974987493747/2000
# Simulation step 1951.975487743872/2000
# Simulation step 1952.9759879939973/2000
# Simulation step 1953.9764882441223/2000
# Simulation step 1954.9769884942473/2000
# Simulation step 1955.9774887443723/2000
# Simulation step 1956.9779889944973/2000
# Simulation step 1957.9784892446226/2000
# Simulation step 1958.9789894947476/2000
# Simulation step 1959.9794897448726/2000
# Simulation step 1960.9799899949976/2000
# Simulation step 1961.9804902451226/2000
# Simulation step 1962.9809904952479/2000
# Simulation step 1963.9814907453729/2000
# Simulation step 1964.9819909954979/2000
# Simulation step 1965.982491245623/2000
# Simulation step 1966.982991495748/2000
# Simulation step 1967.9834917458732/2000
# Simulation step 1968.9839919959982/2000
# Simulation step 1969.9844922461232/2000
# Simulation step 1970.9849924962482/2000
# Simulation step 1971.9854927463734/2000
# Simulation step 1972.9859929964985/2000
# Simulation step 1973.9864932466235/2000
# Simulation step 1974.9869934967485/2000
# Simulation step 1975.9874937468735/2000
# Simulation step 1976.9879939969987/2000
# Simulation step 1977.9884942471238/2000
# Simulation step 1978.9889944972488/2000
# Simulation step 1979.9894947473738/2000
# Simulation step 1980.9899949974988/2000
# Simulation step 1981.990495247624/2000
# Simulation step 1982.990995497749/2000
# Simulation step 1983.991495747874/2000
# Simulation step 1984.991995997999/2000
# Simulation step 1985.992496248124/2000
# Simulation step 1986.9929964982493/2000
# Simulation step 1987.9934967483744/2000
# Simulation step 1988.9939969984994/2000
# Simulation step 1989.9944972486244/2000
# Simulation step 1990.9949974987496/2000
# Simulation step 1991.9954977488746/2000
# Simulation step 1992.9959979989997/2000
# Simulation step 1993.9964982491247/2000
# Simulation step 1994.9969984992497/2000
# Simulation step 1995.997498749375/2000
# Simulation step 1996.9979989995/2000
# Simulation step 1997.998499249625/2000
# Simulation step 1998.99899949975/2000
# Simulation step 1999.999499749875/2000
# [ 9.93109961e-01  8.60329392e-02  5.13123899e-02  6.08272771e-02
#  -4.61540746e-09 -3.32015588e-09 -4.13027528e-09]

# %%
#plot angular velocity
plt.figure(figsize=(10, 6))
plt.plot(time_sec, states[:, 4:])
plt.plot(time_sec, np.tile(0.00269, (len(time_sec), 1)), '--')
plt.xlabel('Time')
plt.ylabel('Angular Velocity')
plt.title('Angular Velocity over Time')
plt.legend(['wx', 'wy', 'wz'])
plt.show()

# %%
#plot control torques
plt.figure(figsize=(10, 6))
time_sec_control = np.linspace(0, 2000, 2000)
plt.plot(time_sec_control, control_torques_history)
plt.xlabel('Time')
plt.ylabel('Control Torques')
plt.title('Control Torques over Time')
plt.legend(['Tx', 'Ty', 'Tz'])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem, t

# Assume `states` and `control_torques` are available from the simulation
# `states` contains quaternions and angular velocities
# `control_torques` contains the control torques for each timestep

# Extract angular velocities and time from simulation data
omega = states[:, 4:]  # Extract angular velocity components
time_sec = np.linspace(0, 2000, 2000)  # Time array matching simulation

# Parameters
threshold = 1e-6
window_size = 10
confidence = 0.97

# Calculate moving averages
omega_avg = np.array([
    np.convolve(omega[:, i], np.ones(window_size) / window_size, mode='valid')
    for i in range(3)
]).T

# Calculate standard errors of the mean (SEM)
omega_sem = np.array([
    np.array([sem(omega[j:j + window_size, i]) for j in range(len(omega) - window_size + 1)])
    for i in range(3)
]).T

# Calculate confidence intervals
degrees_freedom = window_size - 1
confidence_factor = t.ppf((1 + confidence) / 2., degrees_freedom)

omega_ci = omega_sem * confidence_factor

# Check when values are within threshold
def check_stability_with_ci(omega_avg, omega_ci, threshold, window_size):
    for i in range(len(omega_avg)):
        if (np.all(np.abs(omega_avg[i]) < threshold) and
            np.all(omega_ci[i] < threshold)):
            return time_sec[i + window_size - 1], i + window_size - 1
    return -1, -1

stable_time_step, stable_index = check_stability_with_ci(omega_avg, omega_ci, threshold, window_size)

print(f"The system stabilizes at time step: {stable_time_step} seconds")

# Plot angular velocities over time with a marker for stability time
plt.figure(figsize=(12, 8))
plt.plot(time_sec, omega[:, 0], label='Omega x')
plt.plot(time_sec, omega[:, 1], label='Omega y')
plt.plot(time_sec, omega[:, 2], label='Omega z')
if stable_time_step != -1:
    plt.axvline(x=stable_time_step, color='r', linestyle='--', label='Stability Time')
plt.xlabel('Time (s)')
plt.ylabel('Angular Velocities (rad/s)')
plt.title('Angular Velocities Over Time')
plt.legend()
plt.grid(True)
plt.show()

# Plot moving averages with confidence intervals
plt.figure(figsize=(12, 8))
plt.plot(time_sec[window_size - 1:], omega_avg[:, 0], label='Omega x Average')
plt.fill_between(time_sec[window_size - 1:], omega_avg[:, 0] - omega_ci[:, 0], omega_avg[:, 0] + omega_ci[:, 0], alpha=0.3)
plt.plot(time_sec[window_size - 1:], omega_avg[:, 1], label='Omega y Average')
plt.fill_between(time_sec[window_size - 1:], omega_avg[:, 1] - omega_ci[:, 1], omega_avg[:, 1] + omega_ci[:, 1], alpha=0.3)
plt.plot(time_sec[window_size - 1:], omega_avg[:, 2], label='Omega z Average')
plt.fill_between(time_sec[window_size - 1:], omega_avg[:, 2] - omega_ci[:, 2], omega_avg[:, 2] + omega_ci[:, 2], alpha=0.3)
if stable_time_step != -1:
    plt.axvline(x=stable_time_step, color='r', linestyle='--', label='Stability Time')
plt.xlabel('Time (s)')
plt.ylabel('Average Angular Velocities (rad/s)')
plt.title('Moving Averages of Angular Velocities with Confidence Intervals')
plt.legend()
plt.grid(True)
plt.show()

# Plot quaternion components over time with stability time
plt.figure(figsize=(12, 8))
plt.plot(time_sec, states[:, 0], label='q0')
plt.plot(time_sec, states[:, 1], label='q1')
plt.plot(time_sec, states[:, 2], label='q2')
plt.plot(time_sec, states[:, 3], label='q3')
if stable_time_step != -1:
    plt.axvline(x=stable_time_step, color='r', linestyle='--', label='Stability Time')
plt.xlabel('Time (s)')
plt.ylabel('Quaternion Components')
plt.title('Quaternion Over Time')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# The system stabilizes at time step: 713.3566783391697 seconds

# %% [markdown]
# Save to csv

# %%
# save to csv
import pandas as pd
from datetime import datetime

control_torques_history = np.array(control_torques_history)
# Exporting the data into a csv file
def save_simulation_to_csv(filename):
    data = {
        'time': time_history,
        'q0': states[:, 0],
        'q1': states[:, 1],
        'q2': states[:, 2],
        'q3': states[:, 3],
        'omega_x': states[:, 4],
        'omega_y': states[:, 5],
        'omega_z': states[:, 6],
        'Total_torque_x': control_torques_history[:, 0],
        'Total_torque_y': control_torques_history[:, 1],
        'Total_torque_z': control_torques_history[:, 2],
    }
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)

date_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
file_name = f"satellite_attitude_control_PID_RK4_OPTIMALTuned_P2P_{date_time}.csv"
save_simulation_to_csv(file_name)

# %% [markdown]
# ### Optimiser function

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem, t as t_distribution
from itertools import product

def quaternion_product(q, p):
    w0, x0, y0, z0 = q
    w1, x1, y1, z1 = p
    return np.array([
        w0*w1 - x0*x1 - y0*y1 - z0*z1,
        w0*x1 + x0*w1 + y0*z1 - z0*y1,
        w0*y1 - x0*z1 + y0*w1 + z0*x1,
        w0*z1 + x0*y1 - y0*x1 + z0*w1
    ])

def quaternion_conjugate(q):
    return np.array([q[0], -q[1], -q[2], -q[3]])

def quaternion_error(q, q_target):
    return quaternion_product(quaternion_conjugate(q), q_target)

def pid_control(q, omega, q_target, integral_error, prev_error, dt, Kp, Ki, Kd):
    error = 2*quaternion_error(q, q_target)[1:]  # Vector part of the quaternion error
    
    integral_error += error * dt
    derivative_error = (error - prev_error) / dt
    
    control_torque = Kp * error + Ki * integral_error + Kd * derivative_error

    return control_torque, integral_error, error

def dynamics(t, state, integral_error, prev_error, dt, I, inv_I, q_target, Kp, Ki, Kd):
    q = state[:4]
    omega = state[4:]

    q = q / np.linalg.norm(q)  # Normalize quaternion

    dqdt = 0.5 * quaternion_product(q, np.append([0], omega))
    
    control_torque, integral_error, prev_error = pid_control(q, omega, q_target, integral_error, prev_error, dt, Kp, Ki, Kd)
    
    omega_cross_I_omega = np.cross(omega, I @ omega)
    dwdt = inv_I @ (control_torque - omega_cross_I_omega)

    return np.concatenate([dqdt, dwdt]), integral_error, prev_error

def rk4_step(dynamics_func, t, state, dt, integral_error, prev_error, I, inv_I, q_target, Kp, Ki, Kd):
    k1, integral_error1, prev_error1 = dynamics_func(t, state, integral_error, prev_error, dt, I, inv_I, q_target, Kp, Ki, Kd)
    k2, integral_error2, prev_error2 = dynamics_func(t + 0.5 * dt, state + 0.5 * dt * k1, integral_error1, prev_error1, dt, I, inv_I, q_target, Kp, Ki, Kd)
    k3, integral_error3, prev_error3 = dynamics_func(t + 0.5 * dt, state + 0.5 * dt * k2, integral_error2, prev_error2, dt, I, inv_I, q_target, Kp, Ki, Kd)
    k4, integral_error4, prev_error4 = dynamics_func(t + dt, state + dt * k3, integral_error3, prev_error3, dt, I, inv_I, q_target, Kp, Ki, Kd)

    new_state = state + (dt / 6) * (k1 + 2 * k2 + 2 * k3 + k4)
    return new_state, integral_error4, prev_error4

def run_simulation(Kp, Ki, Kd, max_time=2000, dt=1, angular_velocity_bound=0.00269):
    # Initialize simulation
    Ix, Iy, Iz = 1191, 1844, 1798
    I = np.diag([Ix, Iy, Iz])
    inv_I = np.linalg.inv(I)

    q_target = np.array([0.9938, 0.086, 0.0513, 0.0608])
    q_target = q_target / np.linalg.norm(q_target)

    q0 = np.array([1, 0, 0, 0])
    q0 = q0 / np.linalg.norm(q0)
    omega0 = np.array([0, 0, 0])
    state0 = np.concatenate([q0, omega0])

    t_eval = np.arange(0, max_time, dt)
    
    integral_error = np.zeros(3)
    prev_error = np.zeros(3)
    
    states = [state0]
    
    for t in t_eval[:-1]:
        new_state, integral_error, prev_error = rk4_step(dynamics, t, states[-1], dt, integral_error, prev_error, I, inv_I, q_target, Kp, Ki, Kd)
        states.append(new_state)
        
        # Check if angular velocity exceeds the bound
        if np.any(np.abs(new_state[4:]) > angular_velocity_bound):
            return max_time, False  # Return max time and flag for exceeding bound
    
    states = np.array(states)
    omega = states[:, 4:]
    
    # Check stability
    threshold = 1e-5
    window_size = 10
    confidence = 0.97
    
    omega_avg = np.array([
        np.convolve(omega[:, i], np.ones(window_size) / window_size, mode='valid')
        for i in range(3)
    ]).T
    
    omega_sem = np.array([
        np.array([sem(omega[j:j + window_size, i]) for j in range(len(omega) - window_size + 1)])
        for i in range(3)
    ]).T
    
    degrees_freedom = window_size - 1
    confidence_factor = t_distribution.ppf((1 + confidence) / 2., degrees_freedom)
    omega_ci = omega_sem * confidence_factor
    
    for i in range(len(omega_avg)):
        if (np.all(np.abs(omega_avg[i]) < threshold) and
            np.all(omega_ci[i] < threshold)):
            return (i + window_size - 1) * dt, True  # Return stabilization time and success flag
    
    return max_time, True  # If not stabilized, return max time and success flag

def optimize_pid_gains():
    # Define the range for each gain
    kp_range = np.linspace(0.1, 0.4, 50)
    ki_range = np.linspace(0.000001, 0.000001, 1)
    kd_range = np.linspace(90, 120.0, 100)
    
    best_time = float('inf')
    best_gains = None
    
    total_combinations = len(kp_range) * len(ki_range) * len(kd_range)
    current_combination = 0
    max_time = 2000
    valid_solutions = 0
    exceeded_velocity_bound = 0
    didnt_stabilize = 0

    for kp, ki, kd in product(kp_range, ki_range, kd_range):
        current_combination += 1
        print(f"Testing combination {current_combination}/{total_combinations}")
        
        Kp = np.array([kp, kp, kp])
        Ki = np.array([ki, ki, ki])
        Kd = np.array([kd, kd, kd])
        
        stabilization_time, within_bound = run_simulation(Kp, Ki, Kd)
        
        if within_bound:
            if stabilization_time < max_time:  # max_time
                valid_solutions += 1
                if stabilization_time < best_time:
                    best_time = stabilization_time
                    best_gains = (Kp, Ki, Kd)
            else:
                didnt_stabilize += 1
        else:
            exceeded_velocity_bound += 1

    print(f"Valid solutions: {valid_solutions}")
    print(f"Solutions that exceeded velocity bound: {exceeded_velocity_bound}")
    print(f"Solutions that didn't stabilize in time: {didnt_stabilize}")
        
    return best_gains, best_time

# Run the optimization
best_gains, best_time = optimize_pid_gains()

if best_gains is not None:
    print(f"Best gains: Kp = {best_gains[0]}, Ki = {best_gains[1]}, Kd = {best_gains[2]}")
    print(f"Best stabilization time: {best_time} seconds")
else:
    print("No valid solution found. All tested combinations either exceeded the angular velocity bound or didn't stabilize within the maximum time.")
# Out:
# Testing combination 1/5000
# Testing combination 2/5000
# Testing combination 3/5000
# Testing combination 4/5000
# Testing combination 5/5000
# Testing combination 6/5000
# Testing combination 7/5000
# Testing combination 8/5000
# Testing combination 9/5000
# Testing combination 10/5000
# Testing combination 11/5000
# Testing combination 12/5000
# Testing combination 13/5000
# Testing combination 14/5000
# Testing combination 15/5000
# Testing combination 16/5000
# Testing combination 17/5000
# Testing combination 18/5000
# Testing combination 19/5000
# Testing combination 20/5000
# Testing combination 21/5000
# Testing combination 22/5000
# Testing combination 23/5000
# Testing combination 24/5000
# Testing combination 25/5000
# Testing combination 26/5000
# Testing combination 27/5000
# Testing combination 28/5000
# Testing combination 29/5000
# Testing combination 30/5000
# Testing combination 31/5000
# Testing combination 32/5000
# Testing combination 33/5000
# Testing combination 34/5000
# Testing combination 35/5000
# Testing combination 36/5000
# Testing combination 37/5000
# Testing combination 38/5000
# Testing combination 39/5000
# Testing combination 40/5000
# Testing combination 41/5000
# Testing combination 42/5000
# Testing combination 43/5000
# Testing combination 44/5000
# Testing combination 45/5000
# Testing combination 46/5000
# Testing combination 47/5000
# Testing combination 48/5000
# Testing combination 49/5000
# Testing combination 50/5000
# Testing combination 51/5000
# Testing combination 52/5000
# Testing combination 53/5000
# Testing combination 54/5000
# Testing combination 55/5000
# Testing combination 56/5000
# Testing combination 57/5000
# Testing combination 58/5000
# Testing combination 59/5000
# Testing combination 60/5000
# Testing combination 61/5000
# Testing combination 62/5000
# Testing combination 63/5000
# Testing combination 64/5000
# Testing combination 65/5000
# Testing combination 66/5000
# Testing combination 67/5000
# Testing combination 68/5000
# Testing combination 69/5000
# Testing combination 70/5000
# Testing combination 71/5000
# Testing combination 72/5000
# Testing combination 73/5000
# Testing combination 74/5000
# Testing combination 75/5000
# Testing combination 76/5000
# Testing combination 77/5000
# Testing combination 78/5000
# Testing combination 79/5000
# Testing combination 80/5000
# Testing combination 81/5000
# Testing combination 82/5000
# Testing combination 83/5000
# Testing combination 84/5000
# Testing combination 85/5000
# Testing combination 86/5000
# Testing combination 87/5000
# Testing combination 88/5000
# Testing combination 89/5000
# Testing combination 90/5000
# Testing combination 91/5000
# Testing combination 92/5000
# Testing combination 93/5000
# Testing combination 94/5000
# Testing combination 95/5000
# Testing combination 96/5000
# Testing combination 97/5000
# Testing combination 98/5000
# Testing combination 99/5000
# Testing combination 100/5000
# Testing combination 101/5000
# Testing combination 102/5000
# Testing combination 103/5000
# Testing combination 104/5000
# Testing combination 105/5000
# Testing combination 106/5000
# Testing combination 107/5000
# Testing combination 108/5000
# Testing combination 109/5000
# Testing combination 110/5000
# Testing combination 111/5000
# Testing combination 112/5000
# Testing combination 113/5000
# Testing combination 114/5000
# Testing combination 115/5000
# Testing combination 116/5000
# Testing combination 117/5000
# Testing combination 118/5000
# Testing combination 119/5000
# Testing combination 120/5000
# Testing combination 121/5000
# Testing combination 122/5000
# Testing combination 123/5000
# Testing combination 124/5000
# Testing combination 125/5000
# Testing combination 126/5000
# Testing combination 127/5000
# Testing combination 128/5000
# Testing combination 129/5000
# Testing combination 130/5000
# Testing combination 131/5000
# Testing combination 132/5000
# Testing combination 133/5000
# Testing combination 134/5000
# Testing combination 135/5000
# Testing combination 136/5000
# Testing combination 137/5000
# Testing combination 138/5000
# Testing combination 139/5000
# Testing combination 140/5000
# Testing combination 141/5000
# Testing combination 142/5000
# Testing combination 143/5000
# Testing combination 144/5000
# Testing combination 145/5000
# Testing combination 146/5000
# Testing combination 147/5000
# Testing combination 148/5000
# Testing combination 149/5000
# Testing combination 150/5000
# Testing combination 151/5000
# Testing combination 152/5000
# Testing combination 153/5000
# Testing combination 154/5000
# Testing combination 155/5000
# Testing combination 156/5000
# Testing combination 157/5000
# Testing combination 158/5000
# Testing combination 159/5000
# Testing combination 160/5000
# Testing combination 161/5000
# Testing combination 162/5000
# Testing combination 163/5000
# Testing combination 164/5000
# Testing combination 165/5000
# Testing combination 166/5000
# Testing combination 167/5000
# Testing combination 168/5000
# Testing combination 169/5000
# Testing combination 170/5000
# Testing combination 171/5000
# Testing combination 172/5000
# Testing combination 173/5000
# Testing combination 174/5000
# Testing combination 175/5000
# Testing combination 176/5000
# Testing combination 177/5000
# Testing combination 178/5000
# Testing combination 179/5000
# Testing combination 180/5000
# Testing combination 181/5000
# Testing combination 182/5000
# Testing combination 183/5000
# Testing combination 184/5000
# Testing combination 185/5000
# Testing combination 186/5000
# Testing combination 187/5000
# Testing combination 188/5000
# Testing combination 189/5000
# Testing combination 190/5000
# Testing combination 191/5000
# Testing combination 192/5000
# Testing combination 193/5000
# Testing combination 194/5000
# Testing combination 195/5000
# Testing combination 196/5000
# Testing combination 197/5000
# Testing combination 198/5000
# Testing combination 199/5000
# Testing combination 200/5000
# Testing combination 201/5000
# Testing combination 202/5000
# Testing combination 203/5000
# Testing combination 204/5000
# Testing combination 205/5000
# Testing combination 206/5000
# Testing combination 207/5000
# Testing combination 208/5000
# Testing combination 209/5000
# Testing combination 210/5000
# Testing combination 211/5000
# Testing combination 212/5000
# Testing combination 213/5000
# Testing combination 214/5000
# Testing combination 215/5000
# Testing combination 216/5000
# Testing combination 217/5000
# Testing combination 218/5000
# Testing combination 219/5000
# Testing combination 220/5000
# Testing combination 221/5000
# Testing combination 222/5000
# Testing combination 223/5000
# Testing combination 224/5000
# Testing combination 225/5000
# Testing combination 226/5000
# Testing combination 227/5000
# Testing combination 228/5000
# Testing combination 229/5000
# Testing combination 230/5000
# Testing combination 231/5000
# Testing combination 232/5000
# Testing combination 233/5000
# Testing combination 234/5000
# Testing combination 235/5000
# Testing combination 236/5000
# Testing combination 237/5000
# Testing combination 238/5000
# Testing combination 239/5000
# Testing combination 240/5000
# Testing combination 241/5000
# Testing combination 242/5000
# Testing combination 243/5000
# Testing combination 244/5000
# Testing combination 245/5000
# Testing combination 246/5000
# Testing combination 247/5000
# Testing combination 248/5000
# Testing combination 249/5000
# Testing combination 250/5000
# Testing combination 251/5000
# Testing combination 252/5000
# Testing combination 253/5000
# Testing combination 254/5000
# Testing combination 255/5000
# Testing combination 256/5000
# Testing combination 257/5000
# Testing combination 258/5000
# Testing combination 259/5000
# Testing combination 260/5000
# Testing combination 261/5000
# Testing combination 262/5000
# Testing combination 263/5000
# Testing combination 264/5000
# Testing combination 265/5000
# Testing combination 266/5000
# Testing combination 267/5000
# Testing combination 268/5000
# Testing combination 269/5000
# Testing combination 270/5000
# Testing combination 271/5000
# Testing combination 272/5000
# Testing combination 273/5000
# Testing combination 274/5000
# Testing combination 275/5000
# Testing combination 276/5000
# Testing combination 277/5000
# Testing combination 278/5000
# Testing combination 279/5000
# Testing combination 280/5000
# Testing combination 281/5000
# Testing combination 282/5000
# Testing combination 283/5000
# Testing combination 284/5000
# Testing combination 285/5000
# Testing combination 286/5000
# Testing combination 287/5000
# Testing combination 288/5000
# Testing combination 289/5000
# Testing combination 290/5000
# Testing combination 291/5000
# Testing combination 292/5000
# Testing combination 293/5000
# Testing combination 294/5000
# Testing combination 295/5000
# Testing combination 296/5000
# Testing combination 297/5000
# Testing combination 298/5000
# Testing combination 299/5000
# Testing combination 300/5000
# Testing combination 301/5000
# Testing combination 302/5000
# Testing combination 303/5000
# Testing combination 304/5000
# Testing combination 305/5000
# Testing combination 306/5000
# Testing combination 307/5000
# Testing combination 308/5000
# Testing combination 309/5000
# Testing combination 310/5000
# Testing combination 311/5000
# Testing combination 312/5000
# Testing combination 313/5000
# Testing combination 314/5000
# Testing combination 315/5000
# Testing combination 316/5000
# Testing combination 317/5000
# Testing combination 318/5000
# Testing combination 319/5000
# Testing combination 320/5000
# Testing combination 321/5000
# Testing combination 322/5000
# Testing combination 323/5000
# Testing combination 324/5000
# Testing combination 325/5000
# Testing combination 326/5000
# Testing combination 327/5000
# Testing combination 328/5000
# Testing combination 329/5000
# Testing combination 330/5000
# Testing combination 331/5000
# Testing combination 332/5000
# Testing combination 333/5000
# Testing combination 334/5000
# Testing combination 335/5000
# Testing combination 336/5000
# Testing combination 337/5000
# Testing combination 338/5000
# Testing combination 339/5000
# Testing combination 340/5000
# Testing combination 341/5000
# Testing combination 342/5000
# Testing combination 343/5000
# Testing combination 344/5000
# Testing combination 345/5000
# Testing combination 346/5000
# Testing combination 347/5000
# Testing combination 348/5000
# Testing combination 349/5000
# Testing combination 350/5000
# Testing combination 351/5000
# Testing combination 352/5000
# Testing combination 353/5000
# Testing combination 354/5000
# Testing combination 355/5000
# Testing combination 356/5000
# Testing combination 357/5000
# Testing combination 358/5000
# Testing combination 359/5000
# Testing combination 360/5000
# Testing combination 361/5000
# Testing combination 362/5000
# Testing combination 363/5000
# Testing combination 364/5000
# Testing combination 365/5000
# Testing combination 366/5000
# Testing combination 367/5000
# Testing combination 368/5000
# Testing combination 369/5000
# Testing combination 370/5000
# Testing combination 371/5000
# Testing combination 372/5000
# Testing combination 373/5000
# Testing combination 374/5000
# Testing combination 375/5000
# Testing combination 376/5000
# Testing combination 377/5000
# Testing combination 378/5000
# Testing combination 379/5000
# Testing combination 380/5000
# Testing combination 381/5000
# Testing combination 382/5000
# Testing combination 383/5000
# Testing combination 384/5000
# Testing combination 385/5000
# Testing combination 386/5000
# Testing combination 387/5000
# Testing combination 388/5000
# Testing combination 389/5000
# Testing combination 390/5000
# Testing combination 391/5000
# Testing combination 392/5000
# Testing combination 393/5000
# Testing combination 394/5000
# Testing combination 395/5000
# Testing combination 396/5000
# Testing combination 397/5000
# Testing combination 398/5000
# Testing combination 399/5000
# Testing combination 400/5000
# Testing combination 401/5000
# Testing combination 402/5000
# Testing combination 403/5000
# Testing combination 404/5000
# Testing combination 405/5000
# Testing combination 406/5000
# Testing combination 407/5000
# Testing combination 408/5000
# Testing combination 409/5000
# Testing combination 410/5000
# Testing combination 411/5000
# Testing combination 412/5000
# Testing combination 413/5000
# Testing combination 414/5000
# Testing combination 415/5000
# Testing combination 416/5000
# Testing combination 417/5000
# Testing combination 418/5000
# Testing combination 419/5000
# Testing combination 420/5000
# Testing combination 421/5000
# Testing combination 422/5000
# Testing combination 423/5000
# Testing combination 424/5000
# Testing combination 425/5000
# Testing combination 426/5000
# Testing combination 427/5000
# Testing combination 428/5000
# Testing combination 429/5000
# Testing combination 430/5000
# Testing combination 431/5000
# Testing combination 432/5000
# Testing combination 433/5000
# Testing combination 434/5000
# Testing combination 435/5000
# Testing combination 436/5000
# Testing combination 437/5000
# Testing combination 438/5000
# Testing combination 439/5000
# Testing combination 440/5000
# Testing combination 441/5000
# Testing combination 442/5000
# Testing combination 443/5000
# Testing combination 444/5000
# Testing combination 445/5000
# Testing combination 446/5000
# Testing combination 447/5000
# Testing combination 448/5000
# Testing combination 449/5000
# Testing combination 450/5000
# Testing combination 451/5000
# Testing combination 452/5000
# Testing combination 453/5000
# Testing combination 454/5000
# Testing combination 455/5000
# Testing combination 456/5000
# Testing combination 457/5000
# Testing combination 458/5000
# Testing combination 459/5000
# Testing combination 460/5000
# Testing combination 461/5000
# Testing combination 462/5000
# Testing combination 463/5000
# Testing combination 464/5000
# Testing combination 465/5000
# Testing combination 466/5000
# Testing combination 467/5000
# Testing combination 468/5000
# Testing combination 469/5000
# Testing combination 470/5000
# Testing combination 471/5000
# Testing combination 472/5000
# Testing combination 473/5000
# Testing combination 474/5000
# Testing combination 475/5000
# Testing combination 476/5000
# Testing combination 477/5000
# Testing combination 478/5000
# Testing combination 479/5000
# Testing combination 480/5000
# Testing combination 481/5000
# Testing combination 482/5000
# Testing combination 483/5000
# Testing combination 484/5000
# Testing combination 485/5000
# Testing combination 486/5000
# Testing combination 487/5000
# Testing combination 488/5000
# Testing combination 489/5000
# Testing combination 490/5000
# Testing combination 491/5000
# Testing combination 492/5000
# Testing combination 493/5000
# Testing combination 494/5000
# Testing combination 495/5000
# Testing combination 496/5000
# Testing combination 497/5000
# Testing combination 498/5000
# Testing combination 499/5000
# Testing combination 500/5000
# Testing combination 501/5000
# Testing combination 502/5000
# Testing combination 503/5000
# Testing combination 504/5000
# Testing combination 505/5000
# Testing combination 506/5000
# Testing combination 507/5000
# Testing combination 508/5000
# Testing combination 509/5000
# Testing combination 510/5000
# Testing combination 511/5000
# Testing combination 512/5000
# Testing combination 513/5000
# Testing combination 514/5000
# Testing combination 515/5000
# Testing combination 516/5000
# Testing combination 517/5000
# Testing combination 518/5000
# Testing combination 519/5000
# Testing combination 520/5000
# Testing combination 521/5000
# Testing combination 522/5000
# Testing combination 523/5000
# Testing combination 524/5000
# Testing combination 525/5000
# Testing combination 526/5000
# Testing combination 527/5000
# Testing combination 528/5000
# Testing combination 529/5000
# Testing combination 530/5000
# Testing combination 531/5000
# Testing combination 532/5000
# Testing combination 533/5000
# Testing combination 534/5000
# Testing combination 535/5000
# Testing combination 536/5000
# Testing combination 537/5000
# Testing combination 538/5000
# Testing combination 539/5000
# Testing combination 540/5000
# Testing combination 541/5000
# Testing combination 542/5000
# Testing combination 543/5000
# Testing combination 544/5000
# Testing combination 545/5000
# Testing combination 546/5000
# Testing combination 547/5000
# Testing combination 548/5000
# Testing combination 549/5000
# Testing combination 550/5000
# Testing combination 551/5000
# Testing combination 552/5000
# Testing combination 553/5000
# Testing combination 554/5000
# Testing combination 555/5000
# Testing combination 556/5000
# Testing combination 557/5000
# Testing combination 558/5000
# Testing combination 559/5000
# Testing combination 560/5000
# Testing combination 561/5000
# Testing combination 562/5000
# Testing combination 563/5000
# Testing combination 564/5000
# Testing combination 565/5000
# Testing combination 566/5000
# Testing combination 567/5000
# Testing combination 568/5000
# Testing combination 569/5000
# Testing combination 570/5000
# Testing combination 571/5000
# Testing combination 572/5000
# Testing combination 573/5000
# Testing combination 574/5000
# Testing combination 575/5000
# Testing combination 576/5000
# Testing combination 577/5000
# Testing combination 578/5000
# Testing combination 579/5000
# Testing combination 580/5000
# Testing combination 581/5000
# Testing combination 582/5000
# Testing combination 583/5000
# Testing combination 584/5000
# Testing combination 585/5000
# Testing combination 586/5000
# Testing combination 587/5000
# Testing combination 588/5000
# Testing combination 589/5000
# Testing combination 590/5000
# Testing combination 591/5000
# Testing combination 592/5000
# Testing combination 593/5000
# Testing combination 594/5000
# Testing combination 595/5000
# Testing combination 596/5000
# Testing combination 597/5000
# Testing combination 598/5000
# Testing combination 599/5000
# Testing combination 600/5000
# Testing combination 601/5000
# Testing combination 602/5000
# Testing combination 603/5000
# Testing combination 604/5000
# Testing combination 605/5000
# Testing combination 606/5000
# Testing combination 607/5000
# Testing combination 608/5000
# Testing combination 609/5000
# Testing combination 610/5000
# Testing combination 611/5000
# Testing combination 612/5000
# Testing combination 613/5000
# Testing combination 614/5000
# Testing combination 615/5000
# Testing combination 616/5000
# Testing combination 617/5000
# Testing combination 618/5000
# Testing combination 619/5000
# Testing combination 620/5000
# Testing combination 621/5000
# Testing combination 622/5000
# Testing combination 623/5000
# Testing combination 624/5000
# Testing combination 625/5000
# Testing combination 626/5000
# Testing combination 627/5000
# Testing combination 628/5000
# Testing combination 629/5000
# Testing combination 630/5000
# Testing combination 631/5000
# Testing combination 632/5000
# Testing combination 633/5000
# Testing combination 634/5000
# Testing combination 635/5000
# Testing combination 636/5000
# Testing combination 637/5000
# Testing combination 638/5000
# Testing combination 639/5000
# Testing combination 640/5000
# Testing combination 641/5000
# Testing combination 642/5000
# Testing combination 643/5000
# Testing combination 644/5000
# Testing combination 645/5000
# Testing combination 646/5000
# Testing combination 647/5000
# Testing combination 648/5000
# Testing combination 649/5000
# Testing combination 650/5000
# Testing combination 651/5000
# Testing combination 652/5000
# Testing combination 653/5000
# Testing combination 654/5000
# Testing combination 655/5000
# Testing combination 656/5000
# Testing combination 657/5000
# Testing combination 658/5000
# Testing combination 659/5000
# Testing combination 660/5000
# Testing combination 661/5000
# Testing combination 662/5000
# Testing combination 663/5000
# Testing combination 664/5000
# Testing combination 665/5000
# Testing combination 666/5000
# Testing combination 667/5000
# Testing combination 668/5000
# Testing combination 669/5000
# Testing combination 670/5000
# Testing combination 671/5000
# Testing combination 672/5000
# Testing combination 673/5000
# Testing combination 674/5000
# Testing combination 675/5000
# Testing combination 676/5000
# Testing combination 677/5000
# Testing combination 678/5000
# Testing combination 679/5000
# Testing combination 680/5000
# Testing combination 681/5000
# Testing combination 682/5000
# Testing combination 683/5000
# Testing combination 684/5000
# Testing combination 685/5000
# Testing combination 686/5000
# Testing combination 687/5000
# Testing combination 688/5000
# Testing combination 689/5000
# Testing combination 690/5000
# Testing combination 691/5000
# Testing combination 692/5000
# Testing combination 693/5000
# Testing combination 694/5000
# Testing combination 695/5000
# Testing combination 696/5000
# Testing combination 697/5000
# Testing combination 698/5000
# Testing combination 699/5000
# Testing combination 700/5000
# Testing combination 701/5000
# Testing combination 702/5000
# Testing combination 703/5000
# Testing combination 704/5000
# Testing combination 705/5000
# Testing combination 706/5000
# Testing combination 707/5000
# Testing combination 708/5000
# Testing combination 709/5000
# Testing combination 710/5000
# Testing combination 711/5000
# Testing combination 712/5000
# Testing combination 713/5000
# Testing combination 714/5000
# Testing combination 715/5000
# Testing combination 716/5000
# Testing combination 717/5000
# Testing combination 718/5000
# Testing combination 719/5000
# Testing combination 720/5000
# Testing combination 721/5000
# Testing combination 722/5000
# Testing combination 723/5000
# Testing combination 724/5000
# Testing combination 725/5000
# Testing combination 726/5000
# Testing combination 727/5000
# Testing combination 728/5000
# Testing combination 729/5000
# Testing combination 730/5000
# Testing combination 731/5000
# Testing combination 732/5000
# Testing combination 733/5000
# Testing combination 734/5000
# Testing combination 735/5000
# Testing combination 736/5000
# Testing combination 737/5000
# Testing combination 738/5000
# Testing combination 739/5000
# Testing combination 740/5000
# Testing combination 741/5000
# Testing combination 742/5000
# Testing combination 743/5000
# Testing combination 744/5000
# Testing combination 745/5000
# Testing combination 746/5000
# Testing combination 747/5000
# Testing combination 748/5000
# Testing combination 749/5000
# Testing combination 750/5000
# Testing combination 751/5000
# Testing combination 752/5000
# Testing combination 753/5000
# Testing combination 754/5000
# Testing combination 755/5000
# Testing combination 756/5000
# Testing combination 757/5000
# Testing combination 758/5000
# Testing combination 759/5000
# Testing combination 760/5000
# Testing combination 761/5000
# Testing combination 762/5000
# Testing combination 763/5000
# Testing combination 764/5000
# Testing combination 765/5000
# Testing combination 766/5000
# Testing combination 767/5000
# Testing combination 768/5000
# Testing combination 769/5000
# Testing combination 770/5000
# Testing combination 771/5000
# Testing combination 772/5000
# Testing combination 773/5000
# Testing combination 774/5000
# Testing combination 775/5000
# Testing combination 776/5000
# Testing combination 777/5000
# Testing combination 778/5000
# Testing combination 779/5000
# Testing combination 780/5000
# Testing combination 781/5000
# Testing combination 782/5000
# Testing combination 783/5000
# Testing combination 784/5000
# Testing combination 785/5000
# Testing combination 786/5000
# Testing combination 787/5000
# Testing combination 788/5000
# Testing combination 789/5000
# Testing combination 790/5000
# Testing combination 791/5000
# Testing combination 792/5000
# Testing combination 793/5000
# Testing combination 794/5000
# Testing combination 795/5000
# Testing combination 796/5000
# Testing combination 797/5000
# Testing combination 798/5000
# Testing combination 799/5000
# Testing combination 800/5000
# Testing combination 801/5000
# Testing combination 802/5000
# Testing combination 803/5000
# Testing combination 804/5000
# Testing combination 805/5000
# Testing combination 806/5000
# Testing combination 807/5000
# Testing combination 808/5000
# Testing combination 809/5000
# Testing combination 810/5000
# Testing combination 811/5000
# Testing combination 812/5000
# Testing combination 813/5000
# Testing combination 814/5000
# Testing combination 815/5000
# Testing combination 816/5000
# Testing combination 817/5000
# Testing combination 818/5000
# Testing combination 819/5000
# Testing combination 820/5000
# Testing combination 821/5000
# Testing combination 822/5000
# Testing combination 823/5000
# Testing combination 824/5000
# Testing combination 825/5000
# Testing combination 826/5000
# Testing combination 827/5000
# Testing combination 828/5000
# Testing combination 829/5000
# Testing combination 830/5000
# Testing combination 831/5000
# Testing combination 832/5000
# Testing combination 833/5000
# Testing combination 834/5000
# Testing combination 835/5000
# Testing combination 836/5000
# Testing combination 837/5000
# Testing combination 838/5000
# Testing combination 839/5000
# Testing combination 840/5000
# Testing combination 841/5000
# Testing combination 842/5000
# Testing combination 843/5000
# Testing combination 844/5000
# Testing combination 845/5000
# Testing combination 846/5000
# Testing combination 847/5000
# Testing combination 848/5000
# Testing combination 849/5000
# Testing combination 850/5000
# Testing combination 851/5000
# Testing combination 852/5000
# Testing combination 853/5000
# Testing combination 854/5000
# Testing combination 855/5000
# Testing combination 856/5000
# Testing combination 857/5000
# Testing combination 858/5000
# Testing combination 859/5000
# Testing combination 860/5000
# Testing combination 861/5000
# Testing combination 862/5000
# Testing combination 863/5000
# Testing combination 864/5000
# Testing combination 865/5000
# Testing combination 866/5000
# Testing combination 867/5000
# Testing combination 868/5000
# Testing combination 869/5000
# Testing combination 870/5000
# Testing combination 871/5000
# Testing combination 872/5000
# Testing combination 873/5000
# Testing combination 874/5000
# Testing combination 875/5000
# Testing combination 876/5000
# Testing combination 877/5000
# Testing combination 878/5000
# Testing combination 879/5000
# Testing combination 880/5000
# Testing combination 881/5000
# Testing combination 882/5000
# Testing combination 883/5000
# Testing combination 884/5000
# Testing combination 885/5000
# Testing combination 886/5000
# Testing combination 887/5000
# Testing combination 888/5000
# Testing combination 889/5000
# Testing combination 890/5000
# Testing combination 891/5000
# Testing combination 892/5000
# Testing combination 893/5000
# Testing combination 894/5000
# Testing combination 895/5000
# Testing combination 896/5000
# Testing combination 897/5000
# Testing combination 898/5000
# Testing combination 899/5000
# Testing combination 900/5000
# Testing combination 901/5000
# Testing combination 902/5000
# Testing combination 903/5000
# Testing combination 904/5000
# Testing combination 905/5000
# Testing combination 906/5000
# Testing combination 907/5000
# Testing combination 908/5000
# Testing combination 909/5000
# Testing combination 910/5000
# Testing combination 911/5000
# Testing combination 912/5000
# Testing combination 913/5000
# Testing combination 914/5000
# Testing combination 915/5000
# Testing combination 916/5000
# Testing combination 917/5000
# Testing combination 918/5000
# Testing combination 919/5000
# Testing combination 920/5000
# Testing combination 921/5000
# Testing combination 922/5000
# Testing combination 923/5000
# Testing combination 924/5000
# Testing combination 925/5000
# Testing combination 926/5000
# Testing combination 927/5000
# Testing combination 928/5000
# Testing combination 929/5000
# Testing combination 930/5000
# Testing combination 931/5000
# Testing combination 932/5000
# Testing combination 933/5000
# Testing combination 934/5000
# Testing combination 935/5000
# Testing combination 936/5000
# Testing combination 937/5000
# Testing combination 938/5000
# Testing combination 939/5000
# Testing combination 940/5000
# Testing combination 941/5000
# Testing combination 942/5000
# Testing combination 943/5000
# Testing combination 944/5000
# Testing combination 945/5000
# Testing combination 946/5000
# Testing combination 947/5000
# Testing combination 948/5000
# Testing combination 949/5000
# Testing combination 950/5000
# Testing combination 951/5000
# Testing combination 952/5000
# Testing combination 953/5000
# Testing combination 954/5000
# Testing combination 955/5000
# Testing combination 956/5000
# Testing combination 957/5000
# Testing combination 958/5000
# Testing combination 959/5000
# Testing combination 960/5000
# Testing combination 961/5000
# Testing combination 962/5000
# Testing combination 963/5000
# Testing combination 964/5000
# Testing combination 965/5000
# Testing combination 966/5000
# Testing combination 967/5000
# Testing combination 968/5000
# Testing combination 969/5000
# Testing combination 970/5000
# Testing combination 971/5000
# Testing combination 972/5000
# Testing combination 973/5000
# Testing combination 974/5000
# Testing combination 975/5000
# Testing combination 976/5000
# Testing combination 977/5000
# Testing combination 978/5000
# Testing combination 979/5000
# Testing combination 980/5000
# Testing combination 981/5000
# Testing combination 982/5000
# Testing combination 983/5000
# Testing combination 984/5000
# Testing combination 985/5000
# Testing combination 986/5000
# Testing combination 987/5000
# Testing combination 988/5000
# Testing combination 989/5000
# Testing combination 990/5000
# Testing combination 991/5000
# Testing combination 992/5000
# Testing combination 993/5000
# Testing combination 994/5000
# Testing combination 995/5000
# Testing combination 996/5000
# Testing combination 997/5000
# Testing combination 998/5000
# Testing combination 999/5000
# Testing combination 1000/5000
# Testing combination 1001/5000
# Testing combination 1002/5000
# Testing combination 1003/5000
# Testing combination 1004/5000
# Testing combination 1005/5000
# Testing combination 1006/5000
# Testing combination 1007/5000
# Testing combination 1008/5000
# Testing combination 1009/5000
# Testing combination 1010/5000
# Testing combination 1011/5000
# Testing combination 1012/5000
# Testing combination 1013/5000
# Testing combination 1014/5000
# Testing combination 1015/5000
# Testing combination 1016/5000
# Testing combination 1017/5000
# Testing combination 1018/5000
# Testing combination 1019/5000
# Testing combination 1020/5000
# Testing combination 1021/5000
# Testing combination 1022/5000
# Testing combination 1023/5000
# Testing combination 1024/5000
# Testing combination 1025/5000
# Testing combination 1026/5000
# Testing combination 1027/5000
# Testing combination 1028/5000
# Testing combination 1029/5000
# Testing combination 1030/5000
# Testing combination 1031/5000
# Testing combination 1032/5000
# Testing combination 1033/5000
# Testing combination 1034/5000
# Testing combination 1035/5000
# Testing combination 1036/5000
# Testing combination 1037/5000
# Testing combination 1038/5000
# Testing combination 1039/5000
# Testing combination 1040/5000
# Testing combination 1041/5000
# Testing combination 1042/5000
# Testing combination 1043/5000
# Testing combination 1044/5000
# Testing combination 1045/5000
# Testing combination 1046/5000
# Testing combination 1047/5000
# Testing combination 1048/5000
# Testing combination 1049/5000
# Testing combination 1050/5000
# Testing combination 1051/5000
# Testing combination 1052/5000
# Testing combination 1053/5000
# Testing combination 1054/5000
# Testing combination 1055/5000
# Testing combination 1056/5000
# Testing combination 1057/5000
# Testing combination 1058/5000
# Testing combination 1059/5000
# Testing combination 1060/5000
# Testing combination 1061/5000
# Testing combination 1062/5000
# Testing combination 1063/5000
# Testing combination 1064/5000
# Testing combination 1065/5000
# Testing combination 1066/5000
# Testing combination 1067/5000
# Testing combination 1068/5000
# Testing combination 1069/5000
# Testing combination 1070/5000
# Testing combination 1071/5000
# Testing combination 1072/5000
# Testing combination 1073/5000
# Testing combination 1074/5000
# Testing combination 1075/5000
# Testing combination 1076/5000
# Testing combination 1077/5000
# Testing combination 1078/5000
# Testing combination 1079/5000
# Testing combination 1080/5000
# Testing combination 1081/5000
# Testing combination 1082/5000
# Testing combination 1083/5000
# Testing combination 1084/5000
# Testing combination 1085/5000
# Testing combination 1086/5000
# Testing combination 1087/5000
# Testing combination 1088/5000
# Testing combination 1089/5000
# Testing combination 1090/5000
# Testing combination 1091/5000
# Testing combination 1092/5000
# Testing combination 1093/5000
# Testing combination 1094/5000
# Testing combination 1095/5000
# Testing combination 1096/5000
# Testing combination 1097/5000
# Testing combination 1098/5000
# Testing combination 1099/5000
# Testing combination 1100/5000
# Testing combination 1101/5000
# Testing combination 1102/5000
# Testing combination 1103/5000
# Testing combination 1104/5000
# Testing combination 1105/5000
# Testing combination 1106/5000
# Testing combination 1107/5000
# Testing combination 1108/5000
# Testing combination 1109/5000
# Testing combination 1110/5000
# Testing combination 1111/5000
# Testing combination 1112/5000
# Testing combination 1113/5000
# Testing combination 1114/5000
# Testing combination 1115/5000
# Testing combination 1116/5000
# Testing combination 1117/5000
# Testing combination 1118/5000
# Testing combination 1119/5000
# Testing combination 1120/5000
# Testing combination 1121/5000
# Testing combination 1122/5000
# Testing combination 1123/5000
# Testing combination 1124/5000
# Testing combination 1125/5000
# Testing combination 1126/5000
# Testing combination 1127/5000
# Testing combination 1128/5000
# Testing combination 1129/5000
# Testing combination 1130/5000
# Testing combination 1131/5000
# Testing combination 1132/5000
# Testing combination 1133/5000
# Testing combination 1134/5000
# Testing combination 1135/5000
# Testing combination 1136/5000
# Testing combination 1137/5000
# Testing combination 1138/5000
# Testing combination 1139/5000
# Testing combination 1140/5000
# Testing combination 1141/5000
# Testing combination 1142/5000
# Testing combination 1143/5000
# Testing combination 1144/5000
# Testing combination 1145/5000
# Testing combination 1146/5000
# Testing combination 1147/5000
# Testing combination 1148/5000
# Testing combination 1149/5000
# Testing combination 1150/5000
# Testing combination 1151/5000
# Testing combination 1152/5000
# Testing combination 1153/5000
# Testing combination 1154/5000
# Testing combination 1155/5000
# Testing combination 1156/5000
# Testing combination 1157/5000
# Testing combination 1158/5000
# Testing combination 1159/5000
# Testing combination 1160/5000
# Testing combination 1161/5000
# Testing combination 1162/5000
# Testing combination 1163/5000
# Testing combination 1164/5000
# Testing combination 1165/5000
# Testing combination 1166/5000
# Testing combination 1167/5000
# Testing combination 1168/5000
# Testing combination 1169/5000
# Testing combination 1170/5000
# Testing combination 1171/5000
# Testing combination 1172/5000
# Testing combination 1173/5000
# Testing combination 1174/5000
# Testing combination 1175/5000
# Testing combination 1176/5000
# Testing combination 1177/5000
# Testing combination 1178/5000
# Testing combination 1179/5000
# Testing combination 1180/5000
# Testing combination 1181/5000
# Testing combination 1182/5000
# Testing combination 1183/5000
# Testing combination 1184/5000
# Testing combination 1185/5000
# Testing combination 1186/5000
# Testing combination 1187/5000
# Testing combination 1188/5000
# Testing combination 1189/5000
# Testing combination 1190/5000
# Testing combination 1191/5000
# Testing combination 1192/5000
# Testing combination 1193/5000
# Testing combination 1194/5000
# Testing combination 1195/5000
# Testing combination 1196/5000
# Testing combination 1197/5000
# Testing combination 1198/5000
# Testing combination 1199/5000
# Testing combination 1200/5000
# Testing combination 1201/5000
# Testing combination 1202/5000
# Testing combination 1203/5000
# Testing combination 1204/5000
# Testing combination 1205/5000
# Testing combination 1206/5000
# Testing combination 1207/5000
# Testing combination 1208/5000
# Testing combination 1209/5000
# Testing combination 1210/5000
# Testing combination 1211/5000
# Testing combination 1212/5000
# Testing combination 1213/5000
# Testing combination 1214/5000
# Testing combination 1215/5000
# Testing combination 1216/5000
# Testing combination 1217/5000
# Testing combination 1218/5000
# Testing combination 1219/5000
# Testing combination 1220/5000
# Testing combination 1221/5000
# Testing combination 1222/5000
# Testing combination 1223/5000
# Testing combination 1224/5000
# Testing combination 1225/5000
# Testing combination 1226/5000
# Testing combination 1227/5000
# Testing combination 1228/5000
# Testing combination 1229/5000
# Testing combination 1230/5000
# Testing combination 1231/5000
# Testing combination 1232/5000
# Testing combination 1233/5000
# Testing combination 1234/5000
# Testing combination 1235/5000
# Testing combination 1236/5000
# Testing combination 1237/5000
# Testing combination 1238/5000
# Testing combination 1239/5000
# Testing combination 1240/5000
# Testing combination 1241/5000
# Testing combination 1242/5000
# Testing combination 1243/5000
# Testing combination 1244/5000
# Testing combination 1245/5000
# Testing combination 1246/5000
# Testing combination 1247/5000
# Testing combination 1248/5000
# Testing combination 1249/5000
# Testing combination 1250/5000
# Testing combination 1251/5000
# Testing combination 1252/5000
# Testing combination 1253/5000
# Testing combination 1254/5000
# Testing combination 1255/5000
# Testing combination 1256/5000
# Testing combination 1257/5000
# Testing combination 1258/5000
# Testing combination 1259/5000
# Testing combination 1260/5000
# Testing combination 1261/5000
# Testing combination 1262/5000
# Testing combination 1263/5000
# Testing combination 1264/5000
# Testing combination 1265/5000
# Testing combination 1266/5000
# Testing combination 1267/5000
# Testing combination 1268/5000
# Testing combination 1269/5000
# Testing combination 1270/5000
# Testing combination 1271/5000
# Testing combination 1272/5000
# Testing combination 1273/5000
# Testing combination 1274/5000
# Testing combination 1275/5000
# Testing combination 1276/5000
# Testing combination 1277/5000
# Testing combination 1278/5000
# Testing combination 1279/5000
# Testing combination 1280/5000
# Testing combination 1281/5000
# Testing combination 1282/5000
# Testing combination 1283/5000
# Testing combination 1284/5000
# Testing combination 1285/5000
# Testing combination 1286/5000
# Testing combination 1287/5000
# Testing combination 1288/5000
# Testing combination 1289/5000
# Testing combination 1290/5000
# Testing combination 1291/5000
# Testing combination 1292/5000
# Testing combination 1293/5000
# Testing combination 1294/5000
# Testing combination 1295/5000
# Testing combination 1296/5000
# Testing combination 1297/5000
# Testing combination 1298/5000
# Testing combination 1299/5000
# Testing combination 1300/5000
# Testing combination 1301/5000
# Testing combination 1302/5000
# Testing combination 1303/5000
# Testing combination 1304/5000
# Testing combination 1305/5000
# Testing combination 1306/5000
# Testing combination 1307/5000
# Testing combination 1308/5000
# Testing combination 1309/5000
# Testing combination 1310/5000
# Testing combination 1311/5000
# Testing combination 1312/5000
# Testing combination 1313/5000
# Testing combination 1314/5000
# Testing combination 1315/5000
# Testing combination 1316/5000
# Testing combination 1317/5000
# Testing combination 1318/5000
# Testing combination 1319/5000
# Testing combination 1320/5000
# Testing combination 1321/5000
# Testing combination 1322/5000
# Testing combination 1323/5000
# Testing combination 1324/5000
# Testing combination 1325/5000
# Testing combination 1326/5000
# Testing combination 1327/5000
# Testing combination 1328/5000
# Testing combination 1329/5000
# Testing combination 1330/5000
# Testing combination 1331/5000
# Testing combination 1332/5000
# Testing combination 1333/5000
# Testing combination 1334/5000
# Testing combination 1335/5000
# Testing combination 1336/5000
# Testing combination 1337/5000
# Testing combination 1338/5000
# Testing combination 1339/5000
# Testing combination 1340/5000
# Testing combination 1341/5000
# Testing combination 1342/5000
# Testing combination 1343/5000
# Testing combination 1344/5000
# Testing combination 1345/5000
# Testing combination 1346/5000
# Testing combination 1347/5000
# Testing combination 1348/5000
# Testing combination 1349/5000
# Testing combination 1350/5000
# Testing combination 1351/5000
# Testing combination 1352/5000
# Testing combination 1353/5000
# Testing combination 1354/5000
# Testing combination 1355/5000
# Testing combination 1356/5000
# Testing combination 1357/5000
# Testing combination 1358/5000
# Testing combination 1359/5000
# Testing combination 1360/5000
# Testing combination 1361/5000
# Testing combination 1362/5000
# Testing combination 1363/5000
# Testing combination 1364/5000
# Testing combination 1365/5000
# Testing combination 1366/5000
# Testing combination 1367/5000
# Testing combination 1368/5000
# Testing combination 1369/5000
# Testing combination 1370/5000
# Testing combination 1371/5000
# Testing combination 1372/5000
# Testing combination 1373/5000
# Testing combination 1374/5000
# Testing combination 1375/5000
# Testing combination 1376/5000
# Testing combination 1377/5000
# Testing combination 1378/5000
# Testing combination 1379/5000
# Testing combination 1380/5000
# Testing combination 1381/5000
# Testing combination 1382/5000
# Testing combination 1383/5000
# Testing combination 1384/5000
# Testing combination 1385/5000
# Testing combination 1386/5000
# Testing combination 1387/5000
# Testing combination 1388/5000
# Testing combination 1389/5000
# Testing combination 1390/5000
# Testing combination 1391/5000
# Testing combination 1392/5000
# Testing combination 1393/5000
# Testing combination 1394/5000
# Testing combination 1395/5000
# Testing combination 1396/5000
# Testing combination 1397/5000
# Testing combination 1398/5000
# Testing combination 1399/5000
# Testing combination 1400/5000
# Testing combination 1401/5000
# Testing combination 1402/5000
# Testing combination 1403/5000
# Testing combination 1404/5000
# Testing combination 1405/5000
# Testing combination 1406/5000
# Testing combination 1407/5000
# Testing combination 1408/5000
# Testing combination 1409/5000
# Testing combination 1410/5000
# Testing combination 1411/5000
# Testing combination 1412/5000
# Testing combination 1413/5000
# Testing combination 1414/5000
# Testing combination 1415/5000
# Testing combination 1416/5000
# Testing combination 1417/5000
# Testing combination 1418/5000
# Testing combination 1419/5000
# Testing combination 1420/5000
# Testing combination 1421/5000
# Testing combination 1422/5000
# Testing combination 1423/5000
# Testing combination 1424/5000
# Testing combination 1425/5000
# Testing combination 1426/5000
# Testing combination 1427/5000
# Testing combination 1428/5000
# Testing combination 1429/5000
# Testing combination 1430/5000
# Testing combination 1431/5000
# Testing combination 1432/5000
# Testing combination 1433/5000
# Testing combination 1434/5000
# Testing combination 1435/5000
# Testing combination 1436/5000
# Testing combination 1437/5000
# Testing combination 1438/5000
# Testing combination 1439/5000
# Testing combination 1440/5000
# Testing combination 1441/5000
# Testing combination 1442/5000
# Testing combination 1443/5000
# Testing combination 1444/5000
# Testing combination 1445/5000
# Testing combination 1446/5000
# Testing combination 1447/5000
# Testing combination 1448/5000
# Testing combination 1449/5000
# Testing combination 1450/5000
# Testing combination 1451/5000
# Testing combination 1452/5000
# Testing combination 1453/5000
# Testing combination 1454/5000
# Testing combination 1455/5000
# Testing combination 1456/5000
# Testing combination 1457/5000
# Testing combination 1458/5000
# Testing combination 1459/5000
# Testing combination 1460/5000
# Testing combination 1461/5000
# Testing combination 1462/5000
# Testing combination 1463/5000
# Testing combination 1464/5000
# Testing combination 1465/5000
# Testing combination 1466/5000
# Testing combination 1467/5000
# Testing combination 1468/5000
# Testing combination 1469/5000
# Testing combination 1470/5000
# Testing combination 1471/5000
# Testing combination 1472/5000
# Testing combination 1473/5000
# Testing combination 1474/5000
# Testing combination 1475/5000
# Testing combination 1476/5000
# Testing combination 1477/5000
# Testing combination 1478/5000
# Testing combination 1479/5000
# Testing combination 1480/5000
# Testing combination 1481/5000
# Testing combination 1482/5000
# Testing combination 1483/5000
# Testing combination 1484/5000
# Testing combination 1485/5000
# Testing combination 1486/5000
# Testing combination 1487/5000
# Testing combination 1488/5000
# Testing combination 1489/5000
# Testing combination 1490/5000
# Testing combination 1491/5000
# Testing combination 1492/5000
# Testing combination 1493/5000
# Testing combination 1494/5000
# Testing combination 1495/5000
# Testing combination 1496/5000
# Testing combination 1497/5000
# Testing combination 1498/5000
# Testing combination 1499/5000
# Testing combination 1500/5000
# Testing combination 1501/5000
# Testing combination 1502/5000
# Testing combination 1503/5000
# Testing combination 1504/5000
# Testing combination 1505/5000
# Testing combination 1506/5000
# Testing combination 1507/5000
# Testing combination 1508/5000
# Testing combination 1509/5000
# Testing combination 1510/5000
# Testing combination 1511/5000
# Testing combination 1512/5000
# Testing combination 1513/5000
# Testing combination 1514/5000
# Testing combination 1515/5000
# Testing combination 1516/5000
# Testing combination 1517/5000
# Testing combination 1518/5000
# Testing combination 1519/5000
# Testing combination 1520/5000
# Testing combination 1521/5000
# Testing combination 1522/5000
# Testing combination 1523/5000
# Testing combination 1524/5000
# Testing combination 1525/5000
# Testing combination 1526/5000
# Testing combination 1527/5000
# Testing combination 1528/5000
# Testing combination 1529/5000
# Testing combination 1530/5000
# Testing combination 1531/5000
# Testing combination 1532/5000
# Testing combination 1533/5000
# Testing combination 1534/5000
# Testing combination 1535/5000
# Testing combination 1536/5000
# Testing combination 1537/5000
# Testing combination 1538/5000
# Testing combination 1539/5000
# Testing combination 1540/5000
# Testing combination 1541/5000
# Testing combination 1542/5000
# Testing combination 1543/5000
# Testing combination 1544/5000
# Testing combination 1545/5000
# Testing combination 1546/5000
# Testing combination 1547/5000
# Testing combination 1548/5000
# Testing combination 1549/5000
# Testing combination 1550/5000
# Testing combination 1551/5000
# Testing combination 1552/5000
# Testing combination 1553/5000
# Testing combination 1554/5000
# Testing combination 1555/5000
# Testing combination 1556/5000
# Testing combination 1557/5000
# Testing combination 1558/5000
# Testing combination 1559/5000
# Testing combination 1560/5000
# Testing combination 1561/5000
# Testing combination 1562/5000
# Testing combination 1563/5000
# Testing combination 1564/5000
# Testing combination 1565/5000
# Testing combination 1566/5000
# Testing combination 1567/5000
# Testing combination 1568/5000
# Testing combination 1569/5000
# Testing combination 1570/5000
# Testing combination 1571/5000
# Testing combination 1572/5000
# Testing combination 1573/5000
# Testing combination 1574/5000
# Testing combination 1575/5000
# Testing combination 1576/5000
# Testing combination 1577/5000
# Testing combination 1578/5000
# Testing combination 1579/5000
# Testing combination 1580/5000
# Testing combination 1581/5000
# Testing combination 1582/5000
# Testing combination 1583/5000
# Testing combination 1584/5000
# Testing combination 1585/5000
# Testing combination 1586/5000
# Testing combination 1587/5000
# Testing combination 1588/5000
# Testing combination 1589/5000
# Testing combination 1590/5000
# Testing combination 1591/5000
# Testing combination 1592/5000
# Testing combination 1593/5000
# Testing combination 1594/5000
# Testing combination 1595/5000
# Testing combination 1596/5000
# Testing combination 1597/5000
# Testing combination 1598/5000
# Testing combination 1599/5000
# Testing combination 1600/5000
# Testing combination 1601/5000
# Testing combination 1602/5000
# Testing combination 1603/5000
# Testing combination 1604/5000
# Testing combination 1605/5000
# Testing combination 1606/5000
# Testing combination 1607/5000
# Testing combination 1608/5000
# Testing combination 1609/5000
# Testing combination 1610/5000
# Testing combination 1611/5000
# Testing combination 1612/5000
# Testing combination 1613/5000
# Testing combination 1614/5000
# Testing combination 1615/5000
# Testing combination 1616/5000
# Testing combination 1617/5000
# Testing combination 1618/5000
# Testing combination 1619/5000
# Testing combination 1620/5000
# Testing combination 1621/5000
# Testing combination 1622/5000
# Testing combination 1623/5000
# Testing combination 1624/5000
# Testing combination 1625/5000
# Testing combination 1626/5000
# Testing combination 1627/5000
# Testing combination 1628/5000
# Testing combination 1629/5000
# Testing combination 1630/5000
# Testing combination 1631/5000
# Testing combination 1632/5000
# Testing combination 1633/5000
# Testing combination 1634/5000
# Testing combination 1635/5000
# Testing combination 1636/5000
# ...
# Testing combination 4477/5000
# Testing combination 4478/5000
# Testing combination 4479/5000
# Testing combination 4480/5000
# Testing combination 4481/5000
# Testing combination 4482/5000
# Testing combination 4483/5000
# Testing combination 4484/5000
# Testing combination 4485/5000
# Testing combination 4486/5000
# Testing combination 4487/5000
# Testing combination 4488/5000
# Testing combination 4489/5000
# Testing combination 4490/5000
# Testing combination 4491/5000
# Testing combination 4492/5000
# Testing combination 4493/5000
# Testing combination 4494/5000
# Testing combination 4495/5000
# Testing combination 4496/5000
# Testing combination 4497/5000
# Testing combination 4498/5000
# Testing combination 4499/5000
# Testing combination 4500/5000
# Testing combination 4501/5000
# Testing combination 4502/5000
# Testing combination 4503/5000
# Testing combination 4504/5000
# Testing combination 4505/5000
# Testing combination 4506/5000
# Testing combination 4507/5000
# Testing combination 4508/5000
# Testing combination 4509/5000
# Testing combination 4510/5000
# Testing combination 4511/5000
# Testing combination 4512/5000
# Testing combination 4513/5000
# Testing combination 4514/5000
# Testing combination 4515/5000
# Testing combination 4516/5000
# Testing combination 4517/5000
# Testing combination 4518/5000
# Testing combination 4519/5000
# Testing combination 4520/5000
# Testing combination 4521/5000
# Testing combination 4522/5000
# Testing combination 4523/5000
# Testing combination 4524/5000
# Testing combination 4525/5000
# Testing combination 4526/5000
# Testing combination 4527/5000
# Testing combination 4528/5000
# Testing combination 4529/5000
# Testing combination 4530/5000
# Testing combination 4531/5000
# Testing combination 4532/5000
# Testing combination 4533/5000
# Testing combination 4534/5000
# Testing combination 4535/5000
# Testing combination 4536/5000
# Testing combination 4537/5000
# Testing combination 4538/5000
# Testing combination 4539/5000
# Testing combination 4540/5000
# Testing combination 4541/5000
# Testing combination 4542/5000
# Testing combination 4543/5000
# Testing combination 4544/5000
# Testing combination 4545/5000
# Testing combination 4546/5000
# Testing combination 4547/5000
# Testing combination 4548/5000
# Testing combination 4549/5000
# Testing combination 4550/5000
# Testing combination 4551/5000
# Testing combination 4552/5000
# Testing combination 4553/5000
# Testing combination 4554/5000
# Testing combination 4555/5000
# Testing combination 4556/5000
# Testing combination 4557/5000
# Testing combination 4558/5000
# Testing combination 4559/5000
# Testing combination 4560/5000
# Testing combination 4561/5000
# Testing combination 4562/5000
# Testing combination 4563/5000
# Testing combination 4564/5000
# Testing combination 4565/5000
# Testing combination 4566/5000
# Testing combination 4567/5000
# Testing combination 4568/5000
# Testing combination 4569/5000
# Testing combination 4570/5000
# Testing combination 4571/5000
# Testing combination 4572/5000
# Testing combination 4573/5000
# Testing combination 4574/5000
# Testing combination 4575/5000
# Testing combination 4576/5000
# Testing combination 4577/5000
# Testing combination 4578/5000
# Testing combination 4579/5000
# Testing combination 4580/5000
# Testing combination 4581/5000
# Testing combination 4582/5000
# Testing combination 4583/5000
# Testing combination 4584/5000
# Testing combination 4585/5000
# Testing combination 4586/5000
# Testing combination 4587/5000
# Testing combination 4588/5000
# Testing combination 4589/5000
# Testing combination 4590/5000
# Testing combination 4591/5000
# Testing combination 4592/5000
# Testing combination 4593/5000
# Testing combination 4594/5000
# Testing combination 4595/5000
# Testing combination 4596/5000
# Testing combination 4597/5000
# Testing combination 4598/5000
# Testing combination 4599/5000
# Testing combination 4600/5000
# Testing combination 4601/5000
# Testing combination 4602/5000
# Testing combination 4603/5000
# Testing combination 4604/5000
# Testing combination 4605/5000
# Testing combination 4606/5000
# Testing combination 4607/5000
# Testing combination 4608/5000
# Testing combination 4609/5000
# Testing combination 4610/5000
# Testing combination 4611/5000
# Testing combination 4612/5000
# Testing combination 4613/5000
# Testing combination 4614/5000
# Testing combination 4615/5000
# Testing combination 4616/5000
# Testing combination 4617/5000
# Testing combination 4618/5000
# Testing combination 4619/5000
# Testing combination 4620/5000
# Testing combination 4621/5000
# Testing combination 4622/5000
# Testing combination 4623/5000
# Testing combination 4624/5000
# Testing combination 4625/5000
# Testing combination 4626/5000
# Testing combination 4627/5000
# Testing combination 4628/5000
# Testing combination 4629/5000
# Testing combination 4630/5000
# Testing combination 4631/5000
# Testing combination 4632/5000
# Testing combination 4633/5000
# Testing combination 4634/5000
# Testing combination 4635/5000
# Testing combination 4636/5000
# Testing combination 4637/5000
# Testing combination 4638/5000
# Testing combination 4639/5000
# Testing combination 4640/5000
# Testing combination 4641/5000
# Testing combination 4642/5000
# Testing combination 4643/5000
# Testing combination 4644/5000
# Testing combination 4645/5000
# Testing combination 4646/5000
# Testing combination 4647/5000
# Testing combination 4648/5000
# Testing combination 4649/5000
# Testing combination 4650/5000
# Testing combination 4651/5000
# Testing combination 4652/5000
# Testing combination 4653/5000
# Testing combination 4654/5000
# Testing combination 4655/5000
# Testing combination 4656/5000
# Testing combination 4657/5000
# Testing combination 4658/5000
# Testing combination 4659/5000
# Testing combination 4660/5000
# Testing combination 4661/5000
# Testing combination 4662/5000
# Testing combination 4663/5000
# Testing combination 4664/5000
# Testing combination 4665/5000
# Testing combination 4666/5000
# Testing combination 4667/5000
# Testing combination 4668/5000
# Testing combination 4669/5000
# Testing combination 4670/5000
# Testing combination 4671/5000
# Testing combination 4672/5000
# Testing combination 4673/5000
# Testing combination 4674/5000
# Testing combination 4675/5000
# Testing combination 4676/5000
# Testing combination 4677/5000
# Testing combination 4678/5000
# Testing combination 4679/5000
# Testing combination 4680/5000
# Testing combination 4681/5000
# Testing combination 4682/5000
# Testing combination 4683/5000
# Testing combination 4684/5000
# Testing combination 4685/5000
# Testing combination 4686/5000
# Testing combination 4687/5000
# Testing combination 4688/5000
# Testing combination 4689/5000
# Testing combination 4690/5000
# Testing combination 4691/5000
# Testing combination 4692/5000
# Testing combination 4693/5000
# Testing combination 4694/5000
# Testing combination 4695/5000
# Testing combination 4696/5000
# Testing combination 4697/5000
# Testing combination 4698/5000
# Testing combination 4699/5000
# Testing combination 4700/5000
# Testing combination 4701/5000
# Testing combination 4702/5000
# Testing combination 4703/5000
# Testing combination 4704/5000
# Testing combination 4705/5000
# Testing combination 4706/5000
# Testing combination 4707/5000
# Testing combination 4708/5000
# Testing combination 4709/5000
# Testing combination 4710/5000
# Testing combination 4711/5000
# Testing combination 4712/5000
# Testing combination 4713/5000
# Testing combination 4714/5000
# Testing combination 4715/5000
# Testing combination 4716/5000
# Testing combination 4717/5000
# Testing combination 4718/5000
# Testing combination 4719/5000
# Testing combination 4720/5000
# Testing combination 4721/5000
# Testing combination 4722/5000
# Testing combination 4723/5000
# Testing combination 4724/5000
# Testing combination 4725/5000
# Testing combination 4726/5000
# Testing combination 4727/5000
# Testing combination 4728/5000
# Testing combination 4729/5000
# Testing combination 4730/5000
# Testing combination 4731/5000
# Testing combination 4732/5000
# Testing combination 4733/5000
# Testing combination 4734/5000
# Testing combination 4735/5000
# Testing combination 4736/5000
# Testing combination 4737/5000
# Testing combination 4738/5000
# Testing combination 4739/5000
# Testing combination 4740/5000
# Testing combination 4741/5000
# Testing combination 4742/5000
# Testing combination 4743/5000
# Testing combination 4744/5000
# Testing combination 4745/5000
# Testing combination 4746/5000
# Testing combination 4747/5000
# Testing combination 4748/5000
# Testing combination 4749/5000
# Testing combination 4750/5000
# Testing combination 4751/5000
# Testing combination 4752/5000
# Testing combination 4753/5000
# Testing combination 4754/5000
# Testing combination 4755/5000
# Testing combination 4756/5000
# Testing combination 4757/5000
# Testing combination 4758/5000
# Testing combination 4759/5000
# Testing combination 4760/5000
# Testing combination 4761/5000
# Testing combination 4762/5000
# Testing combination 4763/5000
# Testing combination 4764/5000
# Testing combination 4765/5000
# Testing combination 4766/5000
# Testing combination 4767/5000
# Testing combination 4768/5000
# Testing combination 4769/5000
# Testing combination 4770/5000
# Testing combination 4771/5000
# Testing combination 4772/5000
# Testing combination 4773/5000
# Testing combination 4774/5000
# Testing combination 4775/5000
# Testing combination 4776/5000
# Testing combination 4777/5000
# Testing combination 4778/5000
# Testing combination 4779/5000
# Testing combination 4780/5000
# Testing combination 4781/5000
# Testing combination 4782/5000
# Testing combination 4783/5000
# Testing combination 4784/5000
# Testing combination 4785/5000
# Testing combination 4786/5000
# Testing combination 4787/5000
# Testing combination 4788/5000
# Testing combination 4789/5000
# Testing combination 4790/5000
# Testing combination 4791/5000
# Testing combination 4792/5000
# Testing combination 4793/5000
# Testing combination 4794/5000
# Testing combination 4795/5000
# Testing combination 4796/5000
# Testing combination 4797/5000
# Testing combination 4798/5000
# Testing combination 4799/5000
# Testing combination 4800/5000
# Testing combination 4801/5000
# Testing combination 4802/5000
# Testing combination 4803/5000
# Testing combination 4804/5000
# Testing combination 4805/5000
# Testing combination 4806/5000
# Testing combination 4807/5000
# Testing combination 4808/5000
# Testing combination 4809/5000
# Testing combination 4810/5000
# Testing combination 4811/5000
# Testing combination 4812/5000
# Testing combination 4813/5000
# Testing combination 4814/5000
# Testing combination 4815/5000
# Testing combination 4816/5000
# Testing combination 4817/5000
# Testing combination 4818/5000
# Testing combination 4819/5000
# Testing combination 4820/5000
# Testing combination 4821/5000
# Testing combination 4822/5000
# Testing combination 4823/5000
# Testing combination 4824/5000
# Testing combination 4825/5000
# Testing combination 4826/5000
# Testing combination 4827/5000
# Testing combination 4828/5000
# Testing combination 4829/5000
# Testing combination 4830/5000
# Testing combination 4831/5000
# Testing combination 4832/5000
# Testing combination 4833/5000
# Testing combination 4834/5000
# Testing combination 4835/5000
# Testing combination 4836/5000
# Testing combination 4837/5000
# Testing combination 4838/5000
# Testing combination 4839/5000
# Testing combination 4840/5000
# Testing combination 4841/5000
# Testing combination 4842/5000
# Testing combination 4843/5000
# Testing combination 4844/5000
# Testing combination 4845/5000
# Testing combination 4846/5000
# Testing combination 4847/5000
# Testing combination 4848/5000
# Testing combination 4849/5000
# Testing combination 4850/5000
# Testing combination 4851/5000
# Testing combination 4852/5000
# Testing combination 4853/5000
# Testing combination 4854/5000
# Testing combination 4855/5000
# Testing combination 4856/5000
# Testing combination 4857/5000
# Testing combination 4858/5000
# Testing combination 4859/5000
# Testing combination 4860/5000
# Testing combination 4861/5000
# Testing combination 4862/5000
# Testing combination 4863/5000
# Testing combination 4864/5000
# Testing combination 4865/5000
# Testing combination 4866/5000
# Testing combination 4867/5000
# Testing combination 4868/5000
# Testing combination 4869/5000
# Testing combination 4870/5000
# Testing combination 4871/5000
# Testing combination 4872/5000
# Testing combination 4873/5000
# Testing combination 4874/5000
# Testing combination 4875/5000
# Testing combination 4876/5000
# Testing combination 4877/5000
# Testing combination 4878/5000
# Testing combination 4879/5000
# Testing combination 4880/5000
# Testing combination 4881/5000
# Testing combination 4882/5000
# Testing combination 4883/5000
# Testing combination 4884/5000
# Testing combination 4885/5000
# Testing combination 4886/5000
# Testing combination 4887/5000
# Testing combination 4888/5000
# Testing combination 4889/5000
# Testing combination 4890/5000
# Testing combination 4891/5000
# Testing combination 4892/5000
# Testing combination 4893/5000
# Testing combination 4894/5000
# Testing combination 4895/5000
# Testing combination 4896/5000
# Testing combination 4897/5000
# Testing combination 4898/5000
# Testing combination 4899/5000
# Testing combination 4900/5000
# Testing combination 4901/5000
# Testing combination 4902/5000
# Testing combination 4903/5000
# Testing combination 4904/5000
# Testing combination 4905/5000
# Testing combination 4906/5000
# Testing combination 4907/5000
# Testing combination 4908/5000
# Testing combination 4909/5000
# Testing combination 4910/5000
# Testing combination 4911/5000
# Testing combination 4912/5000
# Testing combination 4913/5000
# Testing combination 4914/5000
# Testing combination 4915/5000
# Testing combination 4916/5000
# Testing combination 4917/5000
# Testing combination 4918/5000
# Testing combination 4919/5000
# Testing combination 4920/5000
# Testing combination 4921/5000
# Testing combination 4922/5000
# Testing combination 4923/5000
# Testing combination 4924/5000
# Testing combination 4925/5000
# Testing combination 4926/5000
# Testing combination 4927/5000
# Testing combination 4928/5000
# Testing combination 4929/5000
# Testing combination 4930/5000
# Testing combination 4931/5000
# Testing combination 4932/5000
# Testing combination 4933/5000
# Testing combination 4934/5000
# Testing combination 4935/5000
# Testing combination 4936/5000
# Testing combination 4937/5000
# Testing combination 4938/5000
# Testing combination 4939/5000
# Testing combination 4940/5000
# Testing combination 4941/5000
# Testing combination 4942/5000
# Testing combination 4943/5000
# Testing combination 4944/5000
# Testing combination 4945/5000
# Testing combination 4946/5000
# Testing combination 4947/5000
# Testing combination 4948/5000
# Testing combination 4949/5000
# Testing combination 4950/5000
# Testing combination 4951/5000
# Testing combination 4952/5000
# Testing combination 4953/5000
# Testing combination 4954/5000
# Testing combination 4955/5000
# Testing combination 4956/5000
# Testing combination 4957/5000
# Testing combination 4958/5000
# Testing combination 4959/5000
# Testing combination 4960/5000
# Testing combination 4961/5000
# Testing combination 4962/5000
# Testing combination 4963/5000
# Testing combination 4964/5000
# Testing combination 4965/5000
# Testing combination 4966/5000
# Testing combination 4967/5000
# Testing combination 4968/5000
# Testing combination 4969/5000
# Testing combination 4970/5000
# Testing combination 4971/5000
# Testing combination 4972/5000
# Testing combination 4973/5000
# Testing combination 4974/5000
# Testing combination 4975/5000
# Testing combination 4976/5000
# Testing combination 4977/5000
# Testing combination 4978/5000
# Testing combination 4979/5000
# Testing combination 4980/5000
# Testing combination 4981/5000
# Testing combination 4982/5000
# Testing combination 4983/5000
# Testing combination 4984/5000
# Testing combination 4985/5000
# Testing combination 4986/5000
# Testing combination 4987/5000
# Testing combination 4988/5000
# Testing combination 4989/5000
# Testing combination 4990/5000
# Testing combination 4991/5000
# Testing combination 4992/5000
# Testing combination 4993/5000
# Testing combination 4994/5000
# Testing combination 4995/5000
# Testing combination 4996/5000
# Testing combination 4997/5000
# Testing combination 4998/5000
# Testing combination 4999/5000
# Testing combination 5000/5000
# Valid solutions: 3825
# Solutions that exceeded velocity bound: 1175
# Solutions that didn't stabilize in time: 0
# Best gains: Kp = [0.19795918 0.19795918 0.19795918], Ki = [1.e-06 1.e-06 1.e-06], Kd = [111.51515152 111.51515152 111.51515152]
# Best stabilization time: 285 seconds
